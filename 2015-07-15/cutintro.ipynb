# %%
# %matplotlib inline
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.colors as colors
import matplotlib.patches as mpatches

pd.options.display.max_rows = 100
plt.style.use('ggplot')

# %%
def getDataOld(filename):
    data = pd.read_csv(filename, names=['method', 'file', 'status', 'inf_input', 'quant_input', 'cuts_in', 'inf_output', 
                                        'quant_output', 'termset', 'mingrammar', 'num_mingrammars', 'can_sol', 'min_sol', 
                                        'time_termset', 'time_dtable', 'time_grammar', 'time_minsol', 'time_prcons', 
                                        'time_cleanproof'])
    data = data.replace(" ", -1)
    data = data.replace(-1, np.nan)
    data = data.replace('-1', np.nan)
    
    # Setting the correct datatypes
    columns = set(data.keys())
    integer_columns = [c for c in columns if c not in ['method', 'file', 'status']]
    for c in integer_columns:
        data[c] = data[c].astype(np.float)   
    data['method'] = data['method'].astype(str)
    data['file'] = data['file'].astype(str)
    data['status'] = data['status'].astype(str)
    
    # Adding a column for the database
    def getDB (s):
        if 'ExampleProof' in s:
            return 0
        elif 'testing/TSTP' in s:
            return 1
        elif 'testing/veriT' in s:
            return 2
        else:
            return -1
    data['db'] = data.file.apply(getDB)
    
    return data

def getData(filename):
    data = pd.read_json(filename)
    
    # Adding a column for the database
    def getDB (s):
        if 'ExampleProof' in s:
            return 0
        elif 'testing/TSTP/prover9' in s:
            return 1
        elif 'testing/veriT' in s:
            return 2
        elif 'testing/TSTP/leanCoP' in s:
            return 3
        else:
            return -1
    data['db'] = data.file.apply(getDB)
    
    return data

# %%
filename = "results.json"
data = getData(filename)

# %%
# Other exceptions (aka bugs to hunt)

data_other_exp = data[data.status == 'cutintro_other_exception']
print(data_other_exp.shape)
data_other_exp[['method', 'file', 'status']]
# Out:
# (4249, 26)
#                          method  \
# 1291          one_cut_one_quant
# 3037                        NaN
# 3041                        NaN
# 3046                        NaN
# 3063                        NaN
# 3086                        NaN
# 3111                        NaN
# 3113                        NaN
# 3146                        NaN
# 3151          one_cut_one_quant
# 3155                        NaN
# 3168                        NaN
# 3222                        NaN
# 3226                        NaN
# 3232                        NaN
# 3251                        NaN
# 3280                        NaN
# 3286                        NaN
# 3296                        NaN
# 3307          one_cut_one_quant
# 3328          one_cut_one_quant
# 3330          one_cut_one_quant
# 3430          one_cut_one_quant
# 3474          one_cut_one_quant
# 3494          one_cut_one_quant
# 3525          one_cut_one_quant
# 3553          one_cut_one_quant
# 3591          one_cut_one_quant
# 3823          one_cut_one_quant
# 3824                        NaN
# 3825          one_cut_one_quant
# 3828          one_cut_one_quant
# 3829                        NaN
# 3831          one_cut_one_quant
# 3832                        NaN
# 3833          one_cut_one_quant
# 3836          one_cut_one_quant
# 3838          one_cut_one_quant
# 3839          one_cut_one_quant
# 3841          one_cut_one_quant
# 3843          one_cut_one_quant
# 3844          one_cut_one_quant
# 3878                        NaN
# 3888                        NaN
# 3894          one_cut_one_quant
# 3911                        NaN
# 3915                        NaN
# 3916                        NaN
# 3920                        NaN
# 3930                        NaN
# ...                         ...
# 37011                       NaN
# 37014                       NaN
# 37016                       NaN
# 37017  many_cuts_many_quant_2_2
# 37018  many_cuts_many_quant_2_2
# 37020                       NaN
# 37021                       NaN
# 37022                       NaN
# 37023  many_cuts_many_quant_2_2
# 37027  many_cuts_many_quant_2_2
# 37028                       NaN
# 37032                       NaN
# 37033                       NaN
# 37037                       NaN
# 37038                       NaN
# 37040                       NaN
# 37042                       NaN
# 37045                       NaN
# 37048  many_cuts_many_quant_2_2
# 37049                       NaN
# 37050  many_cuts_many_quant_2_2
# 37053                       NaN
# 37055                       NaN
# 37058                       NaN
# 37059                       NaN
# 37060                       NaN
# 37062                       NaN
# 37063                       NaN
# 37064  many_cuts_many_quant_2_2
# 37065                       NaN
# 37066                       NaN
# 37068  many_cuts_many_quant_2_2
# 37069                       NaN
# 37070                       NaN
# 37072                       NaN
# 37073                       NaN
# 37075                       NaN
# 37076  many_cuts_many_quant_2_2
# 37077  many_cuts_many_quant_2_2
# 37078                       NaN
# 37081                       NaN
# 37082                       NaN
# 37083                       NaN
# 37086                       NaN
# 37088                       NaN
# 37089                       NaN
# 37090                       NaN
# 37091                       NaN
# 37092                       NaN
# 37094                       NaN
#
#                                                     file  \
# 1291   testing/TSTP/prover9/RNG/RNG001-1/Prover9---11...
# 3037   testing/TSTP/leanCoP/SCT/SCT165+1/leanCoP---2....
# 3041   testing/TSTP/leanCoP/SCT/SCT164+1/leanCoP---2....
# 3046   testing/TSTP/leanCoP/SCT/SCT131+1/leanCoP---2....
# 3063   testing/TSTP/leanCoP/RNG/RNG125+4/leanCoP---2....
# 3086   testing/TSTP/leanCoP/RNG/RNG121+4/leanCoP---2....
# 3111   testing/TSTP/leanCoP/RNG/RNG087+2/leanCoP---2....
# 3113   testing/TSTP/leanCoP/RNG/RNG086+2/leanCoP---2....
# 3146   testing/TSTP/leanCoP/KRS/KRS193+1/leanCoP---2....
# 3151   testing/TSTP/leanCoP/KRS/KRS065+1/leanCoP---2....
# 3155   testing/TSTP/leanCoP/KRS/KRS194+1/leanCoP---2....
# 3168   testing/TSTP/leanCoP/KRS/KRS063+1/leanCoP---2....
# 3222   testing/TSTP/leanCoP/KRS/KRS190+1/leanCoP---2....
# 3226   testing/TSTP/leanCoP/KRS/KRS178+1/leanCoP---2....
# 3232   testing/TSTP/leanCoP/KRS/KRS191+1/leanCoP---2....
# 3251   testing/TSTP/leanCoP/KRS/KRS187+1/leanCoP---2....
# 3280   testing/TSTP/leanCoP/KRS/KRS195+1/leanCoP---2....
# 3286   testing/TSTP/leanCoP/KRS/KRS196+1/leanCoP---2....
# 3296   testing/TSTP/leanCoP/KRS/KRS126+1/leanCoP---2....
# 3307   testing/TSTP/leanCoP/CSR/CSR103+4/leanCoP---2....
# 3328   testing/TSTP/leanCoP/CSR/CSR103+2/leanCoP---2....
# 3330   testing/TSTP/leanCoP/CSR/CSR103+3/leanCoP---2....
# 3430   testing/TSTP/leanCoP/CSR/CSR103+6/leanCoP---2....
# 3474   testing/TSTP/leanCoP/CSR/CSR103+5/leanCoP---2....
# 3494   testing/TSTP/leanCoP/CSR/CSR098+1/leanCoP---2....
# 3525   testing/TSTP/leanCoP/CSR/CSR103+7/leanCoP---2....
# 3553   testing/TSTP/leanCoP/CSR/CSR098+2/leanCoP---2....
# 3591   testing/TSTP/leanCoP/CSR/CSR103+1/leanCoP---2....
# 3823   testing/TSTP/leanCoP/KLE/KLE002+1/leanCoP---2....
# 3824   testing/TSTP/leanCoP/KLE/KLE001+1/leanCoP---2....
# 3825   testing/TSTP/leanCoP/KLE/KLE076+1/leanCoP---2....
# 3828   testing/TSTP/leanCoP/KLE/KLE053+1/leanCoP---2....
# 3829   testing/TSTP/leanCoP/KLE/KLE005+1/leanCoP---2....
# 3831   testing/TSTP/leanCoP/KLE/KLE059+1/leanCoP---2....
# 3832   testing/TSTP/leanCoP/KLE/KLE004+1/leanCoP---2....
# 3833   testing/TSTP/leanCoP/KLE/KLE150+1/leanCoP---2....
# 3836   testing/TSTP/leanCoP/KLE/KLE074+1/leanCoP---2....
# 3838   testing/TSTP/leanCoP/KLE/KLE051+1/leanCoP---2....
# 3839   testing/TSTP/leanCoP/KLE/KLE067+1/leanCoP---2....
# 3841   testing/TSTP/leanCoP/KLE/KLE006+1/leanCoP---2....
# 3843   testing/TSTP/leanCoP/KLE/KLE072+1/leanCoP---2....
# 3844   testing/TSTP/leanCoP/KLE/KLE075+1/leanCoP---2....
# 3878   testing/TSTP/leanCoP/NLP/NLP208+1/leanCoP---2....
# 3888   testing/TSTP/leanCoP/NLP/NLP204+1/leanCoP---2....
# 3894   testing/TSTP/leanCoP/REL/REL049+1/leanCoP---2....
# 3911   testing/TSTP/leanCoP/LCL/LCL455+1/leanCoP---2....
# 3915   testing/TSTP/leanCoP/LCL/LCL646+1.001/leanCoP-...
# 3916   testing/TSTP/leanCoP/LCL/LCL648+1.001/leanCoP-...
# 3920   testing/TSTP/leanCoP/LCL/LCL536+1/leanCoP---2....
# 3930   testing/TSTP/leanCoP/LCL/LCL684+1.001/leanCoP-...
# ...                                                  ...
# 37011  testing/TSTP/leanCoP/SET/SET586+3/leanCoP---2....
# 37014  testing/TSTP/leanCoP/SET/SET947+1/leanCoP---2....
# 37016  testing/TSTP/leanCoP/SET/SET584+3/leanCoP---2....
# 37017  testing/TSTP/leanCoP/SET/SET063+3/leanCoP---2....
# 37018  testing/TSTP/leanCoP/SET/SET979+1/leanCoP---2....
# 37020  testing/TSTP/leanCoP/SET/SET351+4/leanCoP---2....
# 37021  testing/TSTP/leanCoP/SET/SET200+3/leanCoP---2....
# 37022  testing/TSTP/leanCoP/SET/SET155+4/leanCoP---2....
# 37023  testing/TSTP/leanCoP/SET/SET621+3/leanCoP---2....
# 37027  testing/TSTP/leanCoP/SET/SET602+3/leanCoP---2....
# 37028  testing/TSTP/leanCoP/SET/SET949+1/leanCoP---2....
# 37032  testing/TSTP/leanCoP/SET/SET603+4/leanCoP---2....
# 37033  testing/TSTP/leanCoP/SET/SET590+3/leanCoP---2....
# 37037  testing/TSTP/leanCoP/SET/SET054+1/leanCoP---2....
# 37038  testing/TSTP/leanCoP/SET/SET679+3/leanCoP---2....
# 37040  testing/TSTP/leanCoP/SET/SET625+3/leanCoP---2....
# 37042  testing/TSTP/leanCoP/SET/SET013+4/leanCoP---2....
# 37045  testing/TSTP/leanCoP/SET/SET639+3/leanCoP---2....
# 37048  testing/TSTP/leanCoP/SET/SET926+1/leanCoP---2....
# 37049  testing/TSTP/leanCoP/SET/SET591+3/leanCoP---2....
# 37050  testing/TSTP/leanCoP/SET/SET605+3/leanCoP---2....
# 37053  testing/TSTP/leanCoP/SET/SET635+3/leanCoP---2....
# 37055  testing/TSTP/leanCoP/SET/SET194+3/leanCoP---2....
# 37058  testing/TSTP/leanCoP/SET/SET347+4/leanCoP---2....
# 37059  testing/TSTP/leanCoP/SET/SET614+3/leanCoP---2....
# 37060  testing/TSTP/leanCoP/SET/SET867+1/leanCoP---2....
# 37062  testing/TSTP/leanCoP/SET/SET148+4/leanCoP---2....
# 37063  testing/TSTP/leanCoP/SET/SET875+1/leanCoP---2....
# 37064  testing/TSTP/leanCoP/SET/SET954+1/leanCoP---2....
# 37065  testing/TSTP/leanCoP/SET/SET764+4/leanCoP---2....
# 37066  testing/TSTP/leanCoP/SET/SET909+1/leanCoP---2....
# 37068  testing/TSTP/leanCoP/SET/SET618+3/leanCoP---2....
# 37069  testing/TSTP/leanCoP/SET/SET797+4/leanCoP---2....
# 37070  testing/TSTP/leanCoP/SET/SET101+1/leanCoP---2....
# 37072  testing/TSTP/leanCoP/SET/SET704+4/leanCoP---2....
# 37073  testing/TSTP/leanCoP/SET/SET076+1/leanCoP---2....
# 37075  testing/TSTP/leanCoP/SET/SET044+1/leanCoP---2....
# 37076  testing/TSTP/leanCoP/SET/SET117+1/leanCoP---2....
# 37077  testing/TSTP/leanCoP/SET/SET940+1/leanCoP---2....
# 37078  testing/TSTP/leanCoP/SET/SET199+3/leanCoP---2....
# 37081  testing/TSTP/leanCoP/SET/SET063+1/leanCoP---2....
# 37082  testing/TSTP/leanCoP/SET/SET702+4/leanCoP---2....
# 37083  testing/TSTP/leanCoP/SET/SET062+1/leanCoP---2....
# 37086  testing/TSTP/leanCoP/SET/SET687+4/leanCoP---2....
# 37088  testing/TSTP/leanCoP/SET/SET102+1/leanCoP---2....
# 37089  testing/TSTP/leanCoP/SET/SET705+4/leanCoP---2....
# 37090  testing/TSTP/leanCoP/SET/SET062+3/leanCoP---2....
# 37091  testing/TSTP/leanCoP/SET/SET143+3/leanCoP---2....
# 37092  testing/TSTP/leanCoP/SET/SET878+1/leanCoP---2....
# 37094  testing/TSTP/leanCoP/SET/SET885+1/leanCoP---2....
#
#                          status
# 1291   cutintro_other_exception
# 3037   cutintro_other_exception
# 3041   cutintro_other_exception
# 3046   cutintro_other_exception
# 3063   cutintro_other_exception
# 3086   cutintro_other_exception
# 3111   cutintro_other_exception
# 3113   cutintro_other_exception
# 3146   cutintro_other_exception
# 3151   cutintro_other_exception
# 3155   cutintro_other_exception
# 3168   cutintro_other_exception
# 3222   cutintro_other_exception
# 3226   cutintro_other_exception
# 3232   cutintro_other_exception
# 3251   cutintro_other_exception
# 3280   cutintro_other_exception
# 3286   cutintro_other_exception
# 3296   cutintro_other_exception
# 3307   cutintro_other_exception
# 3328   cutintro_other_exception
# 3330   cutintro_other_exception
# 3430   cutintro_other_exception
# 3474   cutintro_other_exception
# 3494   cutintro_other_exception
# 3525   cutintro_other_exception
# 3553   cutintro_other_exception
# 3591   cutintro_other_exception
# 3823   cutintro_other_exception
# 3824   cutintro_other_exception
# 3825   cutintro_other_exception
# 3828   cutintro_other_exception
# 3829   cutintro_other_exception
# 3831   cutintro_other_exception
# 3832   cutintro_other_exception
# 3833   cutintro_other_exception
# 3836   cutintro_other_exception
# 3838   cutintro_other_exception
# 3839   cutintro_other_exception
# 3841   cutintro_other_exception
# 3843   cutintro_other_exception
# 3844   cutintro_other_exception
# 3878   cutintro_other_exception
# 3888   cutintro_other_exception
# 3894   cutintro_other_exception
# 3911   cutintro_other_exception
# 3915   cutintro_other_exception
# 3916   cutintro_other_exception
# 3920   cutintro_other_exception
# 3930   cutintro_other_exception
# ...                         ...
# 37011  cutintro_other_exception
# 37014  cutintro_other_exception
# 37016  cutintro_other_exception
# 37017  cutintro_other_exception
# 37018  cutintro_other_exception
# 37020  cutintro_other_exception
# 37021  cutintro_other_exception
# 37022  cutintro_other_exception
# 37023  cutintro_other_exception
# 37027  cutintro_other_exception
# 37028  cutintro_other_exception
# 37032  cutintro_other_exception
# 37033  cutintro_other_exception
# 37037  cutintro_other_exception
# 37038  cutintro_other_exception
# 37040  cutintro_other_exception
# 37042  cutintro_other_exception
# 37045  cutintro_other_exception
# 37048  cutintro_other_exception
# 37049  cutintro_other_exception
# 37050  cutintro_other_exception
# 37053  cutintro_other_exception
# 37055  cutintro_other_exception
# 37058  cutintro_other_exception
# 37059  cutintro_other_exception
# 37060  cutintro_other_exception
# 37062  cutintro_other_exception
# 37063  cutintro_other_exception
# 37064  cutintro_other_exception
# 37065  cutintro_other_exception
# 37066  cutintro_other_exception
# 37068  cutintro_other_exception
# 37069  cutintro_other_exception
# 37070  cutintro_other_exception
# 37072  cutintro_other_exception
# 37073  cutintro_other_exception
# 37075  cutintro_other_exception
# 37076  cutintro_other_exception
# 37077  cutintro_other_exception
# 37078  cutintro_other_exception
# 37081  cutintro_other_exception
# 37082  cutintro_other_exception
# 37083  cutintro_other_exception
# 37086  cutintro_other_exception
# 37088  cutintro_other_exception
# 37089  cutintro_other_exception
# 37090  cutintro_other_exception
# 37091  cutintro_other_exception
# 37092  cutintro_other_exception
# 37094  cutintro_other_exception
#
# [4249 rows x 3 columns]

# %%
# Test that are ok in one_cut_one_quantifier and fail for many_cuts_one_quantifier_1

data_ocoq = data[data.method == 'one_cut_one_quant']
data_mcoq1 = data[data.method == 'many_cuts_one_quant_1']

merged = pd.merge(data_ocoq, data_mcoq1, on=['file'], suffixes=('_ocoq', '_mcoq1'))

diff = merged[(merged.status_ocoq == 'ok') & (merged.status_mcoq1 != 'ok')]
print(diff.shape)
diff[['file','status_ocoq', 'status_mcoq1']]
# Out:
# (207, 51)
#                                                    file status_ocoq  \
# 3                                 LinearExampleProof(4)          ok
# 32                           SquareEdgesExampleProof(2)          ok
# 56                      SquareEdges2DimExampleProof(14)          ok
# 95             FactorialFunctionEqualityExampleProof(4)          ok
# 120   testing/TSTP/prover9/SWV/SWV466+1/Prover9---11...          ok
# 121   testing/TSTP/prover9/GEO/GEO070-3/Prover9---11...          ok
# 162   testing/TSTP/prover9/SET/SET510-6/Prover9---11...          ok
# 184   testing/TSTP/prover9/SEU/SEU291+2/Prover9---11...          ok
# 207   testing/TSTP/prover9/SET/SET246-6/Prover9---11...          ok
# 219   testing/TSTP/prover9/KLE/KLE150+1/Prover9---11...          ok
# 222   testing/TSTP/prover9/LCL/LCL526+1/Prover9---11...          ok
# 232   testing/TSTP/prover9/SET/SET018-1/Prover9---11...          ok
# 248   testing/TSTP/prover9/GRP/GRP039-6/Prover9---11...          ok
# 250   testing/TSTP/prover9/RNG/RNG007-1/Prover9---11...          ok
# 253   testing/TSTP/prover9/GEO/GEO213+1/Prover9---11...          ok
# 264   testing/TSTP/prover9/LCL/LCL026-1/Prover9---11...          ok
# 266   testing/TSTP/prover9/SEU/SEU102+1/Prover9---11...          ok
# 286   testing/TSTP/prover9/HEN/HEN005-1/Prover9---11...          ok
# 300   testing/TSTP/prover9/PLA/PLA002-1/Prover9---11...          ok
# 305   testing/TSTP/prover9/REL/REL009+1/Prover9---11...          ok
# 357   testing/TSTP/prover9/GEO/GEO187+2/Prover9---11...          ok
# 379   testing/TSTP/prover9/LCL/LCL756-1/Prover9---11...          ok
# 392   testing/TSTP/prover9/LCL/LCL193-3/Prover9---11...          ok
# 398   testing/TSTP/prover9/LCL/LCL225-1/Prover9---11...          ok
# 408   testing/TSTP/prover9/SWV/SWV841-1/Prover9---11...          ok
# 409   testing/TSTP/prover9/SYN/SYN171-1/Prover9---11...          ok
# 411   testing/TSTP/prover9/GEO/GEO213+2/Prover9---11...          ok
# 416   testing/TSTP/prover9/SET/SET803+4/Prover9---11...          ok
# 453   testing/TSTP/prover9/PRO/PRO014+1/Prover9---11...          ok
# 469   testing/TSTP/prover9/MGT/MGT064-1/Prover9---11...          ok
# 481   testing/TSTP/prover9/GRP/GRP124-6.004/Prover9-...          ok
# 496   testing/TSTP/prover9/FLD/FLD002-3/Prover9---11...          ok
# 504   testing/TSTP/prover9/NUM/NUM016-2/Prover9---11...          ok
# 505   testing/TSTP/prover9/ALG/ALG029+1/Prover9---11...          ok
# 513   testing/TSTP/prover9/FLD/FLD001-3/Prover9---11...          ok
# 522   testing/TSTP/prover9/FLD/FLD063-3/Prover9---11...          ok
# 550   testing/TSTP/prover9/SEU/SEU188+2/Prover9---11...          ok
# 553   testing/TSTP/prover9/GRP/GRP166-2/Prover9---11...          ok
# 554   testing/TSTP/prover9/GRP/GRP496-1/Prover9---11...          ok
# 573   testing/TSTP/prover9/SYN/SYN613-1/Prover9---11...          ok
# 594   testing/TSTP/prover9/SET/SET206-6/Prover9---11...          ok
# 604   testing/TSTP/prover9/SET/SET788+1/Prover9---11...          ok
# 605   testing/TSTP/prover9/GEO/GEO067-3/Prover9---11...          ok
# 667   testing/TSTP/prover9/LCL/LCL453+1/Prover9---11...          ok
# 683   testing/TSTP/prover9/SWV/SWV909-1/Prover9---11...          ok
# 686   testing/TSTP/prover9/HWV/HWV007-1/Prover9---11...          ok
# 691   testing/TSTP/prover9/SWV/SWV408+1/Prover9---11...          ok
# 701   testing/TSTP/prover9/SET/SET105-7/Prover9---11...          ok
# 723   testing/TSTP/prover9/SWB/SWB014+3/Prover9---11...          ok
# 746   testing/TSTP/prover9/SWV/SWV275-2/Prover9---11...          ok
# ...                                                 ...         ...
# 2155  testing/TSTP/prover9/SYN/SYN158-1/Prover9---11...          ok
# 2158  testing/TSTP/prover9/COL/COL044-4/Prover9---11...          ok
# 2159  testing/TSTP/prover9/SET/SET205-6/Prover9---11...          ok
# 2164  testing/TSTP/prover9/REL/REL009-2/Prover9---11...          ok
# 2178  testing/TSTP/prover9/RNG/RNG023-7/Prover9---11...          ok
# 2196  testing/TSTP/prover9/LCL/LCL539+1/Prover9---11...          ok
# 2240  testing/TSTP/prover9/GEO/GEO111+1/Prover9---11...          ok
# 2245  testing/TSTP/prover9/SYN/SYN077+1/Prover9---11...          ok
# 2279  testing/TSTP/prover9/HEN/HEN004-5/Prover9---11...          ok
# 2289  testing/TSTP/prover9/SET/SET473-6/Prover9---11...          ok
# 2293  testing/TSTP/prover9/SET/SET515-6/Prover9---11...          ok
# 2383  testing/TSTP/prover9/GRP/GRP001-1/Prover9---11...          ok
# 2413  testing/TSTP/prover9/GEO/GEO027-2/Prover9---11...          ok
# 2418  testing/TSTP/prover9/SET/SET962+1/Prover9---11...          ok
# 2419  testing/TSTP/prover9/SCT/SCT023-1/Prover9---11...          ok
# 2447  testing/TSTP/prover9/KLE/KLE143+1/Prover9---11...          ok
# 2534  testing/TSTP/prover9/LCL/LCL250-3/Prover9---11...          ok
# 2563  testing/TSTP/prover9/COL/COL044-5/Prover9---11...          ok
# 2567  testing/TSTP/prover9/MGT/MGT007+1/Prover9---11...          ok
# 2575  testing/TSTP/prover9/SYN/SYN219-1/Prover9---11...          ok
# 2579  testing/TSTP/prover9/SET/SET843-2/Prover9---11...          ok
# 2582  testing/TSTP/prover9/SYN/SYN690-1/Prover9---11...          ok
# 2588  testing/TSTP/prover9/KRS/KRS080+1/Prover9---11...          ok
# 2598  testing/TSTP/prover9/GRP/GRP552-1/Prover9---11...          ok
# 2620  testing/TSTP/prover9/LCL/LCL224-1/Prover9---11...          ok
# 2635  testing/TSTP/prover9/LCL/LCL109-5/Prover9---11...          ok
# 2660  testing/TSTP/prover9/NUM/NUM078-1/Prover9---11...          ok
# 2679  testing/TSTP/prover9/GEO/GEO189+1/Prover9---11...          ok
# 2688  testing/TSTP/prover9/NUM/NUM926+3/Prover9---11...          ok
# 2708  testing/TSTP/prover9/GEO/GEO186+3/Prover9---11...          ok
# 2719  testing/TSTP/prover9/SYN/SYN576-1/Prover9---11...          ok
# 2729  testing/TSTP/prover9/SET/SET163-6/Prover9---11...          ok
# 2731  testing/TSTP/prover9/MGT/MGT055+1/Prover9---11...          ok
# 2744  testing/TSTP/prover9/LCL/LCL223-1/Prover9---11...          ok
# 2747  testing/TSTP/prover9/NUM/NUM016-1/Prover9---11...          ok
# 2754  testing/TSTP/prover9/SWV/SWV827-1/Prover9---11...          ok
# 2784  testing/TSTP/prover9/COL/COL044-8/Prover9---11...          ok
# 2785  testing/TSTP/prover9/ANA/ANA002-2/Prover9---11...          ok
# 2792  testing/TSTP/prover9/GRP/GRP574-1/Prover9---11...          ok
# 2806  testing/TSTP/prover9/LCL/LCL533+1/Prover9---11...          ok
# 2807  testing/TSTP/prover9/SWW/SWW101+1/Prover9---11...          ok
# 2824  testing/TSTP/prover9/LCL/LCL194-3/Prover9---11...          ok
# 2839  testing/TSTP/prover9/GEO/GEO030-2/Prover9---11...          ok
# 2858  testing/TSTP/prover9/HWV/HWV017-1/Prover9---11...          ok
# 2872  testing/TSTP/prover9/SET/SET247-6/Prover9---11...          ok
# 2877  testing/TSTP/prover9/RNG/RNG007-4/Prover9---11...          ok
# 2878  testing/TSTP/prover9/SET/SET497-6/Prover9---11...          ok
# 3751  testing/veriT-SMT-LIB/QF_UF/eq_diamond/eq_diam...          ok
# 3753  testing/veriT-SMT-LIB/QF_UF/eq_diamond/eq_diam...          ok
# 3754  testing/veriT-SMT-LIB/QF_UF/eq_diamond/eq_diam...          ok
#
#                  status_mcoq1
# 3     cutintro_uncompressible
# 32    cutintro_uncompressible
# 56             maxsat_timeout
# 95    cutintro_uncompressible
# 120   cutintro_uncompressible
# 121   cutintro_uncompressible
# 162            prcons_timeout
# 184   cutintro_uncompressible
# 207            prcons_timeout
# 219   cutintro_uncompressible
# 222   cutintro_uncompressible
# 232   cutintro_uncompressible
# 248   cutintro_uncompressible
# 250            minsol_timeout
# 253   cutintro_uncompressible
# 264            prcons_timeout
# 266   cutintro_uncompressible
# 286   cutintro_uncompressible
# 300   cutintro_uncompressible
# 305   cutintro_uncompressible
# 357   cutintro_uncompressible
# 379   cutintro_uncompressible
# 392   cutintro_uncompressible
# 398   cutintro_uncompressible
# 408   cutintro_uncompressible
# 409   cutintro_uncompressible
# 411   cutintro_uncompressible
# 416   cutintro_uncompressible
# 453   cutintro_uncompressible
# 469            prcons_timeout
# 481            prcons_timeout
# 496   cutintro_uncompressible
# 504   cutintro_uncompressible
# 505   cutintro_uncompressible
# 513   cutintro_uncompressible
# 522   cutintro_uncompressible
# 550   cutintro_uncompressible
# 553   cutintro_uncompressible
# 554   cutintro_uncompressible
# 573   cutintro_uncompressible
# 594            prcons_timeout
# 604   cutintro_uncompressible
# 605   cutintro_uncompressible
# 667   cutintro_uncompressible
# 683   cutintro_uncompressible
# 686            prcons_timeout
# 691   cutintro_uncompressible
# 701   cutintro_uncompressible
# 723   cutintro_uncompressible
# 746   cutintro_uncompressible
# ...                       ...
# 2155  cutintro_uncompressible
# 2158  cutintro_uncompressible
# 2159           prcons_timeout
# 2164  cutintro_uncompressible
# 2178  cutintro_uncompressible
# 2196  cutintro_uncompressible
# 2240  cutintro_uncompressible
# 2245  cutintro_uncompressible
# 2279  cutintro_uncompressible
# 2289           prcons_timeout
# 2293           prcons_timeout
# 2383  cutintro_uncompressible
# 2413  cutintro_uncompressible
# 2418  cutintro_uncompressible
# 2419  cutintro_uncompressible
# 2447           minsol_timeout
# 2534           maxsat_timeout
# 2563  cutintro_uncompressible
# 2567  cutintro_uncompressible
# 2575  cutintro_uncompressible
# 2579  cutintro_uncompressible
# 2582  cutintro_uncompressible
# 2588           prcons_timeout
# 2598           minsol_timeout
# 2620  cutintro_uncompressible
# 2635  cutintro_uncompressible
# 2660           prcons_timeout
# 2679  cutintro_uncompressible
# 2688  cutintro_uncompressible
# 2708  cutintro_uncompressible
# 2719  cutintro_uncompressible
# 2729           minsol_timeout
# 2731  cutintro_uncompressible
# 2744  cutintro_uncompressible
# 2747  cutintro_uncompressible
# 2754  cutintro_uncompressible
# 2784  cutintro_uncompressible
# 2785  cutintro_uncompressible
# 2792           minsol_timeout
# 2806  cutintro_uncompressible
# 2807           prcons_timeout
# 2824  cutintro_uncompressible
# 2839  cutintro_uncompressible
# 2858  cutintro_uncompressible
# 2872           prcons_timeout
# 2877  cutintro_uncompressible
# 2878           prcons_timeout
# 3751           prcons_timeout
# 3753  cutintro_uncompressible
# 3754           prcons_timeout
#
# [207 rows x 3 columns]

# %%
# Test that are ok in many_cuts_one_quantifier_1 and fail for one_cut_one_quantifier

data_ocoq = data[data.method == 'one_cut_one_quant']
data_mcoq1 = data[data.method == 'many_cuts_one_quant_1']

merged = pd.merge(data_ocoq, data_mcoq1, on=['file'], suffixes=('_ocoq', '_mcmq1'))

diff = merged[(merged.status_ocoq != 'ok') & (merged.status_mcmq1 == 'ok')]
print(diff.shape)
diff[['file','status_ocoq', 'status_mcmq1']]
# Out:
# (36, 51)
#                                                    file  \
# 18                               LinearExampleProof(19)
# 30                       SquareDiagonalExampleProof(12)
# 42                          SquareEdgesExampleProof(12)
# 68                             LinearEqExampleProof(12)
# 74                           SumOfOnesF2ExampleProof(6)
# 80                            SumOfOnesFExampleProof(6)
# 87                             SumOfOnesExampleProof(7)
# 91                 UniformAssociativity3ExampleProof(4)
# 101           FactorialFunctionEqualityExampleProof(10)
# 294   testing/TSTP/prover9/HWC/HWC002-1/Prover9---11...
# 365   testing/TSTP/prover9/SYN/SYN328-1/Prover9---11...
# 382   testing/TSTP/prover9/LCL/LCL048-1/Prover9---11...
# 543   testing/TSTP/prover9/GRP/GRP134-2.003/Prover9-...
# 597   testing/TSTP/prover9/LCL/LCL235-3/Prover9---11...
# 638   testing/TSTP/prover9/GRP/GRP129-4.004/Prover9-...
# 642   testing/TSTP/prover9/KLE/KLE038+1/Prover9---11...
# 759   testing/TSTP/prover9/GRP/GRP144-1/Prover9---11...
# 783   testing/TSTP/prover9/LDA/LDA002-1/Prover9---11...
# 971   testing/TSTP/prover9/MSC/MSC008-1.002/Prover9-...
# 1009  testing/TSTP/prover9/LCL/LCL239-3/Prover9---11...
# 1149  testing/TSTP/prover9/GRP/GRP175-4/Prover9---11...
# 1239  testing/TSTP/prover9/LCL/LCL206-3/Prover9---11...
# 1274  testing/TSTP/prover9/PUZ/PUZ008-3/Prover9---11...
# 1276  testing/TSTP/prover9/SYN/SYN328+1/Prover9---11...
# 1282  testing/TSTP/prover9/GRP/GRP133-2.003/Prover9-...
# 1420  testing/TSTP/prover9/SET/SET661+3/Prover9---11...
# 2030  testing/TSTP/prover9/LCL/LCL009-1/Prover9---11...
# 2046  testing/TSTP/prover9/SYN/SYN155-1/Prover9---11...
# 2111  testing/TSTP/prover9/KLE/KLE022+4/Prover9---11...
# 2311  testing/TSTP/prover9/LCL/LCL180-3/Prover9---11...
# 2432  testing/TSTP/prover9/LCL/LCL203-3/Prover9---11...
# 2462  testing/TSTP/prover9/RNG/RNG008-4/Prover9---11...
# 2476  testing/TSTP/prover9/CAT/CAT004-2/Prover9---11...
# 2618  testing/TSTP/prover9/GRP/GRP589-1/Prover9---11...
# 2670  testing/TSTP/prover9/GRP/GRP159-1/Prover9---11...
# 3607  testing/TSTP/leanCoP/SYN/SYN986+1.003/leanCoP-...
#
#                   status_ocoq status_mcmq1
# 18            grammar_timeout           ok
# 30            grammar_timeout           ok
# 42            grammar_timeout           ok
# 68            grammar_timeout           ok
# 74            grammar_timeout           ok
# 80            grammar_timeout           ok
# 87            grammar_timeout           ok
# 91            grammar_timeout           ok
# 101            prcons_timeout           ok
# 294           grammar_timeout           ok
# 365           grammar_timeout           ok
# 382            prcons_timeout           ok
# 543            prcons_timeout           ok
# 597           grammar_timeout           ok
# 638            prcons_timeout           ok
# 642            minsol_timeout           ok
# 759           grammar_timeout           ok
# 783            prcons_timeout           ok
# 971           grammar_timeout           ok
# 1009          grammar_timeout           ok
# 1149           prcons_timeout           ok
# 1239           prcons_timeout           ok
# 1274           prcons_timeout           ok
# 1276          grammar_timeout           ok
# 1282           prcons_timeout           ok
# 1420           prcons_timeout           ok
# 2030           minsol_timeout           ok
# 2046  cutintro_uncompressible           ok
# 2111  cutintro_uncompressible           ok
# 2311          grammar_timeout           ok
# 2432           dtable_timeout           ok
# 2462           minsol_timeout           ok
# 2476           minsol_timeout           ok
# 2618  cutintro_ehs_unprovable           ok
# 2670          grammar_timeout           ok
# 3607          grammar_timeout           ok

# %%
# Regressions compared to previous test

previous_filename = "../2015-03-15/CutIntroDataLog.txt"
previous_data = getDataOld(previous_filename)

merged = pd.merge(data, previous_data, on=['method', 'file'])
#merged.head(0)

regression = merged[(merged.status_y == 'ok') & (merged.status_x != 'ok')]
#regression.head(0)
print(regression.shape)

regression_delta = regression[(regression.method == 'one_cut_one_quant') | (regression.method == 'one_cut_many_quant')]
print(regression_delta.shape)
#regression_delta.head(0)

regression_maxsat = regression[((regression.method == 'many_cuts_one_quant_1') | (regression.method == 'many_cuts_one_quant_2')) ]
print(regression_maxsat.shape)
#regression_maxsat.head(0)

regression[['method', 'file', 'status_x', 'status_y']]
# Out:
# (339, 44)
# (124, 44)
# (215, 44)
#                       method  \
# 110        one_cut_one_quant
# 129        one_cut_one_quant
# 170        one_cut_one_quant
# 290        one_cut_one_quant
# 295        one_cut_one_quant
# 361        one_cut_one_quant
# 409        one_cut_one_quant
# 451        one_cut_one_quant
# 498        one_cut_one_quant
# 549        one_cut_one_quant
# 567        one_cut_one_quant
# 587        one_cut_one_quant
# 607        one_cut_one_quant
# 609        one_cut_one_quant
# 613        one_cut_one_quant
# 624        one_cut_one_quant
# 675        one_cut_one_quant
# 717        one_cut_one_quant
# 739        one_cut_one_quant
# 750        one_cut_one_quant
# 838        one_cut_one_quant
# 883        one_cut_one_quant
# 908        one_cut_one_quant
# 910        one_cut_one_quant
# 931        one_cut_one_quant
# 961        one_cut_one_quant
# 982        one_cut_one_quant
# 1034       one_cut_one_quant
# 1062       one_cut_one_quant
# 1077       one_cut_one_quant
# 1118       one_cut_one_quant
# 1129       one_cut_one_quant
# 1135       one_cut_one_quant
# 1205       one_cut_one_quant
# 1341       one_cut_one_quant
# 1363       one_cut_one_quant
# 1370       one_cut_one_quant
# 1389       one_cut_one_quant
# 1392       one_cut_one_quant
# 1413       one_cut_one_quant
# 1431       one_cut_one_quant
# 1585       one_cut_one_quant
# 1702       one_cut_one_quant
# 1772       one_cut_one_quant
# 1808       one_cut_one_quant
# 1864       one_cut_one_quant
# 1895       one_cut_one_quant
# 2050       one_cut_one_quant
# 2070       one_cut_one_quant
# 2141       one_cut_one_quant
# ...                      ...
# 10448  many_cuts_one_quant_2
# 10459  many_cuts_one_quant_2
# 10489  many_cuts_one_quant_2
# 10497  many_cuts_one_quant_2
# 10526  many_cuts_one_quant_2
# 10575  many_cuts_one_quant_2
# 10633  many_cuts_one_quant_2
# 10715  many_cuts_one_quant_2
# 10856  many_cuts_one_quant_2
# 10867  many_cuts_one_quant_2
# 10871  many_cuts_one_quant_2
# 11005  many_cuts_one_quant_2
# 11042  many_cuts_one_quant_2
# 11057  many_cuts_one_quant_2
# 11109  many_cuts_one_quant_2
# 11120  many_cuts_one_quant_2
# 11124  many_cuts_one_quant_2
# 11133  many_cuts_one_quant_2
# 11155  many_cuts_one_quant_2
# 11179  many_cuts_one_quant_2
# 11203  many_cuts_one_quant_2
# 11241  many_cuts_one_quant_2
# 11242  many_cuts_one_quant_2
# 11275  many_cuts_one_quant_2
# 11276  many_cuts_one_quant_2
# 11300  many_cuts_one_quant_2
# 11309  many_cuts_one_quant_2
# 11334  many_cuts_one_quant_2
# 11391  many_cuts_one_quant_2
# 11399  many_cuts_one_quant_2
# 11505  many_cuts_one_quant_2
# 11520  many_cuts_one_quant_2
# 11543  many_cuts_one_quant_2
# 11545  many_cuts_one_quant_2
# 11606  many_cuts_one_quant_2
# 11643  many_cuts_one_quant_2
# 11652  many_cuts_one_quant_2
# 11668  many_cuts_one_quant_2
# 11695  many_cuts_one_quant_2
# 11711  many_cuts_one_quant_2
# 11743  many_cuts_one_quant_2
# 11751  many_cuts_one_quant_2
# 11757  many_cuts_one_quant_2
# 11766  many_cuts_one_quant_2
# 11770  many_cuts_one_quant_2
# 11798  many_cuts_one_quant_2
# 11799  many_cuts_one_quant_2
# 11831  many_cuts_one_quant_2
# 11834  many_cuts_one_quant_2
# 11986  many_cuts_one_quant_2
#
#                                                     file  \
# 110    testing/TSTP/prover9/NUM/NUM574+1/Prover9---11...
# 129    testing/TSTP/prover9/SET/SET927+1/Prover9---11...
# 170    testing/TSTP/prover9/RNG/RNG081+1/Prover9---11...
# 290    testing/TSTP/prover9/SET/SET921+1/Prover9---11...
# 295    testing/TSTP/prover9/SET/SET669+3/Prover9---11...
# 361    testing/TSTP/prover9/PRO/PRO009+1/Prover9---11...
# 409    testing/TSTP/prover9/GRA/GRA008+2/Prover9---11...
# 451    testing/TSTP/prover9/REL/REL003+1/Prover9---11...
# 498    testing/TSTP/prover9/BOO/BOO005-1/Prover9---11...
# 549    testing/TSTP/prover9/BOO/BOO006-1/Prover9---11...
# 567    testing/TSTP/prover9/SEU/SEU053+1/Prover9---11...
# 587    testing/TSTP/prover9/SEU/SEU149+2/Prover9---11...
# 607    testing/TSTP/prover9/SEU/SEU150+2/Prover9---11...
# 609    testing/TSTP/prover9/LAT/LAT312+1/Prover9---11...
# 613    testing/TSTP/prover9/ALG/ALG071+1/Prover9---11...
# 624    testing/TSTP/prover9/KLE/KLE055+1/Prover9---11...
# 675    testing/TSTP/prover9/SEU/SEU236+3/Prover9---11...
# 717    testing/TSTP/prover9/KRS/KRS175+1/Prover9---11...
# 739    testing/TSTP/prover9/LAT/LAT310+1/Prover9---11...
# 750    testing/TSTP/prover9/GRA/GRA004+1/Prover9---11...
# 838    testing/TSTP/prover9/SET/SET017+1/Prover9---11...
# 883    testing/TSTP/prover9/SWW/SWW224+1/Prover9---11...
# 908    testing/TSTP/prover9/GEO/GEO126+1/Prover9---11...
# 910    testing/TSTP/prover9/TOP/TOP023+1/Prover9---11...
# 931    testing/TSTP/prover9/SET/SET668+3/Prover9---11...
# 961    testing/TSTP/prover9/SEU/SEU147+2/Prover9---11...
# 982    testing/TSTP/prover9/SWV/SWV473+1/Prover9---11...
# 1034   testing/TSTP/prover9/SET/SET622+3/Prover9---11...
# 1062   testing/TSTP/prover9/SEU/SEU375+1/Prover9---11...
# 1077   testing/TSTP/prover9/KLE/KLE167+1/Prover9---11...
# 1118   testing/TSTP/prover9/GRP/GRP175-4/Prover9---11...
# 1129   testing/TSTP/prover9/LAT/LAT304+1/Prover9---11...
# 1135   testing/TSTP/prover9/SWV/SWV460+1/Prover9---11...
# 1205   testing/TSTP/prover9/RNG/RNG001-1/Prover9---11...
# 1341   testing/TSTP/prover9/KRS/KRS071+1/Prover9---11...
# 1363   testing/TSTP/prover9/PRO/PRO009+3/Prover9---11...
# 1370   testing/TSTP/prover9/SET/SET646+3/Prover9---11...
# 1389   testing/TSTP/prover9/SET/SET664+3/Prover9---11...
# 1392   testing/TSTP/prover9/KLE/KLE037+1/Prover9---11...
# 1413   testing/TSTP/prover9/SWW/SWW390+1/Prover9---11...
# 1431   testing/TSTP/prover9/SYN/SYN078+1/Prover9---11...
# 1585   testing/TSTP/prover9/GEO/GEO125+1/Prover9---11...
# 1702   testing/TSTP/prover9/LAT/LAT306+1/Prover9---11...
# 1772   testing/TSTP/prover9/MGT/MGT034+2/Prover9---11...
# 1808   testing/TSTP/prover9/GRP/GRP731-1/Prover9---11...
# 1864   testing/TSTP/prover9/SWC/SWC008+1/Prover9---11...
# 1895   testing/TSTP/prover9/SET/SET675+3/Prover9---11...
# 2050   testing/TSTP/prover9/SET/SET960+1/Prover9---11...
# 2070   testing/TSTP/prover9/PRO/PRO009+4/Prover9---11...
# 2141   testing/TSTP/prover9/SWC/SWC007+1/Prover9---11...
# ...                                                  ...
# 10448  testing/TSTP/prover9/HEN/HEN003-2/Prover9---11...
# 10459  testing/TSTP/prover9/SEU/SEU141+2/Prover9---11...
# 10489  testing/TSTP/prover9/GRP/GRP166-1/Prover9---11...
# 10497  testing/TSTP/prover9/CAT/CAT010-1/Prover9---11...
# 10526  testing/TSTP/prover9/SYN/SYN577-1/Prover9---11...
# 10575  testing/TSTP/prover9/GEO/GEO192+2/Prover9---11...
# 10633  testing/TSTP/prover9/SYN/SYN559-1/Prover9---11...
# 10715  testing/TSTP/prover9/SWV/SWV251-2/Prover9---11...
# 10856  testing/TSTP/prover9/SWC/SWC008+1/Prover9---11...
# 10867  testing/TSTP/prover9/SEU/SEU169+2/Prover9---11...
# 10871  testing/TSTP/prover9/NUM/NUM455+6/Prover9---11...
# 11005  testing/TSTP/prover9/SET/SET063-6/Prover9---11...
# 11042  testing/TSTP/prover9/SET/SET960+1/Prover9---11...
# 11057  testing/TSTP/prover9/BOO/BOO012-2/Prover9---11...
# 11109  testing/TSTP/prover9/SET/SET821-2/Prover9---11...
# 11120  testing/TSTP/prover9/COL/COL044-4/Prover9---11...
# 11124  testing/TSTP/prover9/GRP/GRP011-4/Prover9---11...
# 11133  testing/TSTP/prover9/SWC/SWC007+1/Prover9---11...
# 11155  testing/TSTP/prover9/SEU/SEU110+1/Prover9---11...
# 11179  testing/TSTP/prover9/SEU/SEU153+2/Prover9---11...
# 11203  testing/TSTP/prover9/GRP/GRP001-2/Prover9---11...
# 11241  testing/TSTP/prover9/HEN/HEN004-5/Prover9---11...
# 11242  testing/TSTP/prover9/SEU/SEU408+1/Prover9---11...
# 11275  testing/TSTP/prover9/GEO/GEO268+3/Prover9---11...
# 11276  testing/TSTP/prover9/SEU/SEU309+1/Prover9---11...
# 11300  testing/TSTP/prover9/SET/SET893+1/Prover9---11...
# 11309  testing/TSTP/prover9/LCL/LCL201-1/Prover9---11...
# 11334  testing/TSTP/prover9/RNG/RNG001-4/Prover9---11...
# 11391  testing/TSTP/prover9/SWV/SWV592-1/Prover9---11...
# 11399  testing/TSTP/prover9/SEU/SEU407+1/Prover9---11...
# 11505  testing/TSTP/prover9/SYN/SYN332+1/Prover9---11...
# 11520  testing/TSTP/prover9/GRP/GRP639+1/Prover9---11...
# 11543  testing/TSTP/prover9/SET/SET843-2/Prover9---11...
# 11545  testing/TSTP/prover9/SYN/SYN054-1/Prover9---11...
# 11606  testing/TSTP/prover9/SYN/SYN072+1/Prover9---11...
# 11643  testing/TSTP/prover9/GEO/GEO189+1/Prover9---11...
# 11652  testing/TSTP/prover9/NUM/NUM926+3/Prover9---11...
# 11668  testing/TSTP/prover9/REL/REL008-3/Prover9---11...
# 11695  testing/TSTP/prover9/MGT/MGT055+1/Prover9---11...
# 11711  testing/TSTP/prover9/NUM/NUM016-1/Prover9---11...
# 11743  testing/TSTP/prover9/SWC/SWC009+1/Prover9---11...
# 11751  testing/TSTP/prover9/KLE/KLE003+1/Prover9---11...
# 11757  testing/TSTP/prover9/GRP/GRP574-1/Prover9---11...
# 11766  testing/TSTP/prover9/SET/SET012-4/Prover9---11...
# 11770  testing/TSTP/prover9/GRP/GRP421-1/Prover9---11...
# 11798  testing/TSTP/prover9/HEN/HEN003-3/Prover9---11...
# 11799  testing/TSTP/prover9/GRP/GRP190-1/Prover9---11...
# 11831  testing/TSTP/prover9/SYN/SYN321-1/Prover9---11...
# 11834  testing/TSTP/prover9/LCL/LCL486+1/Prover9---11...
# 11986  testing/veriT-SMT-LIB/QF_UF/QG-classification/...
#
#                        status_x status_y
# 110     cutintro_uncompressible       ok
# 129     cutintro_uncompressible       ok
# 170     cutintro_uncompressible       ok
# 290     cutintro_uncompressible       ok
# 295     cutintro_uncompressible       ok
# 361     cutintro_uncompressible       ok
# 409     cutintro_uncompressible       ok
# 451     cutintro_uncompressible       ok
# 498     cutintro_uncompressible       ok
# 549     cutintro_uncompressible       ok
# 567     cutintro_uncompressible       ok
# 587     cutintro_uncompressible       ok
# 607     cutintro_uncompressible       ok
# 609              prcons_timeout       ok
# 613     cutintro_uncompressible       ok
# 624     cutintro_uncompressible       ok
# 675     cutintro_uncompressible       ok
# 717     cutintro_uncompressible       ok
# 739     cutintro_uncompressible       ok
# 750     cutintro_uncompressible       ok
# 838     cutintro_uncompressible       ok
# 883     cutintro_uncompressible       ok
# 908     cutintro_uncompressible       ok
# 910     cutintro_uncompressible       ok
# 931     cutintro_uncompressible       ok
# 961     cutintro_uncompressible       ok
# 982     cutintro_uncompressible       ok
# 1034    cutintro_uncompressible       ok
# 1062    cutintro_uncompressible       ok
# 1077    cutintro_uncompressible       ok
# 1118             prcons_timeout       ok
# 1129    cutintro_uncompressible       ok
# 1135    cutintro_uncompressible       ok
# 1205   cutintro_other_exception       ok
# 1341    cutintro_uncompressible       ok
# 1363    cutintro_uncompressible       ok
# 1370    cutintro_uncompressible       ok
# 1389    cutintro_uncompressible       ok
# 1392    cutintro_uncompressible       ok
# 1413    cutintro_uncompressible       ok
# 1431    cutintro_uncompressible       ok
# 1585    cutintro_uncompressible       ok
# 1702             prcons_timeout       ok
# 1772    cutintro_uncompressible       ok
# 1808             prcons_timeout       ok
# 1864    cutintro_uncompressible       ok
# 1895    cutintro_uncompressible       ok
# 2050    cutintro_uncompressible       ok
# 2070    cutintro_uncompressible       ok
# 2141    cutintro_uncompressible       ok
# ...                         ...      ...
# 10448            prcons_timeout       ok
# 10459   cutintro_uncompressible       ok
# 10489   cutintro_ehs_unprovable       ok
# 10497   cutintro_ehs_unprovable       ok
# 10526   cutintro_ehs_unprovable       ok
# 10575   cutintro_uncompressible       ok
# 10633   cutintro_uncompressible       ok
# 10715            prcons_timeout       ok
# 10856   cutintro_uncompressible       ok
# 10867   cutintro_uncompressible       ok
# 10871   cutintro_uncompressible       ok
# 11005            prcons_timeout       ok
# 11042   cutintro_uncompressible       ok
# 11057            prcons_timeout       ok
# 11109            prcons_timeout       ok
# 11120   cutintro_uncompressible       ok
# 11124            prcons_timeout       ok
# 11133   cutintro_uncompressible       ok
# 11155   cutintro_uncompressible       ok
# 11179   cutintro_uncompressible       ok
# 11203   cutintro_ehs_unprovable       ok
# 11241   cutintro_uncompressible       ok
# 11242   cutintro_uncompressible       ok
# 11275   cutintro_ehs_unprovable       ok
# 11276   cutintro_uncompressible       ok
# 11300   cutintro_uncompressible       ok
# 11309   cutintro_ehs_unprovable       ok
# 11334   cutintro_ehs_unprovable       ok
# 11391   cutintro_ehs_unprovable       ok
# 11399   cutintro_uncompressible       ok
# 11505   cutintro_ehs_unprovable       ok
# 11520   cutintro_uncompressible       ok
# 11543   cutintro_uncompressible       ok
# 11545   cutintro_uncompressible       ok
# 11606   cutintro_uncompressible       ok
# 11643   cutintro_uncompressible       ok
# 11652   cutintro_uncompressible       ok
# 11668   cutintro_uncompressible       ok
# 11695   cutintro_uncompressible       ok
# 11711   cutintro_uncompressible       ok
# 11743   cutintro_uncompressible       ok
# 11751   cutintro_uncompressible       ok
# 11757            minsol_timeout       ok
# 11766            prcons_timeout       ok
# 11770   cutintro_ehs_unprovable       ok
# 11798   cutintro_uncompressible       ok
# 11799            prcons_timeout       ok
# 11831   cutintro_uncompressible       ok
# 11834   cutintro_ehs_unprovable       ok
# 11986   cutintro_uncompressible       ok
#
# [339 rows x 4 columns]

# %%
methods = sorted(set(data.method.dropna()))

dbs = {
    0: 'Proof examples',
    1: 'Prover9',
    2: 'VeriT',
    3: 'LeanCoP',
}

# %%
print("=== Number of tests per database and method:\n")

for dbi, dbname in dbs.items():
    for method in methods:
        print("{0} - {1}: {2}".format(dbname, method,
                                     data[(data.method==method) & (data.db==dbi)].shape[0]))
    print()
# Out:
# === Number of tests per database and method:
#
# Proof examples - many_cuts_many_quant_2: 87
# Proof examples - many_cuts_many_quant_2_2: 45
# Proof examples - many_cuts_one_quant_1: 200
# Proof examples - many_cuts_one_quant_2: 138
# Proof examples - one_cut_many_quant: 99
# Proof examples - one_cut_one_quant: 104
# Prover9 - many_cuts_many_quant_2: 2794
# Prover9 - many_cuts_many_quant_2_2: 2791
# Prover9 - many_cuts_one_quant_1: 2787
# Prover9 - many_cuts_one_quant_2: 2792
# Prover9 - one_cut_many_quant: 2789
# Prover9 - one_cut_one_quant: 2790
#
# VeriT - many_cuts_many_quant_2: 142
# VeriT - many_cuts_many_quant_2_2: 142
# VeriT - many_cuts_one_quant_1: 142
# VeriT - many_cuts_one_quant_2: 142
# VeriT - one_cut_many_quant: 142
# VeriT - one_cut_one_quant: 142
#
# LeanCoP - many_cuts_many_quant_2: 859
# LeanCoP - many_cuts_many_quant_2_2: 859
# LeanCoP - many_cuts_one_quant_1: 859
# LeanCoP - many_cuts_one_quant_2: 859
# LeanCoP - one_cut_many_quant: 859
# LeanCoP - one_cut_one_quant: 859

# %%
states = set(data.status.values)
status_colors = {}
for s in data.status.values:
    if s == 'ok':
        c = 'green'
    elif s == 'cutintro_uncompressible':
        c = 'yellow'
    elif s.endswith('timeout'):
        c = plt.cm.Blues(hash(s)/2**65+0.5)
    elif s.endswith('exception'):
        c = plt.cm.Reds(hash(s)/2**65+0.5)
    else:
        c = plt.cm.Greys(hash(s)/2**65+0.5)
    status_colors[s] = c

def plot_status(d, legend=True, **kwargs):
    plt.axis('equal')
    d.plot(kind='pie', autopct='%1.1f%%',
                        colors=[status_colors[s] for s in d.index], **kwargs) \
        .set_ylabel('')
    if legend: plt.legend(d.index, loc='center left', bbox_to_anchor=(1, 0.5))

# %%
plot_status(data.groupby('status').size(), figsize=(14,12), title='Return status: full set')

# %%
for dbi, db in dbs.items():
    for method in methods:
        subdata = data[(data.db==dbi) & (data.method==method)].groupby('status').size()
        plot_status(subdata, title='{0}\n{1}'.format(db,method), labels=None, figsize=(8,6))
        plt.show()

# %%
timecols = ['time_termset', 'time_dtable', 'time_grammar', 'time_minsol', 'time_prcons', 'time_cleanproof']
plt.axis('equal')
data[timecols].mean().plot(kind='pie', figsize=(12,12), autopct='%1.1f%%',
                           title='Time: full set', legend=True).set_ylabel('')

# %%
xsize, ysize = len(dbs.items()), len(methods)
plt.figure(1, figsize=(4*xsize,4*ysize))
plt.suptitle('Time consumption per method and db', fontsize=25)
for i, method in enumerate(methods):
    for j, (dbi, db) in enumerate(dbs.items()):
        plt.subplot(ysize, xsize, i*xsize + j + 1)
        plt.axis('equal')
        data[(data.db==dbi) & (data.method==method)][timecols].mean() \
            .plot(kind='pie', autopct='%1.1f%%', labels=None,
                  title='{0}\n{1}'.format(db,method)).set_ylabel('')
plt.legend(timecols, loc='center left', bbox_to_anchor=(1, 0.5))

# %%
xsize, ysize = len(dbs.items()), len(methods)
plt.figure(1, figsize=(4*xsize,4*ysize))
plt.suptitle('Time consumption per method and db, state==ok', fontsize=25)
for i, method in enumerate(methods):
    for j, (dbi, db) in enumerate(dbs.items()):
        plt.subplot(ysize, xsize, i*xsize + j + 1)
        plt.axis('equal')
        ax = data[(data.db==dbi) & (data.method==method) & (data.status=='ok')][timecols].mean() \
            .plot(kind='pie', autopct='%1.1f%%', labels=None,
                  title='{0}\n{1}'.format(db,method))
        ax.set_ylabel('')
plt.legend(timecols, loc='center left', bbox_to_anchor=(1, 0.5))

# %%
# For Daniel
more_than_one_cut = data[(data.cuts_in > 1)]
print(more_than_one_cut.shape)
more_than_one_cut
# Out:
# (2709, 26)
#        can_sol  cuts_in                                               file  \
# 110         10       32  testing/TSTP/prover9/SWV/SWV480+1/Prover9---11...
# 123         10       43  testing/TSTP/prover9/SWV/SWV466+1/Prover9---11...
# 124         13      182  testing/TSTP/prover9/GEO/GEO070-3/Prover9---11...
# 131          8        4  testing/TSTP/prover9/GRP/GRP729-1/Prover9---11...
# 140         13       62  testing/TSTP/prover9/MGT/MGT054+1/Prover9---11...
# 141         39      674  testing/TSTP/prover9/MGT/MGT005-1/Prover9---11...
# 144          9        7  testing/TSTP/prover9/KLE/KLE150+2/Prover9---11...
# 146         14      139  testing/TSTP/prover9/MGT/MGT055-1/Prover9---11...
# 159          8        7  testing/TSTP/prover9/KLE/KLE035+2/Prover9---11...
# 160          4       87  testing/TSTP/prover9/SEU/SEU340+1/Prover9---11...
# 167         45      337  testing/TSTP/prover9/SET/SET510-6/Prover9---11...
# 171          9       40  testing/TSTP/prover9/SET/SET017-7/Prover9---11...
# 174          4        4  testing/TSTP/prover9/BOO/BOO003-4/Prover9---11...
# 187         25      122  testing/TSTP/prover9/SWV/SWV745-1/Prover9---11...
# 189         10      137  testing/TSTP/prover9/SEU/SEU291+2/Prover9---11...
# 196         10       31  testing/TSTP/prover9/ALG/ALG179+1/Prover9---11...
# 201         17       45  testing/TSTP/prover9/KLE/KLE010+1/Prover9---11...
# 211         10       34  testing/TSTP/prover9/SWV/SWV478+1/Prover9---11...
# 212         28      463  testing/TSTP/prover9/SET/SET246-6/Prover9---11...
# 213         12        9  testing/TSTP/prover9/RNG/RNG019-7/Prover9---11...
# 221          8        7  testing/TSTP/prover9/RNG/RNG021-7/Prover9---11...
# 224          4        3  testing/TSTP/prover9/KLE/KLE150+1/Prover9---11...
# 227         16       37  testing/TSTP/prover9/LCL/LCL526+1/Prover9---11...
# 231          7       33  testing/TSTP/prover9/LCL/LCL196-3/Prover9---11...
# 232         30      520  testing/TSTP/prover9/MGT/MGT027+1/Prover9---11...
# 236          6        5  testing/TSTP/prover9/KLE/KLE064+1/Prover9---11...
# 238          7       62  testing/TSTP/prover9/SET/SET018-1/Prover9---11...
# 243          4        7  testing/TSTP/prover9/GRP/GRP199-1/Prover9---11...
# 252         14       30  testing/TSTP/prover9/SEU/SEU187+1/Prover9---11...
# 256         35      266  testing/TSTP/prover9/RNG/RNG007-1/Prover9---11...
# 260         12       23  testing/TSTP/prover9/HEN/HEN012-1/Prover9---11...
# 261          4       10  testing/TSTP/prover9/SWV/SWV911-1/Prover9---11...
# 272         26       65  testing/TSTP/prover9/SEU/SEU102+1/Prover9---11...
# 274         29       46  testing/TSTP/prover9/SWB/SWB031+2/Prover9---11...
# 279         10        8  testing/TSTP/prover9/KLE/KLE078+1/Prover9---11...
# 289         29      158  testing/TSTP/prover9/MGT/MGT062-1/Prover9---11...
# 292          4        5  testing/TSTP/prover9/COL/COL006-2/Prover9---11...
# 293         10       18  testing/TSTP/prover9/HEN/HEN005-1/Prover9---11...
# 314          4        7  testing/TSTP/prover9/REL/REL009+1/Prover9---11...
# 328         31      649  testing/TSTP/prover9/SEU/SEU235+1/Prover9---11...
# 335         26       54  testing/TSTP/prover9/LCL/LCL241-3/Prover9---11...
# 337         30      520  testing/TSTP/prover9/MGT/MGT027-1/Prover9---11...
# 364         32      288  testing/TSTP/prover9/COM/COM008+2/Prover9---11...
# 367         12       38  testing/TSTP/prover9/SET/SET935+1/Prover9---11...
# 368          4       17  testing/TSTP/prover9/GRP/GRP029-1/Prover9---11...
# 376         17       37  testing/TSTP/prover9/KLE/KLE009+1/Prover9---11...
# 394          4        5  testing/TSTP/prover9/REL/REL008+3/Prover9---11...
# 396          4        3  testing/TSTP/prover9/LCL/LCL756-1/Prover9---11...
# 397         51     1680  testing/TSTP/prover9/MGT/MGT025+1/Prover9---11...
# 409          4       14  testing/TSTP/prover9/LCL/LCL193-3/Prover9---11...
# ...        ...      ...                                                ...
# 33578       34       63  testing/TSTP/prover9/SEU/SEU407+1/Prover9---11...
# 33584        7        6  testing/TSTP/prover9/GRP/GRP679-1/Prover9---11...
# 33600        5        5  testing/TSTP/prover9/LCL/LCL172-3/Prover9---11...
# 33604        7        3  testing/TSTP/prover9/GRP/GRP541-1/Prover9---11...
# 33611       10       49  testing/TSTP/prover9/SET/SET611+3/Prover9---11...
# 33624       52      794  testing/TSTP/prover9/SET/SET657+3/Prover9---11...
# 33641        5       20  testing/TSTP/prover9/SET/SET663+3/Prover9---11...
# 33644        5       24  testing/TSTP/prover9/HEN/HEN006-2/Prover9---11...
# 33645        5        5  testing/TSTP/prover9/SET/SET204-6/Prover9---11...
# 33648       33      100  testing/TSTP/prover9/RNG/RNG089+1/Prover9---11...
# 33651        5      213  testing/TSTP/prover9/SET/SET659+3/Prover9---11...
# 33655        5        3  testing/TSTP/prover9/GRP/GRP530-1/Prover9---11...
# 33656       45      306  testing/TSTP/prover9/MGT/MGT061-1/Prover9---11...
# 33664       44        2  testing/TSTP/prover9/GEO/GEO198+1/Prover9---11...
# 33674        8       18  testing/TSTP/prover9/SEU/SEU171+1/Prover9---11...
# 33710        8       17  testing/TSTP/prover9/SET/SET072-6/Prover9---11...
# 33718        7        5  testing/TSTP/prover9/RNG/RNG024-7/Prover9---11...
# 33727       19       93  testing/TSTP/prover9/SET/SET843-2/Prover9---11...
# 33732       26     7109  testing/TSTP/prover9/LAT/LAT302+1/Prover9---11...
# 33749       54      557  testing/TSTP/prover9/COM/COM022+4/Prover9---11...
# 33750        5        9  testing/TSTP/prover9/ALG/ALG004-1/Prover9---11...
# 33770        9        6  testing/TSTP/prover9/GRP/GRP537-1/Prover9---11...
# 33800       17      108  testing/TSTP/prover9/SET/SET677+3/Prover9---11...
# 33812        7        5  testing/TSTP/prover9/GRP/GRP484-1/Prover9---11...
# 33822       14       43  testing/TSTP/prover9/SWV/SWV626-1/Prover9---11...
# 33828       11       19  testing/TSTP/prover9/KLE/KLE026+1/Prover9---11...
# 33830        9        6  testing/TSTP/prover9/BOO/BOO011-2/Prover9---11...
# 33842        5       10  testing/TSTP/prover9/NUM/NUM926+3/Prover9---11...
# 33859        9        7  testing/TSTP/prover9/REL/REL008-3/Prover9---11...
# 33864       55        2  testing/TSTP/prover9/GEO/GEO190+2/Prover9---11...
# 33886       23      119  testing/TSTP/prover9/MGT/MGT055+1/Prover9---11...
# 33895       20      283  testing/TSTP/prover9/COM/COM013+1/Prover9---11...
# 33904       11       34  testing/TSTP/prover9/ALG/ALG339-1/Prover9---11...
# 33908        9       34  testing/TSTP/prover9/SET/SET507-6/Prover9---11...
# 33909        5        9  testing/TSTP/prover9/SWV/SWV827-1/Prover9---11...
# 33918        9       19  testing/TSTP/prover9/GRP/GRP538-1/Prover9---11...
# 33920       26      125  testing/TSTP/prover9/SWV/SWV746-1/Prover9---11...
# 33925       21     1400  testing/TSTP/prover9/SWV/SWV465+1/Prover9---11...
# 33933        5       13  testing/TSTP/prover9/SET/SET679+3/Prover9---11...
# 33937       19       29  testing/TSTP/prover9/SET/SET013-4/Prover9---11...
# 33946        9        7  testing/TSTP/prover9/KLE/KLE069+1/Prover9---11...
# 33960       18      956  testing/TSTP/prover9/SET/SET012-4/Prover9---11...
# 33980        5       28  testing/TSTP/prover9/SET/SET984+1/Prover9---11...
# 33990       36      255  testing/TSTP/prover9/GEO/GEO076-4/Prover9---11...
# 33993       16       31  testing/TSTP/prover9/HEN/HEN003-3/Prover9---11...
# 33999       11       18  testing/TSTP/prover9/GEO/GEO030-2/Prover9---11...
# 34020       14       62  testing/TSTP/prover9/HWV/HWV017-1/Prover9---11...
# 35833       43      218  testing/TSTP/leanCoP/SWB/SWB005+1/leanCoP---2....
# 35862       43       43  testing/TSTP/leanCoP/SWB/SWB005+2/leanCoP---2....
# 36367       11       17  testing/TSTP/leanCoP/SYN/SYN986+1.002/leanCoP-...
#
#        inf_input  inf_output                    method  min_sol  \
# 110          225         202         one_cut_one_quant        5
# 123          427         319         one_cut_one_quant        5
# 124          935         879         one_cut_one_quant       13
# 131           87         118         one_cut_one_quant        4
# 140          334         280         one_cut_one_quant       13
# 141         1540        3283         one_cut_one_quant       39
# 144          124         150         one_cut_one_quant        7
# 146          577         627         one_cut_one_quant       14
# 159          122          97         one_cut_one_quant        6
# 160          541         417         one_cut_one_quant        2
# 167          366        3455         one_cut_one_quant       41
# 171          179         344         one_cut_one_quant        7
# 174           88          68         one_cut_one_quant        4
# 187          585         679         one_cut_one_quant       25
# 189          551         622         one_cut_one_quant        5
# 196          144         168         one_cut_one_quant       10
# 201          276         437         one_cut_one_quant       15
# 211          279         248         one_cut_one_quant        5
# 212          387        2854         one_cut_one_quant       28
# 213          261        2455         one_cut_one_quant       10
# 221          211        1057         one_cut_one_quant        6
# 224           41          22         one_cut_one_quant        2
# 227          155         166         one_cut_one_quant       11
# 231          237         770         one_cut_one_quant        7
# 232         1601        3126         one_cut_one_quant       30
# 236           78         154         one_cut_one_quant        4
# 238          816         559         one_cut_one_quant        7
# 243           83          82         one_cut_one_quant        4
# 252          102         164         one_cut_one_quant       14
# 256          560        2256         one_cut_one_quant       33
# 260          104         127         one_cut_one_quant       12
# 261          106          71         one_cut_one_quant        2
# 272          159         338         one_cut_one_quant       26
# 274           80         228         one_cut_one_quant       29
# 279          257         351         one_cut_one_quant        8
# 289          360         783         one_cut_one_quant       29
# 292          281         359         one_cut_one_quant        2
# 293           90          94         one_cut_one_quant        5
# 314           65          87         one_cut_one_quant        4
# 328         2832        2956         one_cut_one_quant       31
# 335          353        1001         one_cut_one_quant       24
# 337         1595        3120         one_cut_one_quant       30
# 364         1024        1662         one_cut_one_quant       30
# 367          189         275         one_cut_one_quant       12
# 368           77          97         one_cut_one_quant        4
# 376           98         272         one_cut_one_quant       15
# 394           52          70         one_cut_one_quant        4
# 396           16          21         one_cut_one_quant        2
# 397        12302        9412         one_cut_one_quant       51
# 409          123         340         one_cut_one_quant        2
# ...          ...         ...                       ...      ...
# 33578        188         475  many_cuts_many_quant_2_2       34
# 33584         32          80  many_cuts_many_quant_2_2        7
# 33600         32         123  many_cuts_many_quant_2_2        5
# 33604         21          23  many_cuts_many_quant_2_2        3
# 33611        544         284  many_cuts_many_quant_2_2       10
# 33624        362        4595  many_cuts_many_quant_2_2       52
# 33641         77          90  many_cuts_many_quant_2_2        5
# 33644         89         130  many_cuts_many_quant_2_2        5
# 33645        103          29  many_cuts_many_quant_2_2        3
# 33648        140         990  many_cuts_many_quant_2_2       33
# 33651        866        1043  many_cuts_many_quant_2_2        5
# 33655         39          41  many_cuts_many_quant_2_2        3
# 33656        568        1814  many_cuts_many_quant_2_2       45
# 33664        261      139597  many_cuts_many_quant_2_2       44
# 33674         93          97  many_cuts_many_quant_2_2        8
# 33710        181         104  many_cuts_many_quant_2_2        8
# 33718         62         122  many_cuts_many_quant_2_2        7
# 33727        348         740  many_cuts_many_quant_2_2       19
# 33732        235       72794  many_cuts_many_quant_2_2       26
# 33749        798        3250  many_cuts_many_quant_2_2       54
# 33750         77         134  many_cuts_many_quant_2_2        5
# 33770         43         169  many_cuts_many_quant_2_2        9
# 33800        643         613  many_cuts_many_quant_2_2       17
# 33812         62         124  many_cuts_many_quant_2_2        7
# 33822        206         263  many_cuts_many_quant_2_2       14
# 33828        114         171  many_cuts_many_quant_2_2        9
# 33830        171          45  many_cuts_many_quant_2_2        9
# 33842        278         197  many_cuts_many_quant_2_2        5
# 33859         52         100  many_cuts_many_quant_2_2        9
# 33864        307      245762  many_cuts_many_quant_2_2       55
# 33886        578         569  many_cuts_many_quant_2_2       23
# 33895       1589        1280  many_cuts_many_quant_2_2       15
# 33904        214         211  many_cuts_many_quant_2_2        9
# 33908        272         177  many_cuts_many_quant_2_2        9
# 33909        157          53  many_cuts_many_quant_2_2        3
# 33918         77         431  many_cuts_many_quant_2_2        9
# 33920        585         689  many_cuts_many_quant_2_2       26
# 33925        266       15902  many_cuts_many_quant_2_2       21
# 33933         48          63  many_cuts_many_quant_2_2        5
# 33937        175         219  many_cuts_many_quant_2_2       19
# 33946         62         180  many_cuts_many_quant_2_2        9
# 33960         89        7622  many_cuts_many_quant_2_2       18
# 33980        107         146  many_cuts_many_quant_2_2        3
# 33990        360        2494  many_cuts_many_quant_2_2       36
# 33993         47         165  many_cuts_many_quant_2_2       16
# 33999        111         118  many_cuts_many_quant_2_2       11
# 34020        158         366  many_cuts_many_quant_2_2       14
# 35833        NaN        1424  many_cuts_many_quant_2_2       43
# 35862        NaN         331  many_cuts_many_quant_2_2       43
# 36367        NaN          87  many_cuts_many_quant_2_2       13
#
#        minform_lcomp  mingrammar  nfgrammar ...  time_dtable  time_grammar  \
# 110              NaN          27        NaN ...            1             0
# 123              NaN          36        NaN ...            1             0
# 124              NaN          45        NaN ...            2             0
# 131              NaN          18        NaN ...            1             0
# 140              NaN          21        NaN ...            1             0
# 141              NaN          32        NaN ...            0             0
# 144              NaN          14        NaN ...            0             0
# 146              NaN          32        NaN ...            0             0
# 159              NaN          17        NaN ...            0             1
# 160              NaN          29        NaN ...            0             0
# 167              NaN          28        NaN ...            3            33
# 171              NaN          13        NaN ...            0             0
# 174              NaN          13        NaN ...            0             0
# 187              NaN          14        NaN ...            1             0
# 189              NaN          32        NaN ...            0             0
# 196              NaN          12        NaN ...            0             0
# 201              NaN          41        NaN ...            3             1
# 211              NaN          30        NaN ...            0             0
# 212              NaN          28        NaN ...            4            47
# 213              NaN          30        NaN ...            3            11
# 221              NaN          28        NaN ...            2             4
# 224              NaN           8        NaN ...            0             0
# 227              NaN          26        NaN ...            1             0
# 231              NaN          40        NaN ...           44            25
# 232              NaN          18        NaN ...            0             0
# 236              NaN          12        NaN ...            1             0
# 238              NaN          20        NaN ...            1             0
# 243              NaN          15        NaN ...            0             0
# 252              NaN          17        NaN ...            1             0
# 256              NaN          51        NaN ...            7            68
# 260              NaN          15        NaN ...            0             0
# 261              NaN          11        NaN ...            0             0
# 272              NaN          12        NaN ...            0             0
# 274              NaN          13        NaN ...            0             0
# 279              NaN          44        NaN ...            9             8
# 289              NaN          28        NaN ...            1             0
# 292              NaN          33        NaN ...            3             2
# 293              NaN          16        NaN ...            0             0
# 314              NaN          15        NaN ...            0             0
# 328              NaN          23        NaN ...            1             0
# 335              NaN          57        NaN ...         1726           798
# 337              NaN          18        NaN ...            1             0
# 364              NaN          21        NaN ...            0             1
# 367              NaN          20        NaN ...            0             0
# 368              NaN          10        NaN ...            0             0
# 376              NaN          19        NaN ...            1             0
# 394              NaN          13        NaN ...            0             0
# 396              NaN           6        NaN ...            0             0
# 397              NaN          24        NaN ...            1             0
# 409              NaN          22        NaN ...            1             1
# ...              ...         ...        ... ...          ...           ...
# 33578           7916          18        411 ...          NaN           321
# 33584          28658           9        521 ...          NaN          1694
# 33600          84103           8       1372 ...          NaN          6585
# 33604           4024           6        129 ...          NaN            66
# 33611           7560          15        251 ...          NaN           192
# 33624          18398          26        389 ...          NaN         17379
# 33641           1809          14         92 ...          NaN            90
# 33644          10811          16        460 ...          NaN           360
# 33645           2374           9         77 ...          NaN            29
# 33648           4977          12        120 ...          NaN            79
# 33651           4133          24        232 ...          NaN         17789
# 33655          15858           9        429 ...          NaN          1689
# 33656          10517          31        424 ...          NaN          1574
# 33664          37723          15        456 ...          NaN          2380
# 33674           3880          15        241 ...          NaN           105
# 33710           5969          14        190 ...          NaN           147
# 33718          62913          13        696 ...          NaN          3202
# 33727           6002          12        339 ...          NaN           177
# 33732           6279          22        304 ...          NaN           280
# 33749           7680          21        221 ...          NaN           341
# 33750         114445          14       3328 ...          NaN         49775
# 33770           5149           8        132 ...          NaN           350
# 33800           3673          22        112 ...          NaN           594
# 33812           5285           8        110 ...          NaN            97
# 33822          11740          23        413 ...          NaN          2679
# 33828          23615          18        496 ...          NaN         13298
# 33830          10600          15        203 ...          NaN          8206
# 33842          23785          18       1500 ...          NaN          1785
# 33859          28102          12        555 ...          NaN         39925
# 33864          37906          15        465 ...          NaN          9888
# 33886           4783          31        344 ...          NaN          1118
# 33895           1694          17        131 ...          NaN            61
# 33904           3201          14        138 ...          NaN            78
# 33908           3986          17        979 ...          NaN           208
# 33909          13045          10        640 ...          NaN           504
# 33918          12149          11        364 ...          NaN         11765
# 33920          33556          14        717 ...          NaN          3561
# 33925           4918          25        557 ...          NaN           411
# 33933           1764          11         89 ...          NaN            81
# 33937           5876          10        153 ...          NaN           182
# 33946          43768          14        611 ...          NaN         19014
# 33960          20771          11        350 ...          NaN           776
# 33980           4898          13        297 ...          NaN           117
# 33990          19747          18        290 ...          NaN          1195
# 33993          17304          10        241 ...          NaN           440
# 33999          16609          14        380 ...          NaN           638
# 34020          33027          19        634 ...          NaN          2320
# 35833          10058          14        165 ...          NaN           970
# 35862          10058          14        165 ...          NaN           975
# 36367          45115           7        470 ...          NaN          3135
#
#        time_maxsat time_minform  time_minsol  time_nfgrammar  time_prcons  \
# 110            NaN          NaN          113             NaN          217
# 123            NaN          NaN           34             NaN          347
# 124            NaN          NaN           12             NaN         1110
# 131            NaN          NaN         1415             NaN          105
# 140            NaN          NaN           10             NaN          144
# 141            NaN          NaN           20             NaN         7677
# 144            NaN          NaN           40             NaN          106
# 146            NaN          NaN            9             NaN          731
# 159            NaN          NaN           89             NaN           97
# 160            NaN          NaN           37             NaN          530
# 167            NaN          NaN         2162             NaN         5958
# 171            NaN          NaN           10             NaN          107
# 174            NaN          NaN          479             NaN          231
# 187            NaN          NaN          168             NaN          330
# 189            NaN          NaN           24             NaN          495
# 196            NaN          NaN           13             NaN           75
# 201            NaN          NaN          286             NaN          388
# 211            NaN          NaN           32             NaN          177
# 212            NaN          NaN           87             NaN         1815
# 213            NaN          NaN          116             NaN         2171
# 221            NaN          NaN           35             NaN         1583
# 224            NaN          NaN           13             NaN           28
# 227            NaN          NaN           49             NaN           99
# 231            NaN          NaN           37             NaN         5443
# 232            NaN          NaN           14             NaN         1344
# 236            NaN          NaN           14             NaN           71
# 238            NaN          NaN           19             NaN          413
# 243            NaN          NaN           17             NaN          188
# 252            NaN          NaN           48             NaN           94
# 256            NaN          NaN         1950             NaN        12330
# 260            NaN          NaN            8             NaN           58
# 261            NaN          NaN           16             NaN           55
# 272            NaN          NaN            8             NaN          120
# 274            NaN          NaN           21             NaN           72
# 279            NaN          NaN         1170             NaN          462
# 289            NaN          NaN           22             NaN          337
# 292            NaN          NaN          476             NaN         3782
# 293            NaN          NaN           12             NaN           47
# 314            NaN          NaN           10             NaN           76
# 328            NaN          NaN           18             NaN         2449
# 335            NaN          NaN          369             NaN         3743
# 337            NaN          NaN           16             NaN         1306
# 364            NaN          NaN          465             NaN          960
# 367            NaN          NaN           43             NaN          207
# 368            NaN          NaN            9             NaN           43
# 376            NaN          NaN          183             NaN          145
# 394            NaN          NaN           20             NaN           56
# 396            NaN          NaN           11             NaN           28
# 397            NaN          NaN           53             NaN         9824
# 409            NaN          NaN           25             NaN          730
# ...            ...          ...          ...             ...          ...
# 33578           74           68           12             125           98
# 33584         1243          329           16               3           45
# 33600         4096         1971            5               6           69
# 33604           32           20          133               0           25
# 33611           67           74           12              16           90
# 33624        16085          154           42            1040         2011
# 33641           71            6            5               8           39
# 33644          174           98            7              23           67
# 33645           14            7           12               2           26
# 33648           38           18           87               8          135
# 33651        17502           28            9             242          993
# 33655         1465          140            7               2           40
# 33656          348           72           31            1082          892
# 33664         1835          340            0              70        11889
# 33674           52           22            6              14           42
# 33710           80           33            6               9           40
# 33718         1857         1062           11              15           75
# 33727           75           58           19               9          178
# 33732           65           48           11             133        49203
# 33749          135           51           15             122         1150
# 33750        41469         5627            8              45          177
# 33770          223          107            9               2           88
# 33800          464           17            0             100          194
# 33812           55           26           84               1           75
# 33822         2354          134            0             119          255
# 33828        12530          485          153              63          170
# 33830         7933          217            1              13          180
# 33842         1034          477           43              40          253
# 33859        39401          348           18               8           63
# 33864         9242          360            1             120        37719
# 33886          247           30            9             813          385
# 33895           12           11           11              31          505
# 33904           37           18           20              10           72
# 33908           71           54            7              31           49
# 33909          198          211           19               5           48
# 33918        11607           93            0              10         2323
# 33920         2449          717          123             109          292
# 33925          169           40           20             164        14816
# 33933           65            8            4               2          123
# 33937           49           43            9               5          124
# 33946        18191          591           21              17           92
# 33960          474          222           57               5         3569
# 33980           44           34            7               7           54
# 33990          856          202          213              63          683
# 33993          257          132           25               3           46
# 33999          333          193            8              22           74
# 34020         1549          521            7              55          221
# 35833          834           42           22              63          400
# 35862          841           39           24              63          115
# 36367         2435          582           10              11           35
#
#        time_termset  time_total  db
# 110               2        1067   1
# 123               2        1370   1
# 124               5        2162   1
# 131               1        1612   1
# 140               1         355   1
# 141               2       12720   1
# 144               1         251   1
# 146               2        1283   1
# 159               0         290   1
# 160               2        1440   1
# 167               2        8436   1
# 171               1         249   1
# 174               1         786   1
# 187               1         843   1
# 189               3        1338   1
# 196               1         170   1
# 201               2        1003   1
# 211               2        1105   1
# 212               9        2292   1
# 213               1        2729   1
# 221               1        1920   1
# 224               1          85   1
# 227               2         277   1
# 231               2        5851   1
# 232               2        2161   1
# 236               0         169   1
# 238               0         782   1
# 243               1         297   1
# 252               0         236   1
# 256               3       15138   1
# 260               1         162   1
# 261               1         135   1
# 272               0         221   1
# 274               1         143   1
# 279               2        2225   1
# 289               4         695   1
# 292               1        4848   1
# 293               1         127   1
# 314               1         168   1
# 328               1        5386   1
# 335               2        6848   1
# 337               1        1996   1
# 364               2        1857   1
# 367               1         392   1
# 368               1         105   1
# 376               0         422   1
# 394               0         148   1
# 396               0          56   1
# 397               3       34518   1
# 409               0         842   1
# ...             ...         ...  ..
# 33578             1         602   1
# 33584             1        1805   1
# 33600             0        6698   1
# 33604             0         243   1
# 33611             1         578   1
# 33624             4       20009   1
# 33641             0         249   1
# 33644             1         527   1
# 33645             0         131   1
# 33648             0         395   1
# 33651             3       19518   1
# 33655             1        1777   1
# 33656             3        3507   1
# 33664             1       15819   1
# 33674             1         243   1
# 33710             1         292   1
# 33718             1        3340   1
# 33727             1         604   1
# 33732             1       50853   1
# 33749             2        2059   1
# 33750             1       50067   1
# 33770             0         489   1
# 33800             2        1225   1
# 33812             1         317   1
# 33822             1        3323   1
# 33828             1       13711   1
# 33830             0        8483   1
# 33842             1        5344   1
# 33859             0       40077   1
# 33864             1       50521   1
# 33886             2        2154   1
# 33895             2        1429   1
# 33904             1         292   1
# 33908             1         381   1
# 33909             1         724   1
# 33918             0       14130   1
# 33920             1        4282   1
# 33925             1       16519   1
# 33933             0         266   1
# 33937             0         429   1
# 33946             0       19213   1
# 33960             0        4556   1
# 33980             0         265   1
# 33990             1        2796   1
# 33993             1         559   1
# 33999             1         822   1
# 34020             1        2663   1
# 35833             1        1411   3
# 35862             1        1128   3
# 36367             0        3186   3
#
# [2709 rows x 26 columns]

# %%
data['status'].value_counts()
# Out:
# cutintro_uncompressible     12519
# parsing_other_exception      9762
# ok                           4738
# cutintro_other_exception     4249
# parsing_timeout              1473
# maxsat_timeout               1404
# nfgrammar_timeout             830
# dtable_timeout                676
# prcons_timeout                501
# minform_timeout               392
# grammar_timeout               234
# minsol_timeout                232
# cutintro_ehs_unprovable       125
# cutintro_out_of_memory         93
# total_timeout                   6
# cutintro_stack_overflow         2
# cleanproof_timeout              1
# dtype: int64

# %%
# Different grammar sizes between different methods: one cut with one quantifier
data[(data.mingrammar >= 0) & ((data.method == 'one_cut_one_quant') | (data.method == 'many_cuts_one_quant_1'))] \
    .groupby('file') \
    .filter(lambda x: len(set(x.mingrammar)) > 1) \
    .sort('file')[['file', 'method', 'mingrammar']]
# Out:
#                                                     file  \
# 52                       SquareEdges2DimExampleProof(10)
# 12487                    SquareEdges2DimExampleProof(10)
# 53                       SquareEdges2DimExampleProof(11)
# 12488                    SquareEdges2DimExampleProof(11)
# 54                       SquareEdges2DimExampleProof(12)
# 12489                    SquareEdges2DimExampleProof(12)
# 55                       SquareEdges2DimExampleProof(13)
# 12490                    SquareEdges2DimExampleProof(13)
# 48                        SquareEdges2DimExampleProof(6)
# 12483                     SquareEdges2DimExampleProof(6)
# 49                        SquareEdges2DimExampleProof(7)
# 12484                     SquareEdges2DimExampleProof(7)
# 50                        SquareEdges2DimExampleProof(8)
# 12485                     SquareEdges2DimExampleProof(8)
# 51                        SquareEdges2DimExampleProof(9)
# 12486                     SquareEdges2DimExampleProof(9)
# 1308   testing/TSTP/prover9/ALG/ALG012-1/Prover9---11...
# 13795  testing/TSTP/prover9/ALG/ALG012-1/Prover9---11...
# 430    testing/TSTP/prover9/ALG/ALG074+1/Prover9---11...
# 12917  testing/TSTP/prover9/ALG/ALG074+1/Prover9---11...
# 2851   testing/TSTP/prover9/ALG/ALG210+1/Prover9---11...
# 15338  testing/TSTP/prover9/ALG/ALG210+1/Prover9---11...
# 2788   testing/TSTP/prover9/ALG/ALG210+2/Prover9---11...
# 15275  testing/TSTP/prover9/ALG/ALG210+2/Prover9---11...
# 1354   testing/TSTP/prover9/ALG/ALG245-1/Prover9---11...
# 13841  testing/TSTP/prover9/ALG/ALG245-1/Prover9---11...
# 2882   testing/TSTP/prover9/ALG/ALG437-1/Prover9---11...
# 15369  testing/TSTP/prover9/ALG/ALG437-1/Prover9---11...
# 2186   testing/TSTP/prover9/ANA/ANA022-2/Prover9---11...
# 14673  testing/TSTP/prover9/ANA/ANA022-2/Prover9---11...
# 1030   testing/TSTP/prover9/ANA/ANA026-2/Prover9---11...
# 13517  testing/TSTP/prover9/ANA/ANA026-2/Prover9---11...
# 968    testing/TSTP/prover9/ANA/ANA028-2/Prover9---11...
# 13455  testing/TSTP/prover9/ANA/ANA028-2/Prover9---11...
# 754    testing/TSTP/prover9/BOO/BOO003-2/Prover9---11...
# 13241  testing/TSTP/prover9/BOO/BOO003-2/Prover9---11...
# 174    testing/TSTP/prover9/BOO/BOO003-4/Prover9---11...
# 12661  testing/TSTP/prover9/BOO/BOO003-4/Prover9---11...
# 2483   testing/TSTP/prover9/BOO/BOO010-1/Prover9---11...
# 14970  testing/TSTP/prover9/BOO/BOO010-1/Prover9---11...
# 490    testing/TSTP/prover9/BOO/BOO011-4/Prover9---11...
# 12977  testing/TSTP/prover9/BOO/BOO011-4/Prover9---11...
# 2187   testing/TSTP/prover9/BOO/BOO012-2/Prover9---11...
# 14674  testing/TSTP/prover9/BOO/BOO012-2/Prover9---11...
# 2147   testing/TSTP/prover9/BOO/BOO016-1/Prover9---11...
# 14634  testing/TSTP/prover9/BOO/BOO016-1/Prover9---11...
# 1664   testing/TSTP/prover9/BOO/BOO018-4/Prover9---11...
# 14151  testing/TSTP/prover9/BOO/BOO018-4/Prover9---11...
# 2802   testing/TSTP/prover9/CAT/CAT005-1/Prover9---11...
# 15289  testing/TSTP/prover9/CAT/CAT005-1/Prover9---11...
# ...                                                  ...
# 1818   testing/TSTP/prover9/SWV/SWV731-1/Prover9---11...
# 14305  testing/TSTP/prover9/SWV/SWV731-1/Prover9---11...
# 1897   testing/TSTP/prover9/SWV/SWV742-1/Prover9---11...
# 14384  testing/TSTP/prover9/SWV/SWV742-1/Prover9---11...
# 1145   testing/TSTP/prover9/SWV/SWV743-1/Prover9---11...
# 13632  testing/TSTP/prover9/SWV/SWV743-1/Prover9---11...
# 2846   testing/TSTP/prover9/SWV/SWV751-1/Prover9---11...
# 15333  testing/TSTP/prover9/SWV/SWV751-1/Prover9---11...
# 639    testing/TSTP/prover9/SWV/SWV752-1/Prover9---11...
# 13126  testing/TSTP/prover9/SWV/SWV752-1/Prover9---11...
# 778    testing/TSTP/prover9/SWV/SWV753-1/Prover9---11...
# 13265  testing/TSTP/prover9/SWV/SWV753-1/Prover9---11...
# 443    testing/TSTP/prover9/SWV/SWV757-1/Prover9---11...
# 12930  testing/TSTP/prover9/SWV/SWV757-1/Prover9---11...
# 2927   testing/TSTP/prover9/SWW/SWW101+1/Prover9---11...
# 15414  testing/TSTP/prover9/SWW/SWW101+1/Prover9---11...
# 1684   testing/TSTP/prover9/SWW/SWW198+1/Prover9---11...
# 14171  testing/TSTP/prover9/SWW/SWW198+1/Prover9---11...
# 2190   testing/TSTP/prover9/SYN/SYN059+1/Prover9---11...
# 14677  testing/TSTP/prover9/SYN/SYN059+1/Prover9---11...
# 2923   testing/TSTP/prover9/SYN/SYN159-1/Prover9---11...
# 15410  testing/TSTP/prover9/SYN/SYN159-1/Prover9---11...
# 2435   testing/TSTP/prover9/SYN/SYN163-1/Prover9---11...
# 14922  testing/TSTP/prover9/SYN/SYN163-1/Prover9---11...
# 1166   testing/TSTP/prover9/SYN/SYN180-1/Prover9---11...
# 13653  testing/TSTP/prover9/SYN/SYN180-1/Prover9---11...
# 1637   testing/TSTP/prover9/SYN/SYN577-1/Prover9---11...
# 14124  testing/TSTP/prover9/SYN/SYN577-1/Prover9---11...
# 1985   testing/TSTP/prover9/SYN/SYN726+1/Prover9---11...
# 14472  testing/TSTP/prover9/SYN/SYN726+1/Prover9---11...
# 1435   testing/TSTP/prover9/SYN/SYN726-1/Prover9---11...
# 13922  testing/TSTP/prover9/SYN/SYN726-1/Prover9---11...
# 2705   testing/TSTP/prover9/SYN/SYN918+1/Prover9---11...
# 15192  testing/TSTP/prover9/SYN/SYN918+1/Prover9---11...
# 6195   testing/veriT-SMT-LIB/QF_UF/QG-classification/...
# 18682  testing/veriT-SMT-LIB/QF_UF/QG-classification/...
# 6197   testing/veriT-SMT-LIB/QF_UF/QG-classification/...
# 18684  testing/veriT-SMT-LIB/QF_UF/QG-classification/...
# 6192   testing/veriT-SMT-LIB/QF_UF/QG-classification/...
# 18679  testing/veriT-SMT-LIB/QF_UF/QG-classification/...
# 6072   testing/veriT-SMT-LIB/QF_UF/SEQ/SEQ011_size2.s...
# 18559  testing/veriT-SMT-LIB/QF_UF/SEQ/SEQ011_size2.s...
# 6060   testing/veriT-SMT-LIB/QF_UF/eq_diamond/eq_diam...
# 18547  testing/veriT-SMT-LIB/QF_UF/eq_diamond/eq_diam...
# 6058   testing/veriT-SMT-LIB/QF_UF/eq_diamond/eq_diam...
# 18545  testing/veriT-SMT-LIB/QF_UF/eq_diamond/eq_diam...
# 6062   testing/veriT-SMT-LIB/QF_UF/eq_diamond/eq_diam...
# 18549  testing/veriT-SMT-LIB/QF_UF/eq_diamond/eq_diam...
# 6059   testing/veriT-SMT-LIB/QF_UF/eq_diamond/eq_diam...
# 18546  testing/veriT-SMT-LIB/QF_UF/eq_diamond/eq_diam...
#
#                       method  mingrammar
# 52         one_cut_one_quant          19
# 12487  many_cuts_one_quant_1          16
# 53         one_cut_one_quant          20
# 12488  many_cuts_one_quant_1          16
# 54         one_cut_one_quant          21
# 12489  many_cuts_one_quant_1          16
# 55         one_cut_one_quant          23
# 12490  many_cuts_one_quant_1          18
# 48         one_cut_one_quant          13
# 12483  many_cuts_one_quant_1          12
# 49         one_cut_one_quant          15
# 12484  many_cuts_one_quant_1          14
# 50         one_cut_one_quant          16
# 12485  many_cuts_one_quant_1          14
# 51         one_cut_one_quant          17
# 12486  many_cuts_one_quant_1          14
# 1308       one_cut_one_quant          41
# 13795  many_cuts_one_quant_1          28
# 430        one_cut_one_quant          17
# 12917  many_cuts_one_quant_1          16
# 2851       one_cut_one_quant          33
# 15338  many_cuts_one_quant_1          31
# 2788       one_cut_one_quant          34
# 15275  many_cuts_one_quant_1          32
# 1354       one_cut_one_quant          17
# 13841  many_cuts_one_quant_1          16
# 2882       one_cut_one_quant          36
# 15369  many_cuts_one_quant_1          34
# 2186       one_cut_one_quant          72
# 14673  many_cuts_one_quant_1          67
# 1030       one_cut_one_quant          93
# 13517  many_cuts_one_quant_1          83
# 968        one_cut_one_quant          49
# 13455  many_cuts_one_quant_1          43
# 754        one_cut_one_quant          24
# 13241  many_cuts_one_quant_1          21
# 174        one_cut_one_quant          13
# 12661  many_cuts_one_quant_1          12
# 2483       one_cut_one_quant          27
# 14970  many_cuts_one_quant_1          25
# 490        one_cut_one_quant          28
# 12977  many_cuts_one_quant_1          25
# 2187       one_cut_one_quant          20
# 14674  many_cuts_one_quant_1          19
# 2147       one_cut_one_quant          27
# 14634  many_cuts_one_quant_1          25
# 1664       one_cut_one_quant          31
# 14151  many_cuts_one_quant_1          24
# 2802       one_cut_one_quant          15
# 15289  many_cuts_one_quant_1          14
# ...                      ...         ...
# 1818       one_cut_one_quant          23
# 14305  many_cuts_one_quant_1          21
# 1897       one_cut_one_quant          34
# 14384  many_cuts_one_quant_1          32
# 1145       one_cut_one_quant          34
# 13632  many_cuts_one_quant_1          32
# 2846       one_cut_one_quant          33
# 15333  many_cuts_one_quant_1          29
# 639        one_cut_one_quant          28
# 13126  many_cuts_one_quant_1          26
# 778        one_cut_one_quant          28
# 13265  many_cuts_one_quant_1          26
# 443        one_cut_one_quant          33
# 12930  many_cuts_one_quant_1          31
# 2927       one_cut_one_quant          27
# 15414  many_cuts_one_quant_1          26
# 1684       one_cut_one_quant          21
# 14171  many_cuts_one_quant_1          20
# 2190       one_cut_one_quant          21
# 14677  many_cuts_one_quant_1          20
# 2923       one_cut_one_quant          55
# 15410  many_cuts_one_quant_1          49
# 2435       one_cut_one_quant          59
# 14922  many_cuts_one_quant_1          55
# 1166       one_cut_one_quant          35
# 13653  many_cuts_one_quant_1          34
# 1637       one_cut_one_quant          18
# 14124  many_cuts_one_quant_1          17
# 1985       one_cut_one_quant          14
# 14472  many_cuts_one_quant_1          13
# 1435       one_cut_one_quant          14
# 13922  many_cuts_one_quant_1          13
# 2705       one_cut_one_quant          10
# 15192  many_cuts_one_quant_1           9
# 6195       one_cut_one_quant          76
# 18682  many_cuts_one_quant_1          45
# 6197       one_cut_one_quant          76
# 18684  many_cuts_one_quant_1          45
# 6192       one_cut_one_quant          76
# 18679  many_cuts_one_quant_1          45
# 6072       one_cut_one_quant          21
# 18559  many_cuts_one_quant_1          20
# 6060       one_cut_one_quant          16
# 18547  many_cuts_one_quant_1          15
# 6058       one_cut_one_quant          25
# 18545  many_cuts_one_quant_1          24
# 6062       one_cut_one_quant          42
# 18549  many_cuts_one_quant_1          37
# 6059       one_cut_one_quant          58
# 18546  many_cuts_one_quant_1          51
#
# [578 rows x 3 columns]

# %%
# Different grammar sizes between different methods: one cut with 2/many quantifiers
data[(data.mingrammar >= 0) & ((data.method == 'one_cut_many_quant') | (data.method == 'many_cuts_many_quant_2'))] \
    .groupby('file') \
    .filter(lambda x: len(set(x.mingrammar)) > 1) \
    .sort('file')[['file', 'method', 'mingrammar']]
# Out:
#                                                     file  \
# 6294            FactorialFunctionEqualityExampleProof(3)
# 25001           FactorialFunctionEqualityExampleProof(3)
# 6295            FactorialFunctionEqualityExampleProof(4)
# 25002           FactorialFunctionEqualityExampleProof(4)
# 6244                      SquareEdges2DimExampleProof(4)
# 24955                     SquareEdges2DimExampleProof(4)
# 6245                      SquareEdges2DimExampleProof(5)
# 24956                     SquareEdges2DimExampleProof(5)
# 6246                      SquareEdges2DimExampleProof(6)
# 24957                     SquareEdges2DimExampleProof(6)
# 6247                      SquareEdges2DimExampleProof(7)
# 24958                     SquareEdges2DimExampleProof(7)
# 6248                      SquareEdges2DimExampleProof(8)
# 24959                     SquareEdges2DimExampleProof(8)
# 6249                      SquareEdges2DimExampleProof(9)
# 24960                     SquareEdges2DimExampleProof(9)
# 6283                            SumOfOnesExampleProof(3)
# 24990                           SumOfOnesExampleProof(3)
# 6284                            SumOfOnesExampleProof(4)
# 24991                           SumOfOnesExampleProof(4)
# 6285                            SumOfOnesExampleProof(5)
# 24992                           SumOfOnesExampleProof(5)
# 6286                            SumOfOnesExampleProof(6)
# 24993                           SumOfOnesExampleProof(6)
# 6288                UniformAssociativity3ExampleProof(1)
# 24996               UniformAssociativity3ExampleProof(1)
# 6289                UniformAssociativity3ExampleProof(2)
# 24997               UniformAssociativity3ExampleProof(2)
# 7452   testing/TSTP/prover9/ALG/ALG002-1/Prover9---11...
# 26159  testing/TSTP/prover9/ALG/ALG002-1/Prover9---11...
# 6718   testing/TSTP/prover9/ALG/ALG029+1/Prover9---11...
# 25425  testing/TSTP/prover9/ALG/ALG029+1/Prover9---11...
# 6995   testing/TSTP/prover9/ALG/ALG030+1/Prover9---11...
# 25702  testing/TSTP/prover9/ALG/ALG030+1/Prover9---11...
# 6623   testing/TSTP/prover9/ALG/ALG074+1/Prover9---11...
# 25330  testing/TSTP/prover9/ALG/ALG074+1/Prover9---11...
# 7579   testing/TSTP/prover9/ALG/ALG178+1/Prover9---11...
# 26286  testing/TSTP/prover9/ALG/ALG178+1/Prover9---11...
# 6389   testing/TSTP/prover9/ALG/ALG179+1/Prover9---11...
# 25096  testing/TSTP/prover9/ALG/ALG179+1/Prover9---11...
# 7396   testing/TSTP/prover9/ALG/ALG222+1/Prover9---11...
# 26103  testing/TSTP/prover9/ALG/ALG222+1/Prover9---11...
# 7547   testing/TSTP/prover9/ALG/ALG245-1/Prover9---11...
# 26254  testing/TSTP/prover9/ALG/ALG245-1/Prover9---11...
# 9075   testing/TSTP/prover9/ALG/ALG437-1/Prover9---11...
# 27782  testing/TSTP/prover9/ALG/ALG437-1/Prover9---11...
# 9097   testing/TSTP/prover9/ANA/ANA002-2/Prover9---11...
# 27804  testing/TSTP/prover9/ANA/ANA002-2/Prover9---11...
# 6734   testing/TSTP/prover9/ANA/ANA002-4/Prover9---11...
# 25441  testing/TSTP/prover9/ANA/ANA002-4/Prover9---11...
# ...                                                  ...
# 8628   testing/TSTP/prover9/SYN/SYN163-1/Prover9---11...
# 27335  testing/TSTP/prover9/SYN/SYN163-1/Prover9---11...
# 6619   testing/TSTP/prover9/SYN/SYN171-1/Prover9---11...
# 25326  testing/TSTP/prover9/SYN/SYN171-1/Prover9---11...
# 7359   testing/TSTP/prover9/SYN/SYN180-1/Prover9---11...
# 26066  testing/TSTP/prover9/SYN/SYN180-1/Prover9---11...
# 7133   testing/TSTP/prover9/SYN/SYN181-1/Prover9---11...
# 25840  testing/TSTP/prover9/SYN/SYN181-1/Prover9---11...
# 9205   testing/TSTP/prover9/SYN/SYN190-1/Prover9---11...
# 27912  testing/TSTP/prover9/SYN/SYN190-1/Prover9---11...
# 8144   testing/TSTP/prover9/SYN/SYN269-1/Prover9---11...
# 26851  testing/TSTP/prover9/SYN/SYN269-1/Prover9---11...
# 7556   testing/TSTP/prover9/SYN/SYN312-1/Prover9---11...
# 26263  testing/TSTP/prover9/SYN/SYN312-1/Prover9---11...
# 8842   testing/TSTP/prover9/SYN/SYN332+1/Prover9---11...
# 27549  testing/TSTP/prover9/SYN/SYN332+1/Prover9---11...
# 7291   testing/TSTP/prover9/SYN/SYN332-1/Prover9---11...
# 25998  testing/TSTP/prover9/SYN/SYN332-1/Prover9---11...
# 7621   testing/TSTP/prover9/SYN/SYN333+1/Prover9---11...
# 26328  testing/TSTP/prover9/SYN/SYN333+1/Prover9---11...
# 8510   testing/TSTP/prover9/SYN/SYN333-1/Prover9---11...
# 27217  testing/TSTP/prover9/SYN/SYN333-1/Prover9---11...
# 7830   testing/TSTP/prover9/SYN/SYN577-1/Prover9---11...
# 26537  testing/TSTP/prover9/SYN/SYN577-1/Prover9---11...
# 6904   testing/TSTP/prover9/SYN/SYN604-1/Prover9---11...
# 25611  testing/TSTP/prover9/SYN/SYN604-1/Prover9---11...
# 7150   testing/TSTP/prover9/SYN/SYN618-1/Prover9---11...
# 25857  testing/TSTP/prover9/SYN/SYN618-1/Prover9---11...
# 8224   testing/TSTP/prover9/SYN/SYN694-1/Prover9---11...
# 26931  testing/TSTP/prover9/SYN/SYN694-1/Prover9---11...
# 6508   testing/TSTP/prover9/SYN/SYN695-1/Prover9---11...
# 25215  testing/TSTP/prover9/SYN/SYN695-1/Prover9---11...
# 8476   testing/TSTP/prover9/SYN/SYN722+1/Prover9---11...
# 27183  testing/TSTP/prover9/SYN/SYN722+1/Prover9---11...
# 8178   testing/TSTP/prover9/SYN/SYN726+1/Prover9---11...
# 26885  testing/TSTP/prover9/SYN/SYN726+1/Prover9---11...
# 7628   testing/TSTP/prover9/SYN/SYN726-1/Prover9---11...
# 26335  testing/TSTP/prover9/SYN/SYN726-1/Prover9---11...
# 7937   testing/TSTP/prover9/SYN/SYN728-1/Prover9---11...
# 26644  testing/TSTP/prover9/SYN/SYN728-1/Prover9---11...
# 8898   testing/TSTP/prover9/SYN/SYN918+1/Prover9---11...
# 27605  testing/TSTP/prover9/SYN/SYN918+1/Prover9---11...
# 12265  testing/veriT-SMT-LIB/QF_UF/SEQ/SEQ011_size2.s...
# 30972  testing/veriT-SMT-LIB/QF_UF/SEQ/SEQ011_size2.s...
# 12250  testing/veriT-SMT-LIB/QF_UF/eq_diamond/eq_diam...
# 30957  testing/veriT-SMT-LIB/QF_UF/eq_diamond/eq_diam...
# 12253  testing/veriT-SMT-LIB/QF_UF/eq_diamond/eq_diam...
# 30960  testing/veriT-SMT-LIB/QF_UF/eq_diamond/eq_diam...
# 12251  testing/veriT-SMT-LIB/QF_UF/eq_diamond/eq_diam...
# 30958  testing/veriT-SMT-LIB/QF_UF/eq_diamond/eq_diam...
#
#                        method  mingrammar
# 6294       one_cut_many_quant          31
# 25001  many_cuts_many_quant_2          26
# 6295       one_cut_many_quant          36
# 25002  many_cuts_many_quant_2          27
# 6244       one_cut_many_quant          10
# 24955  many_cuts_many_quant_2           8
# 6245       one_cut_many_quant          12
# 24956  many_cuts_many_quant_2           9
# 6246       one_cut_many_quant          13
# 24957  many_cuts_many_quant_2           9
# 6247       one_cut_many_quant          15
# 24958  many_cuts_many_quant_2          10
# 6248       one_cut_many_quant          16
# 24959  many_cuts_many_quant_2          10
# 6249       one_cut_many_quant          17
# 24960  many_cuts_many_quant_2          11
# 6283       one_cut_many_quant          12
# 24990  many_cuts_many_quant_2          10
# 6284       one_cut_many_quant          15
# 24991  many_cuts_many_quant_2          11
# 6285       one_cut_many_quant          18
# 24992  many_cuts_many_quant_2          12
# 6286       one_cut_many_quant          21
# 24993  many_cuts_many_quant_2          13
# 6288       one_cut_many_quant          16
# 24996  many_cuts_many_quant_2          15
# 6289       one_cut_many_quant          18
# 24997  many_cuts_many_quant_2          16
# 7452       one_cut_many_quant          24
# 26159  many_cuts_many_quant_2          22
# 6718       one_cut_many_quant          12
# 25425  many_cuts_many_quant_2          10
# 6995       one_cut_many_quant          12
# 25702  many_cuts_many_quant_2          10
# 6623       one_cut_many_quant          16
# 25330  many_cuts_many_quant_2          15
# 7579       one_cut_many_quant          12
# 26286  many_cuts_many_quant_2          11
# 6389       one_cut_many_quant          12
# 25096  many_cuts_many_quant_2          11
# 7396       one_cut_many_quant          37
# 26103  many_cuts_many_quant_2          35
# 7547       one_cut_many_quant          17
# 26254  many_cuts_many_quant_2          14
# 9075       one_cut_many_quant          36
# 27782  many_cuts_many_quant_2          33
# 9097       one_cut_many_quant          31
# 27804  many_cuts_many_quant_2          28
# 6734       one_cut_many_quant          29
# 25441  many_cuts_many_quant_2          26
# ...                       ...         ...
# 8628       one_cut_many_quant          59
# 27335  many_cuts_many_quant_2          53
# 6619       one_cut_many_quant          25
# 25326  many_cuts_many_quant_2          24
# 7359       one_cut_many_quant          35
# 26066  many_cuts_many_quant_2          32
# 7133       one_cut_many_quant          23
# 25840  many_cuts_many_quant_2          22
# 9205       one_cut_many_quant          22
# 27912  many_cuts_many_quant_2          21
# 8144       one_cut_many_quant          25
# 26851  many_cuts_many_quant_2          24
# 7556       one_cut_many_quant          15
# 26263  many_cuts_many_quant_2          14
# 8842       one_cut_many_quant          11
# 27549  many_cuts_many_quant_2          10
# 7291       one_cut_many_quant          11
# 25998  many_cuts_many_quant_2          10
# 7621       one_cut_many_quant           8
# 26328  many_cuts_many_quant_2           7
# 8510       one_cut_many_quant           8
# 27217  many_cuts_many_quant_2           7
# 7830       one_cut_many_quant          18
# 26537  many_cuts_many_quant_2          15
# 6904       one_cut_many_quant          21
# 25611  many_cuts_many_quant_2          19
# 7150       one_cut_many_quant          14
# 25857  many_cuts_many_quant_2          13
# 8224       one_cut_many_quant          19
# 26931  many_cuts_many_quant_2          18
# 6508       one_cut_many_quant          19
# 25215  many_cuts_many_quant_2          18
# 8476       one_cut_many_quant           8
# 27183  many_cuts_many_quant_2           7
# 8178       one_cut_many_quant          14
# 26885  many_cuts_many_quant_2          12
# 7628       one_cut_many_quant          14
# 26335  many_cuts_many_quant_2          12
# 7937       one_cut_many_quant          10
# 26644  many_cuts_many_quant_2           9
# 8898       one_cut_many_quant          10
# 27605  many_cuts_many_quant_2           9
# 12265      one_cut_many_quant          21
# 30972  many_cuts_many_quant_2          18
# 12250      one_cut_many_quant          10
# 30957  many_cuts_many_quant_2           8
# 12253      one_cut_many_quant          16
# 30960  many_cuts_many_quant_2          12
# 12251      one_cut_many_quant          25
# 30958  many_cuts_many_quant_2          18
#
# [1076 rows x 3 columns]

# %%
data['is_ok'] = data.status=='ok'
data['is_uncompressible'] = data.status.str.endswith('uncompressible')
data['is_timeout'] = data.status.str.endswith('timeout')
data['is_error'] = ~data.is_ok & ~data.is_uncompressible & ~data.is_timeout

data[(data.termset<65)&(data.db==1)].groupby('termset').mean() \
    [['is_uncompressible', 'is_ok', 'is_timeout', 'is_error']] \
    .plot(kind='area', figsize=(16,12), ylim=(0,1), title='Status by termset size (prover9)',
          color=['yellow', 'green', 'royalblue', 'tomato'])

# %%
# Proofs with good compression
data[data.inf_output < 0.1*data.inf_input]
# Out:
#        can_sol  cuts_in                                               file  \
# 627         16        1  testing/TSTP/prover9/SET/SET788+1/Prover9---11...
# 834         16        1  testing/TSTP/prover9/SET/SET047-5/Prover9---11...
# 900          4        8  testing/TSTP/prover9/SWW/SWW474+1/Prover9---11...
# 1157        16        1  testing/TSTP/prover9/SET/SET047+1/Prover9---11...
# 2947        28       39  testing/TSTP/prover9/SET/SET887+1/Prover9---11...
# 6652         8        4  testing/TSTP/prover9/SCT/SCT080-1/Prover9---11...
# 6683         9        1  testing/TSTP/prover9/BOO/BOO011-4/Prover9---11...
# 7093         4        8  testing/TSTP/prover9/SWW/SWW474+1/Prover9---11...
# 9140        28       39  testing/TSTP/prover9/SET/SET887+1/Prover9---11...
# 13387        8       12  testing/TSTP/prover9/SWW/SWW474+1/Prover9---11...
# 19178       10        4  testing/TSTP/prover9/SCT/SCT080-1/Prover9---11...
# 26117       12       26  testing/TSTP/prover9/SWV/SWV460+1/Prover9---11...
#
#        inf_input  inf_output                  method  min_sol  minform_lcomp  \
# 627         4629         360       one_cut_one_quant       16            NaN
# 834         4629         428       one_cut_one_quant       16            NaN
# 900          845          56       one_cut_one_quant        2            NaN
# 1157        4629         360       one_cut_one_quant       16            NaN
# 2947        2671         202       one_cut_one_quant       26            NaN
# 6652         292          24      one_cut_many_quant        4            NaN
# 6683         271          14      one_cut_many_quant        5            NaN
# 7093         845          56      one_cut_many_quant        2            NaN
# 9140        2671         202      one_cut_many_quant       26            NaN
# 13387        845          78   many_cuts_one_quant_1        6            834
# 19178        292          24   many_cuts_one_quant_2       10           3196
# 26117       2137         130  many_cuts_many_quant_2       12           1087
#
#        mingrammar  nfgrammar    ...     time_minsol  time_nfgrammar  \
# 627            12        NaN    ...              11             NaN
# 834            12        NaN    ...              11             NaN
# 900            34        NaN    ...              66             NaN
# 1157           12        NaN    ...              11             NaN
# 2947           31        NaN    ...             179             NaN
# 6652           23        NaN    ...             500             NaN
# 6683           26        NaN    ...              32             NaN
# 7093           34        NaN    ...              69             NaN
# 9140           31        NaN    ...             233             NaN
# 13387          34         94    ...             150               4
# 19178          23        144    ...               2              51
# 26117          24        319    ...               8               5
#
#        time_prcons time_termset  time_total  db  is_ok  is_uncompressible  \
# 627             25            1        1423   1   True              False
# 834             34            0        1528   1   True              False
# 900            136            2        1828   1   True              False
# 1157            47            1        1447   1   True              False
# 2947            94            1        2808   1   True              False
# 6652           128            2         863   1   True              False
# 6683            76            1         348   1   True              False
# 7093           131            2        1861   1   True              False
# 9140            93            2        2822   1   True              False
# 13387          105            2        1968   1   True              False
# 19178          315            4         817   1   True              False
# 26117           73            1        4391   1   True              False
#
#        is_timeout  is_error
# 627         False     False
# 834         False     False
# 900         False     False
# 1157        False     False
# 2947        False     False
# 6652        False     False
# 6683        False     False
# 7093        False     False
# 9140        False     False
# 13387       False     False
# 19178       False     False
# 26117       False     False
#
# [12 rows x 30 columns]

# %%
# Proofs with blowup
data[data.inf_output > 1000*data.inf_input]
# Out:
#        can_sol  cuts_in                                               file  \
# 18744       16        2                        SquareEdgesExampleProof(12)
# 18749       16        2                        SquareEdgesExampleProof(17)
# 32474       30        2  testing/TSTP/prover9/SYN/SYN726-1/Prover9---11...
#
#        inf_input  inf_output                    method  min_sol  \
# 18744         83      196985     many_cuts_one_quant_2       16
# 18749        118      197026     many_cuts_one_quant_2       16
# 32474        115      214688  many_cuts_many_quant_2_2       30
#
#        minform_lcomp  mingrammar  nfgrammar    ...     time_minsol  \
# 18744          19331          11        108    ...               0
# 18749          52261          12        153    ...               0
# 32474          13375          12        148    ...               0
#
#        time_nfgrammar  time_prcons time_termset  time_total  db  is_ok  \
# 18744              27        20715            1       24252   0   True
# 18749              87        25856            1       34743   0   True
# 32474              19        22102            1       29061   1   True
#
#        is_uncompressible  is_timeout  is_error
# 18744              False       False     False
# 18749              False       False     False
# 32474              False       False     False
#
# [3 rows x 30 columns]

# %%
# Proofs with an interesting number of cuts
data[data.cuts_in > 5000]
# Out:
#        can_sol  cuts_in                                               file  \
# 13323       41     5681  testing/TSTP/prover9/CAT/CAT009-1/Prover9---11...
# 26499       32     5204  testing/TSTP/prover9/GEO/GEO009-3/Prover9---11...
# 27593       26     7109  testing/TSTP/prover9/LAT/LAT302+1/Prover9---11...
# 32392       13     9592  testing/TSTP/prover9/CAT/CAT014-3/Prover9---11...
# 33361       26     7101  testing/TSTP/prover9/LAT/LAT303+1/Prover9---11...
# 33732       26     7109  testing/TSTP/prover9/LAT/LAT302+1/Prover9---11...
#
#        inf_input  inf_output                    method  min_sol  \
# 13323        318       33906     many_cuts_one_quant_1       41
# 26499        119       45568    many_cuts_many_quant_2       32
# 27593        235       72794    many_cuts_many_quant_2       26
# 32392        181       86033  many_cuts_many_quant_2_2       13
# 33361        268       72758  many_cuts_many_quant_2_2       26
# 33732        235       72794  many_cuts_many_quant_2_2       26
#
#        minform_lcomp  mingrammar  nfgrammar    ...     time_minsol  \
# 13323            715          22         52    ...              28
# 26499           3074          14         88    ...              11
# 27593           1223          22         98    ...              11
# 32392          22946          11        277    ...               1
# 33361           5256          21        179    ...              11
# 33732           6279          22        304    ...              11
#
#        time_nfgrammar  time_prcons time_termset  time_total  db  is_ok  \
# 13323               3        38450            2       39035   1   True
# 26499               3        27613            0       28155   1   True
# 27593               5        48530            1       49855   1   True
# 32392               8        40511            1       43195   1   True
# 33361             101        50189            1       51777   1   True
# 33732             133        49203            1       50853   1   True
#
#        is_uncompressible  is_timeout  is_error
# 13323              False       False     False
# 26499              False       False     False
# 27593              False       False     False
# 32392              False       False     False
# 33361              False       False     False
# 33732              False       False     False
#
# [6 rows x 30 columns]

# %%
ax = (data.time_maxsat/data.time_grammar).dropna().plot(kind='hist', figsize=(14,8),
    title='Percentage of grammar finding time spent in MaxSAT solver', bins=20)
ax.set_xlabel('percentage')
ax.set_ylabel('number of testcases')
