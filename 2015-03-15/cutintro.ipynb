# %%
# %matplotlib inline
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.colors as colors
import matplotlib.patches as mpatches

pd.options.display.max_rows = 1000

# %%
def getData (filename):
    data = pd.read_csv(filename, names=['method', 'file', 'status', 'inf_input', 'quant_input', 'cuts_in', 'inf_output', 
                                        'quant_output', 'termset', 'mingrammar', 'num_mingrammars', 'can_sol', 'min_sol', 
                                        'time_termset', 'time_dtable', 'time_grammar', 'time_minsol', 'time_proof', 
                                        'time_cleanproof'])
    data = data.replace(" ", -1)
    data = data.replace(-1, np.nan)
    data = data.replace('-1', np.nan)
    
    # Setting the correct datatypes
    columns = set(data.keys())
    integer_columns = [c for c in columns if c not in ['method', 'file', 'status']]
    for c in integer_columns:
        data[c] = data[c].astype(np.float)   
    data['method'] = data['method'].astype(str)
    data['file'] = data['file'].astype(str)
    data['status'] = data['status'].astype(str)
    
    # Adding a column for the database
    def getDB (s):
        if 'ExampleProof' in s:
            return 0
        elif 'testing/TSTP' in s:
            return 1
        elif 'testing/veriT' in s:
            return 2
        else:
            return -1
    data['db'] = data.file.apply(getDB)
    
    return data

# %%
filename = "CutIntroDataLog.txt"
data = getData(filename)

# %%
# Other exceptions (aka bugs to hunt)

data_other_exp = data[data.status == 'cutintro_other_exception']
print(data_other_exp.shape)
data_other_exp[['method', 'file', 'status']]
# Out:
# (10, 20)
#                       method  \
# 2156       one_cut_one_quant
# 2477       one_cut_one_quant
# 5386      one_cut_many_quant
# 6443   many_cuts_one_quant_1
# 6626   many_cuts_one_quant_1
# 7894   many_cuts_one_quant_1
# 8328   many_cuts_one_quant_1
# 9535   many_cuts_one_quant_2
# 10803  many_cuts_one_quant_2
# 11237  many_cuts_one_quant_2
#
#                                                     file  \
# 2156   testing/TSTP/prover9/SEU/SEU169+2/Prover9---11...
# 2477   testing/TSTP/prover9/SEU/SEU153+2/Prover9---11...
# 5386   testing/TSTP/prover9/SEU/SEU153+2/Prover9---11...
# 6443   testing/TSTP/prover9/SCT/SCT080-1/Prover9---11...
# 6626   testing/TSTP/prover9/SEU/SEU149+2/Prover9---11...
# 7894   testing/TSTP/prover9/SET/SET173+3/Prover9---11...
# 8328   testing/TSTP/prover9/SCT/SCT031-1/Prover9---11...
# 9535   testing/TSTP/prover9/SEU/SEU149+2/Prover9---11...
# 10803  testing/TSTP/prover9/SET/SET173+3/Prover9---11...
# 11237  testing/TSTP/prover9/SCT/SCT031-1/Prover9---11...
#
#                          status
# 2156   cutintro_other_exception
# 2477   cutintro_other_exception
# 5386   cutintro_other_exception
# 6443   cutintro_other_exception
# 6626   cutintro_other_exception
# 7894   cutintro_other_exception
# 8328   cutintro_other_exception
# 9535   cutintro_other_exception
# 10803  cutintro_other_exception
# 11237  cutintro_other_exception

# %%
# Test that are ok in one_cut_one_quantifier and fail for many_cuts_one_quantifier_1

data_ocoq = data[data.method == 'one_cut_one_quant']
data_mcoq1 = data[data.method == 'many_cuts_one_quant_1']

merged = pd.merge(data_ocoq, data_mcoq1, on=['file'], suffixes=('_ocoq', '_mcoq1'))

diff = merged[(merged.status_ocoq == 'ok') & (merged.status_mcoq1 != 'ok')]
print(diff.shape)
diff[['file','status_ocoq', 'status_mcoq1']]
# Out:
# (246, 39)
#                                                    file status_ocoq  \
# 14                        SquareDiagonalExampleProof(2)          ok
# 22                       SquareDiagonalExampleProof(10)          ok
# 36                       SquareEdges2DimExampleProof(6)          ok
# 51                           SumOfOnesF2ExampleProof(4)          ok
# 55                            SumOfOnesFExampleProof(4)          ok
# 57                             SumOfOnesExampleProof(2)          ok
# 59                             SumOfOnesExampleProof(4)          ok
# 67    testing/TSTP/prover9/SWV/SWV480+1/Prover9---11...          ok
# 80    testing/TSTP/prover9/SWV/SWV466+1/Prover9---11...          ok
# 81    testing/TSTP/prover9/GEO/GEO070-3/Prover9---11...          ok
# 103   testing/TSTP/prover9/MGT/MGT055-1/Prover9---11...          ok
# 123   testing/TSTP/prover9/SET/SET927+1/Prover9---11...          ok
# 128   testing/TSTP/prover9/SET/SET017-7/Prover9---11...          ok
# 146   testing/TSTP/prover9/SEU/SEU291+2/Prover9---11...          ok
# 158   testing/TSTP/prover9/KLE/KLE010+1/Prover9---11...          ok
# 168   testing/TSTP/prover9/SWV/SWV478+1/Prover9---11...          ok
# 169   testing/TSTP/prover9/SET/SET246-6/Prover9---11...          ok
# 170   testing/TSTP/prover9/RNG/RNG019-7/Prover9---11...          ok
# 188   testing/TSTP/prover9/LCL/LCL196-3/Prover9---11...          ok
# 218   testing/TSTP/prover9/SWV/SWV911-1/Prover9---11...          ok
# 243   testing/TSTP/prover9/SYN/SYN084+1/Prover9---11...          ok
# 249   testing/TSTP/prover9/COL/COL006-2/Prover9---11...          ok
# 265   testing/TSTP/prover9/PLA/PLA002-1/Prover9---11...          ok
# 292   testing/TSTP/prover9/LCL/LCL241-3/Prover9---11...          ok
# 296   testing/TSTP/prover9/SET/SET669+3/Prover9---11...          ok
# 320   testing/TSTP/prover9/GEO/GEO266+3/Prover9---11...          ok
# 321   testing/TSTP/prover9/COM/COM008+2/Prover9---11...          ok
# 330   testing/TSTP/prover9/GEO/GEO187+2/Prover9---11...          ok
# 353   testing/TSTP/prover9/LCL/LCL756-1/Prover9---11...          ok
# 367   testing/TSTP/prover9/PRO/PRO009+1/Prover9---11...          ok
# 382   testing/TSTP/prover9/SWV/SWV841-1/Prover9---11...          ok
# 385   testing/TSTP/prover9/GEO/GEO213+2/Prover9---11...          ok
# 397   testing/TSTP/prover9/LAT/LAT032-1/Prover9---11...          ok
# 399   testing/TSTP/prover9/GRP/GRP647+1/Prover9---11...          ok
# 415   testing/TSTP/prover9/GRA/GRA008+2/Prover9---11...          ok
# 416   testing/TSTP/prover9/SCT/SCT080-1/Prover9---11...          ok
# 427   testing/TSTP/prover9/PRO/PRO014+1/Prover9---11...          ok
# 443   testing/TSTP/prover9/MGT/MGT064-1/Prover9---11...          ok
# 472   testing/TSTP/prover9/FLD/FLD002-3/Prover9---11...          ok
# 481   testing/TSTP/prover9/NUM/NUM016-2/Prover9---11...          ok
# 491   testing/TSTP/prover9/FLD/FLD001-3/Prover9---11...          ok
# 509   testing/TSTP/prover9/BOO/BOO005-1/Prover9---11...          ok
# 533   testing/TSTP/prover9/GRP/GRP166-2/Prover9---11...          ok
# 534   testing/TSTP/prover9/GRP/GRP496-1/Prover9---11...          ok
# 550   testing/TSTP/prover9/LCL/LCL202-3/Prover9---11...          ok
# 553   testing/TSTP/prover9/SYN/SYN613-1/Prover9---11...          ok
# 557   testing/TSTP/prover9/GEO/GEO067-2/Prover9---11...          ok
# 561   testing/TSTP/prover9/BOO/BOO006-1/Prover9---11...          ok
# 579   testing/TSTP/prover9/SEU/SEU053+1/Prover9---11...          ok
# 584   testing/TSTP/prover9/SET/SET788+1/Prover9---11...          ok
# 585   testing/TSTP/prover9/GEO/GEO067-3/Prover9---11...          ok
# 599   testing/TSTP/prover9/SEU/SEU149+2/Prover9---11...          ok
# 606   testing/TSTP/prover9/GRP/GRP544-1/Prover9---11...          ok
# 607   testing/TSTP/prover9/MGT/MGT065-1/Prover9---11...          ok
# 619   testing/TSTP/prover9/SEU/SEU150+2/Prover9---11...          ok
# 621   testing/TSTP/prover9/LAT/LAT312+1/Prover9---11...          ok
# 625   testing/TSTP/prover9/ALG/ALG071+1/Prover9---11...          ok
# 637   testing/TSTP/prover9/KLE/KLE055+1/Prover9---11...          ok
# 655   testing/TSTP/prover9/PRO/PRO006+3/Prover9---11...          ok
# 667   testing/TSTP/prover9/SWV/SWV909-1/Prover9---11...          ok
# 689   testing/TSTP/prover9/GRP/GRP531-1/Prover9---11...          ok
# 707   testing/TSTP/prover9/SWB/SWB014+3/Prover9---11...          ok
# 711   testing/TSTP/prover9/BOO/BOO003-2/Prover9---11...          ok
# 713   testing/TSTP/prover9/REL/REL008-1/Prover9---11...          ok
# 714   testing/TSTP/prover9/PRO/PRO006+4/Prover9---11...          ok
# 722   testing/TSTP/prover9/GEO/GEO200+3/Prover9---11...          ok
# 737   testing/TSTP/prover9/KLE/KLE008+1/Prover9---11...          ok
# 742   testing/TSTP/prover9/HEN/HEN004-2/Prover9---11...          ok
# 751   testing/TSTP/prover9/KLE/KLE027+4/Prover9---11...          ok
# 775   testing/TSTP/prover9/SET/SET854-2/Prover9---11...          ok
# 784   testing/TSTP/prover9/LCL/LCL204-1/Prover9---11...          ok
# 793   testing/TSTP/prover9/CAT/CAT009-1/Prover9---11...          ok
# 816   testing/TSTP/prover9/MGT/MGT064+1/Prover9---11...          ok
# 832   testing/TSTP/prover9/SYN/SYN077-1/Prover9---11...          ok
# 834   testing/TSTP/prover9/LDA/LDA004-1/Prover9---11...          ok
# 835   testing/TSTP/prover9/SET/SET014-4/Prover9---11...          ok
# 857   testing/TSTP/prover9/SWW/SWW474+1/Prover9---11...          ok
# 862   testing/TSTP/prover9/SET/SET017+1/Prover9---11...          ok
# 892   testing/TSTP/prover9/GRP/GRP002-1/Prover9---11...          ok
# 896   testing/TSTP/prover9/GRP/GRP355-1/Prover9---11...          ok
# 897   testing/TSTP/prover9/SYN/SYN181-1/Prover9---11...          ok
# 909   testing/TSTP/prover9/SWW/SWW224+1/Prover9---11...          ok
# 920   testing/TSTP/prover9/SYN/SYN321+1/Prover9---11...          ok
# 925   testing/TSTP/prover9/ANA/ANA028-2/Prover9---11...          ok
# 930   testing/TSTP/prover9/GEO/GEO217+1/Prover9---11...          ok
# 931   testing/TSTP/prover9/SWV/SWV252-2/Prover9---11...          ok
# 935   testing/TSTP/prover9/LAT/LAT005-5/Prover9---11...          ok
# 937   testing/TSTP/prover9/GEO/GEO126+1/Prover9---11...          ok
# 939   testing/TSTP/prover9/TOP/TOP023+1/Prover9---11...          ok
# 942   testing/TSTP/prover9/GRP/GRP029-2/Prover9---11...          ok
# 943   testing/TSTP/prover9/GEO/GEO179+2/Prover9---11...          ok
# 944   testing/TSTP/prover9/HEN/HEN003-4/Prover9---11...          ok
# 946   testing/TSTP/prover9/SEU/SEU171+2/Prover9---11...          ok
# 948   testing/TSTP/prover9/KLE/KLE131+1/Prover9---11...          ok
# 966   testing/TSTP/prover9/SEU/SEU187+2/Prover9---11...          ok
# 968   testing/TSTP/prover9/SEU/SEU291+1/Prover9---11...          ok
# 972   testing/TSTP/prover9/SET/SET017-6/Prover9---11...          ok
# 984   testing/TSTP/prover9/GRP/GRP123-6.003/Prover9-...          ok
# 990   testing/TSTP/prover9/SEU/SEU147+2/Prover9---11...          ok
# 991   testing/TSTP/prover9/GRP/GRP001+6/Prover9---11...          ok
# 1000  testing/TSTP/prover9/GRP/GRP189-2/Prover9---11...          ok
# 1011  testing/TSTP/prover9/MGT/MGT054-1/Prover9---11...          ok
# 1014  testing/TSTP/prover9/SWV/SWV473+1/Prover9---11...          ok
# 1048  testing/TSTP/prover9/LCL/LCL219-3/Prover9---11...          ok
# 1053  testing/TSTP/prover9/LCL/LCL210-3/Prover9---11...          ok
# 1066  testing/TSTP/prover9/GEO/GEO205+2/Prover9---11...          ok
# 1069  testing/TSTP/prover9/SYN/SYN137-1/Prover9---11...          ok
# 1095  testing/TSTP/prover9/SEU/SEU375+1/Prover9---11...          ok
# 1110  testing/TSTP/prover9/KLE/KLE167+1/Prover9---11...          ok
# 1114  testing/TSTP/prover9/SET/SET047+1/Prover9---11...          ok
# 1159  testing/TSTP/prover9/GRP/GRP171-1/Prover9---11...          ok
# 1160  testing/TSTP/prover9/ALG/ALG222+1/Prover9---11...          ok
# 1167  testing/TSTP/prover9/LAT/LAT304+1/Prover9---11...          ok
# 1192  testing/TSTP/prover9/SWV/SWV476+1/Prover9---11...          ok
# 1202  testing/TSTP/prover9/LAT/LAT031-1/Prover9---11...          ok
# 1214  testing/TSTP/prover9/LCL/LCL248-3/Prover9---11...          ok
# 1232  testing/TSTP/prover9/SET/SET072-7/Prover9---11...          ok
# 1257  testing/TSTP/prover9/GEO/GEO205+1/Prover9---11...          ok
# 1265  testing/TSTP/prover9/ALG/ALG012-1/Prover9---11...          ok
# 1271  testing/TSTP/prover9/SEU/SEU155+2/Prover9---11...          ok
# 1300  testing/TSTP/prover9/GRP/GRP172-2/Prover9---11...          ok
# 1319  testing/TSTP/prover9/HEN/HEN004-4/Prover9---11...          ok
# 1322  testing/TSTP/prover9/HWV/HWV022-1/Prover9---11...          ok
# 1331  testing/TSTP/prover9/COL/COL044-9/Prover9---11...          ok
# 1376  testing/TSTP/prover9/SYN/SYN054+1/Prover9---11...          ok
# 1390  testing/TSTP/prover9/SWV/SWV305-2/Prover9---11...          ok
# 1393  testing/TSTP/prover9/PUZ/PUZ035-5/Prover9---11...          ok
# 1395  testing/TSTP/prover9/SET/SET347-6/Prover9---11...          ok
# 1401  testing/TSTP/prover9/GEO/GEO183+3/Prover9---11...          ok
# 1404  testing/TSTP/prover9/FLD/FLD035-3/Prover9---11...          ok
# 1405  testing/TSTP/prover9/SEU/SEU131+1/Prover9---11...          ok
# 1407  testing/TSTP/prover9/FLD/FLD036-3/Prover9---11...          ok
# 1411  testing/TSTP/prover9/SYN/SYN271-1/Prover9---11...          ok
# 1413  testing/TSTP/prover9/PRO/PRO009+3/Prover9---11...          ok
# 1440  testing/TSTP/prover9/SET/SET664+3/Prover9---11...          ok
# 1461  testing/TSTP/prover9/SET/SET804+4/Prover9---11...          ok
# 1497  testing/TSTP/prover9/ALG/ALG070+1/Prover9---11...          ok
# 1530  testing/TSTP/prover9/SWV/SWV479+1/Prover9---11...          ok
# 1548  testing/TSTP/prover9/COL/COL002-3/Prover9---11...          ok
# 1553  testing/TSTP/prover9/GRP/GRP166-1/Prover9---11...          ok
# 1567  testing/TSTP/prover9/CAT/CAT014-4/Prover9---11...          ok
# 1577  testing/TSTP/prover9/SET/SET598+3/Prover9---11...          ok
# 1594  testing/TSTP/prover9/SYN/SYN577-1/Prover9---11...          ok
# 1617  testing/TSTP/prover9/SYN/SYN733+1/Prover9---11...          ok
# 1626  testing/TSTP/prover9/LCL/LCL208-3/Prover9---11...          ok
# 1631  testing/TSTP/prover9/SEU/SEU055+1/Prover9---11...          ok
# 1641  testing/TSTP/prover9/SWW/SWW198+1/Prover9---11...          ok
# 1644  testing/TSTP/prover9/GEO/GEO192+2/Prover9---11...          ok
# 1649  testing/TSTP/prover9/GEO/GEO192+1/Prover9---11...          ok
# 1654  testing/TSTP/prover9/KLE/KLE139+2/Prover9---11...          ok
# 1660  testing/TSTP/prover9/KLE/KLE048+1/Prover9---11...          ok
# 1663  testing/TSTP/prover9/COL/COL044-3/Prover9---11...          ok
# 1679  testing/TSTP/prover9/SYN/SYN069-1/Prover9---11...          ok
# 1702  testing/TSTP/prover9/LAT/LAT038-1/Prover9---11...          ok
# 1706  testing/TSTP/prover9/PUZ/PUZ133+1/Prover9---11...          ok
# 1711  testing/TSTP/prover9/GRP/GRP003-1/Prover9---11...          ok
# 1714  testing/TSTP/prover9/GEO/GEO177+2/Prover9---11...          ok
# 1730  testing/TSTP/prover9/GEO/GEO177+3/Prover9---11...          ok
# 1734  testing/TSTP/prover9/GRP/GRP004-2/Prover9---11...          ok
# 1766  testing/TSTP/prover9/LAT/LAT306+1/Prover9---11...          ok
# 1775  testing/TSTP/prover9/SWV/SWV731-1/Prover9---11...          ok
# 1795  testing/TSTP/prover9/GRP/GRP687-1/Prover9---11...          ok
# 1812  testing/TSTP/prover9/COL/COL044-7/Prover9---11...          ok
# 1833  testing/TSTP/prover9/GEO/GEO217+2/Prover9---11...          ok
# 1834  testing/TSTP/prover9/ALG/ALG236-1/Prover9---11...          ok
# 1838  testing/TSTP/prover9/MGT/MGT034+2/Prover9---11...          ok
# 1859  testing/TSTP/prover9/GRP/GRP197-1/Prover9---11...          ok
# 1865  testing/TSTP/prover9/SET/SET068-7/Prover9---11...          ok
# 1866  testing/TSTP/prover9/LCL/LCL201-3/Prover9---11...          ok
# 1867  testing/TSTP/prover9/SET/SET173+3/Prover9---11...          ok
# 1877  testing/TSTP/prover9/GRP/GRP731-1/Prover9---11...          ok
# 1881  testing/TSTP/prover9/GRP/GRP123-7.003/Prover9-...          ok
# 1898  testing/TSTP/prover9/PUZ/PUZ133+2/Prover9---11...          ok
# 1916  testing/TSTP/prover9/PUZ/PUZ035-6/Prover9---11...          ok
# 1920  testing/TSTP/prover9/GRP/GRP003-2/Prover9---11...          ok
# 1951  testing/TSTP/prover9/NUM/NUM455+6/Prover9---11...          ok
# 1953  testing/TSTP/prover9/RNG/RNG004-1/Prover9---11...          ok
# 1961  testing/TSTP/prover9/RNG/RNG029-3/Prover9---11...          ok
# 1974  testing/TSTP/prover9/SWV/SWV477+1/Prover9---11...          ok
# 2024  testing/TSTP/prover9/SET/SET834-2/Prover9---11...          ok
# 2075  testing/TSTP/prover9/SWV/SWV901-1/Prover9---11...          ok
# 2091  testing/TSTP/prover9/SET/SET063-6/Prover9---11...          ok
# 2093  testing/TSTP/prover9/REL/REL009-1/Prover9---11...          ok
# 2142  testing/TSTP/prover9/GEO/GEO111-1/Prover9---11...          ok
# 2149  testing/TSTP/prover9/PRO/PRO009+4/Prover9---11...          ok
# 2178  testing/TSTP/prover9/HEN/HEN005-3/Prover9---11...          ok
# 2190  testing/TSTP/prover9/SET/SET084+1/Prover9---11...          ok
# 2209  testing/TSTP/prover9/COL/COL044-4/Prover9---11...          ok
# 2215  testing/TSTP/prover9/REL/REL009-2/Prover9---11...          ok
# 2229  testing/TSTP/prover9/RNG/RNG023-7/Prover9---11...          ok
# 2233  testing/TSTP/prover9/LCL/LCL441-2/Prover9---11...          ok
# 2236  testing/TSTP/prover9/GRP/GRP617-1/Prover9---11...          ok
# 2237  testing/TSTP/prover9/HEN/HEN010-5/Prover9---11...          ok
# 2243  testing/TSTP/prover9/GEO/GEO212+2/Prover9---11...          ok
# 2244  testing/TSTP/prover9/SEU/SEU110+1/Prover9---11...          ok
# 2279  testing/TSTP/prover9/LAT/LAT303+1/Prover9---11...          ok
# 2287  testing/TSTP/prover9/PRO/PRO003+3/Prover9---11...          ok
# 2293  testing/TSTP/prover9/GRP/GRP001-2/Prover9---11...          ok
# 2294  testing/TSTP/prover9/GEO/GEO212+1/Prover9---11...          ok
# 2297  testing/TSTP/prover9/SYN/SYN077+1/Prover9---11...          ok
# 2301  testing/TSTP/prover9/SCT/SCT031-1/Prover9---11...          ok
# 2344  testing/TSTP/prover9/SET/SET473-6/Prover9---11...          ok
# 2355  testing/TSTP/prover9/KLE/KLE027+2/Prover9---11...          ok
# 2358  testing/TSTP/prover9/GEO/GEO147+1/Prover9---11...          ok
# 2361  testing/TSTP/prover9/LCL/LCL441-1/Prover9---11...          ok
# 2375  testing/TSTP/prover9/HEN/HEN003-5/Prover9---11...          ok
# 2381  testing/TSTP/prover9/SEU/SEU027+1/Prover9---11...          ok
# 2413  testing/TSTP/prover9/GRP/GRP529-1/Prover9---11...          ok
# 2414  testing/TSTP/prover9/LCL/LCL192-3/Prover9---11...          ok
# 2455  testing/TSTP/prover9/GRP/GRP046-2/Prover9---11...          ok
# 2459  testing/TSTP/prover9/KLE/KLE027+3/Prover9---11...          ok
# 2460  testing/TSTP/prover9/COL/COL004-3/Prover9---11...          ok
# 2466  testing/TSTP/prover9/SEU/SEU324+1/Prover9---11...          ok
# 2478  testing/TSTP/prover9/SET/SET962+1/Prover9---11...          ok
# 2559  testing/TSTP/prover9/SET/SET663+3/Prover9---11...          ok
# 2579  testing/TSTP/prover9/KLE/KLE010+2/Prover9---11...          ok
# 2593  testing/TSTP/prover9/SET/SET667+3/Prover9---11...          ok
# 2596  testing/TSTP/prover9/KLE/KLE139+1/Prover9---11...          ok
# 2622  testing/TSTP/prover9/GRP/GRP639+1/Prover9---11...          ok
# 2639  testing/TSTP/prover9/SYN/SYN084-2/Prover9---11...          ok
# 2645  testing/TSTP/prover9/SET/SET843-2/Prover9---11...          ok
# 2647  testing/TSTP/prover9/SYN/SYN054-1/Prover9---11...          ok
# 2650  testing/TSTP/prover9/LAT/LAT302+1/Prover9---11...          ok
# 2654  testing/TSTP/prover9/KRS/KRS080+1/Prover9---11...          ok
# 2704  testing/TSTP/prover9/LCL/LCL109-5/Prover9---11...          ok
# 2744  testing/TSTP/prover9/PRO/PRO014+4/Prover9---11...          ok
# 2747  testing/TSTP/prover9/SWW/SWW410-1/Prover9---11...          ok
# 2750  testing/TSTP/prover9/GEO/GEO189+1/Prover9---11...          ok
# 2777  testing/TSTP/prover9/REL/REL008-3/Prover9---11...          ok
# 2781  testing/TSTP/prover9/GEO/GEO186+3/Prover9---11...          ok
# 2792  testing/TSTP/prover9/SYN/SYN576-1/Prover9---11...          ok
# 2812  testing/TSTP/prover9/LCL/LCL157-1/Prover9---11...          ok
# 2820  testing/TSTP/prover9/NUM/NUM016-1/Prover9---11...          ok
# 2827  testing/TSTP/prover9/SWV/SWV827-1/Prover9---11...          ok
# 2844  testing/TSTP/prover9/LCL/LCL187-3/Prover9---11...          ok
# 2854  testing/TSTP/prover9/SWC/SWC009+1/Prover9---11...          ok
# 2860  testing/TSTP/prover9/COL/COL044-8/Prover9---11...          ok
# 2884  testing/TSTP/prover9/SWW/SWW101+1/Prover9---11...          ok
# 2907  testing/TSTP/prover9/GRP/GRP171-2/Prover9---11...          ok
# 2911  testing/TSTP/prover9/HEN/HEN003-3/Prover9---11...          ok
# 2914  testing/TSTP/prover9/LAT/LAT019-1/Prover9---11...          ok
# 2940  testing/TSTP/prover9/KLE/KLE119+1/Prover9---11...          ok
# 2946  testing/TSTP/prover9/SYN/SYN321-1/Prover9---11...          ok
# 2952  testing/TSTP/prover9/SET/SET247-6/Prover9---11...          ok
# 2957  testing/TSTP/prover9/RNG/RNG007-4/Prover9---11...          ok
# 2963  testing/TSTP/prover9/KLE/KLE148+2/Prover9---11...          ok
#
#                   status_mcoq1
# 14     cutintro_uncompressible
# 22              prcons_timeout
# 36              prcons_timeout
# 51              prcons_timeout
# 55              prcons_timeout
# 57     cutintro_uncompressible
# 59              prcons_timeout
# 67              prcons_timeout
# 80     grammar_finding_timeout
# 81     grammar_finding_timeout
# 103    cutintro_uncompressible
# 123             prcons_timeout
# 128             prcons_timeout
# 146    cutintro_uncompressible
# 158    grammar_finding_timeout
# 168             prcons_timeout
# 169    grammar_finding_timeout
# 170    grammar_finding_timeout
# 188    grammar_finding_timeout
# 218    cutintro_uncompressible
# 243    cutintro_uncompressible
# 249    grammar_finding_timeout
# 265    cutintro_uncompressible
# 292    grammar_finding_timeout
# 296    cutintro_uncompressible
# 320    cutintro_uncompressible
# 321             prcons_timeout
# 330    cutintro_uncompressible
# 353    cutintro_uncompressible
# 367    cutintro_uncompressible
# 382    cutintro_uncompressible
# 385    cutintro_uncompressible
# 397    grammar_finding_timeout
# 399    grammar_finding_timeout
# 415    cutintro_uncompressible
# 416   cutintro_other_exception
# 427    cutintro_uncompressible
# 443    grammar_finding_timeout
# 472    cutintro_uncompressible
# 481    cutintro_uncompressible
# 491    cutintro_uncompressible
# 509    cutintro_uncompressible
# 533    cutintro_uncompressible
# 534    cutintro_uncompressible
# 550    grammar_finding_timeout
# 553    cutintro_uncompressible
# 557             prcons_timeout
# 561    cutintro_uncompressible
# 579    cutintro_uncompressible
# 584    cutintro_uncompressible
# 585    cutintro_uncompressible
# 599   cutintro_other_exception
# 606    cutintro_uncompressible
# 607             prcons_timeout
# 619    cutintro_uncompressible
# 621             prcons_timeout
# 625    cutintro_uncompressible
# 637    cutintro_uncompressible
# 655    grammar_finding_timeout
# 667    cutintro_uncompressible
# 689             prcons_timeout
# 707    cutintro_uncompressible
# 711             prcons_timeout
# 713    cutintro_uncompressible
# 714    grammar_finding_timeout
# 722             prcons_timeout
# 737    grammar_finding_timeout
# 742    cutintro_uncompressible
# 751    grammar_finding_timeout
# 775             prcons_timeout
# 784    cutintro_uncompressible
# 793             prcons_timeout
# 816    grammar_finding_timeout
# 832    cutintro_uncompressible
# 834    grammar_finding_timeout
# 835    cutintro_uncompressible
# 857    grammar_finding_timeout
# 862    cutintro_uncompressible
# 892    grammar_finding_timeout
# 896             prcons_timeout
# 897    cutintro_uncompressible
# 909    grammar_finding_timeout
# 920    cutintro_uncompressible
# 925    grammar_finding_timeout
# 930    cutintro_uncompressible
# 931    grammar_finding_timeout
# 935    cutintro_uncompressible
# 937             prcons_timeout
# 939    cutintro_uncompressible
# 942    cutintro_uncompressible
# 943    cutintro_uncompressible
# 944    cutintro_uncompressible
# 946    grammar_finding_timeout
# 948    grammar_finding_timeout
# 966    cutintro_uncompressible
# 968    cutintro_uncompressible
# 972    cutintro_uncompressible
# 984    cutintro_uncompressible
# 990    cutintro_uncompressible
# 991    cutintro_uncompressible
# 1000   grammar_finding_timeout
# 1011   cutintro_uncompressible
# 1014   cutintro_uncompressible
# 1048   grammar_finding_timeout
# 1053   grammar_finding_timeout
# 1066            prcons_timeout
# 1069   cutintro_uncompressible
# 1095   cutintro_uncompressible
# 1110   grammar_finding_timeout
# 1114   cutintro_uncompressible
# 1159            prcons_timeout
# 1160   cutintro_uncompressible
# 1167            prcons_timeout
# 1192            prcons_timeout
# 1202   grammar_finding_timeout
# 1214   grammar_finding_timeout
# 1232   cutintro_uncompressible
# 1257            prcons_timeout
# 1265   grammar_finding_timeout
# 1271            prcons_timeout
# 1300            prcons_timeout
# 1319   cutintro_uncompressible
# 1322   cutintro_uncompressible
# 1331   cutintro_uncompressible
# 1376   cutintro_uncompressible
# 1390            prcons_timeout
# 1393   cutintro_uncompressible
# 1395   grammar_finding_timeout
# 1401   cutintro_uncompressible
# 1404   cutintro_uncompressible
# 1405   cutintro_uncompressible
# 1407   cutintro_uncompressible
# 1411   cutintro_uncompressible
# 1413   cutintro_uncompressible
# 1440   cutintro_uncompressible
# 1461   cutintro_uncompressible
# 1497            prcons_timeout
# 1530            prcons_timeout
# 1548   cutintro_uncompressible
# 1553   cutintro_uncompressible
# 1567   cutintro_uncompressible
# 1577            prcons_timeout
# 1594            prcons_timeout
# 1617   cutintro_uncompressible
# 1626   grammar_finding_timeout
# 1631   grammar_finding_timeout
# 1641            prcons_timeout
# 1644   cutintro_uncompressible
# 1649   cutintro_uncompressible
# 1654   grammar_finding_timeout
# 1660   grammar_finding_timeout
# 1663   cutintro_uncompressible
# 1679   cutintro_uncompressible
# 1702   grammar_finding_timeout
# 1706            prcons_timeout
# 1711   cutintro_uncompressible
# 1714   cutintro_uncompressible
# 1730            prcons_timeout
# 1734   cutintro_uncompressible
# 1766            prcons_timeout
# 1775            prcons_timeout
# 1795   grammar_finding_timeout
# 1812   cutintro_uncompressible
# 1833   cutintro_uncompressible
# 1834   grammar_finding_timeout
# 1838   cutintro_uncompressible
# 1859   grammar_finding_timeout
# 1865   cutintro_uncompressible
# 1866   grammar_finding_timeout
# 1867  cutintro_other_exception
# 1877   grammar_finding_timeout
# 1881   cutintro_uncompressible
# 1898   grammar_finding_timeout
# 1916   cutintro_uncompressible
# 1920   cutintro_uncompressible
# 1951   cutintro_uncompressible
# 1953   grammar_finding_timeout
# 1961   grammar_finding_timeout
# 1974            prcons_timeout
# 2024   cutintro_uncompressible
# 2075   cutintro_uncompressible
# 2091   cutintro_uncompressible
# 2093   cutintro_uncompressible
# 2142   cutintro_uncompressible
# 2149   cutintro_uncompressible
# 2178   cutintro_uncompressible
# 2190            prcons_timeout
# 2209   cutintro_uncompressible
# 2215   cutintro_uncompressible
# 2229   cutintro_uncompressible
# 2233   cutintro_uncompressible
# 2236   grammar_finding_timeout
# 2237   grammar_finding_timeout
# 2243   cutintro_uncompressible
# 2244   cutintro_uncompressible
# 2279            prcons_timeout
# 2287   cutintro_uncompressible
# 2293   cutintro_uncompressible
# 2294   cutintro_uncompressible
# 2297   cutintro_uncompressible
# 2301  cutintro_other_exception
# 2344   grammar_finding_timeout
# 2355   grammar_finding_timeout
# 2358   cutintro_uncompressible
# 2361   cutintro_uncompressible
# 2375   cutintro_uncompressible
# 2381   cutintro_uncompressible
# 2413            prcons_timeout
# 2414   grammar_finding_timeout
# 2455   cutintro_uncompressible
# 2459   grammar_finding_timeout
# 2460   cutintro_uncompressible
# 2466   cutintro_uncompressible
# 2478   cutintro_uncompressible
# 2559   cutintro_uncompressible
# 2579   grammar_finding_timeout
# 2593            prcons_timeout
# 2596   grammar_finding_timeout
# 2622   cutintro_uncompressible
# 2639   cutintro_uncompressible
# 2645   cutintro_uncompressible
# 2647   cutintro_uncompressible
# 2650            prcons_timeout
# 2654            prcons_timeout
# 2704   cutintro_uncompressible
# 2744   grammar_finding_timeout
# 2747            prcons_timeout
# 2750   cutintro_uncompressible
# 2777   cutintro_uncompressible
# 2781   cutintro_uncompressible
# 2792   cutintro_uncompressible
# 2812   grammar_finding_timeout
# 2820   cutintro_uncompressible
# 2827   cutintro_uncompressible
# 2844   grammar_finding_timeout
# 2854   cutintro_uncompressible
# 2860   cutintro_uncompressible
# 2884            prcons_timeout
# 2907            prcons_timeout
# 2911   cutintro_uncompressible
# 2914   grammar_finding_timeout
# 2940   grammar_finding_timeout
# 2946   cutintro_uncompressible
# 2952            prcons_timeout
# 2957   cutintro_uncompressible
# 2963   grammar_finding_timeout

# %%
# Test that are ok in many_cuts_one_quantifier_1 and fail for one_cut_one_quantifier

data_ocoq = data[data.method == 'one_cut_one_quant']
data_mcoq1 = data[data.method == 'many_cuts_one_quant_1']

merged = pd.merge(data_ocoq, data_mcoq1, on=['file'], suffixes=('_ocoq', '_mcmq1'))

diff = merged[(merged.status_ocoq != 'ok') & (merged.status_mcmq1 == 'ok')]
print(diff.shape)
diff[['file','status_ocoq', 'status_mcmq1']]
# Out:
# (34, 39)
#                                                    file  \
# 12                               LinearExampleProof(13)
# 30                           SquareEdgesExampleProof(8)
# 47                             LinearEqExampleProof(11)
# 245   testing/TSTP/prover9/SYN/SYN052-1/Prover9---11...
# 258   testing/TSTP/prover9/HWC/HWC002-1/Prover9---11...
# 268   testing/TSTP/prover9/GRP/GRP561-1/Prover9---11...
# 447   testing/TSTP/prover9/BOO/BOO011-4/Prover9---11...
# 486   testing/TSTP/prover9/GRP/GRP776+1/Prover9---11...
# 640   testing/TSTP/prover9/GRP/GRP181-4/Prover9---11...
# 684   testing/TSTP/prover9/SEU/SEU132+1/Prover9---11...
# 706   testing/TSTP/prover9/GEO/GEO001-1/Prover9---11...
# 725   testing/TSTP/prover9/GRP/GRP169-1/Prover9---11...
# 729   testing/TSTP/prover9/GEO/GEO126-1/Prover9---11...
# 771   testing/TSTP/prover9/LDA/LDA002-1/Prover9---11...
# 841   testing/TSTP/prover9/GRP/GRP135-2.002/Prover9-...
# 1175  testing/TSTP/prover9/SWV/SWV558-1.004/Prover9-...
# 1304  testing/TSTP/prover9/HWV/HWV052-1.001.001/Prov...
# 1305  testing/TSTP/prover9/GRP/GRP578-1/Prover9---11...
# 1369  testing/TSTP/prover9/LAT/LAT090-1/Prover9---11...
# 1480  testing/TSTP/prover9/HEN/HEN009-5/Prover9---11...
# 1521  testing/TSTP/prover9/SEU/SEU141+2/Prover9---11...
# 1755  testing/TSTP/prover9/SWC/SWC025-1/Prover9---11...
# 1832  testing/TSTP/prover9/LCL/LCL498+1/Prover9---11...
# 1947  testing/TSTP/prover9/SEU/SEU169+2/Prover9---11...
# 2030  testing/TSTP/prover9/LAT/LAT327+1/Prover9---11...
# 2079  testing/TSTP/prover9/GRP/GRP747+1/Prover9---11...
# 2203  testing/TSTP/prover9/GEO/GEO222+1/Prover9---11...
# 2268  testing/TSTP/prover9/SEU/SEU153+2/Prover9---11...
# 2642  testing/TSTP/prover9/BOO/BOO075-1/Prover9---11...
# 2662  testing/TSTP/prover9/SYN/SYN918+1/Prover9---11...
# 2687  testing/TSTP/prover9/GRP/GRP589-1/Prover9---11...
# 2803  testing/TSTP/prover9/SWV/SWV751-1/Prover9---11...
# 2833  testing/TSTP/prover9/GRP/GRP135-1.002/Prover9-...
# 3102  testing/veriT-SMT-LIB/QF_UF/QG-classification/...
#
#                           status_ocoq status_mcmq1
# 12                     prcons_timeout           ok
# 30                     prcons_timeout           ok
# 47                     prcons_timeout           ok
# 245        lk_rule_creation_exception           ok
# 258           grammar_finding_timeout           ok
# 268                       sol_timeout           ok
# 447                       sol_timeout           ok
# 486                    prcons_timeout           ok
# 640                       sol_timeout           ok
# 684                    prcons_timeout           ok
# 706           cutintro_ehs_unprovable           ok
# 725   delta_table_computation_timeout           ok
# 729                    prcons_timeout           ok
# 771                    prcons_timeout           ok
# 841                    prcons_timeout           ok
# 1175          cutintro_uncompressible           ok
# 1304                   prcons_timeout           ok
# 1305                   prcons_timeout           ok
# 1369                      sol_timeout           ok
# 1480                      sol_timeout           ok
# 1521                   prcons_timeout           ok
# 1755                   prcons_timeout           ok
# 1832                   prcons_timeout           ok
# 1947         cutintro_other_exception           ok
# 2030                   prcons_timeout           ok
# 2079                      sol_timeout           ok
# 2203                   prcons_timeout           ok
# 2268         cutintro_other_exception           ok
# 2642                      sol_timeout           ok
# 2662                   prcons_timeout           ok
# 2687          cutintro_ehs_unprovable           ok
# 2803                      sol_timeout           ok
# 2833                   prcons_timeout           ok
# 3102          grammar_finding_timeout           ok

# %%
# Regressions compared to previous test

previous_filename = "../2015-02-10/CutIntroDataLog.txt"
previous_data = getData(previous_filename)

merged = pd.merge(data, previous_data, on=['method', 'file'])
#merged.head(0)

regression = merged[(merged.status_y == 'ok') & (merged.status_x != 'ok')]
#regression.head(0)
print(regression.shape)

regression_delta = regression[(regression.method == 'one_cut_one_quant') | (regression.method == 'one_cut_many_quant')]
print(regression_delta.shape)
#regression_delta.head(0)

regression_maxsat = regression[((regression.method == 'many_cuts_one_quant_1') | (regression.method == 'many_cuts_one_quant_2')) ]
print(regression_maxsat.shape)
#regression_maxsat.head(0)

regression[['method', 'file', 'status_x', 'status_y']]
# Out:
# (3463, 38)
# (26, 38)
# (3437, 38)
#                       method  \
# 69         one_cut_one_quant
# 139       one_cut_many_quant
# 140    many_cuts_one_quant_1
# 141    many_cuts_one_quant_1
# 142    many_cuts_one_quant_1
# 155    many_cuts_one_quant_1
# 156    many_cuts_one_quant_1
# 157    many_cuts_one_quant_1
# 165    many_cuts_one_quant_1
# 166    many_cuts_one_quant_1
# 174    many_cuts_one_quant_1
# 175    many_cuts_one_quant_1
# 176    many_cuts_one_quant_1
# 177    many_cuts_one_quant_1
# 180    many_cuts_one_quant_1
# 181    many_cuts_one_quant_1
# 194    many_cuts_one_quant_1
# 197    many_cuts_one_quant_1
# 198    many_cuts_one_quant_1
# 201    many_cuts_one_quant_1
# 203    many_cuts_one_quant_1
# 205    many_cuts_one_quant_1
# 206    many_cuts_one_quant_1
# 207    many_cuts_one_quant_1
# 208    many_cuts_one_quant_2
# 209    many_cuts_one_quant_2
# 210    many_cuts_one_quant_2
# 221    many_cuts_one_quant_2
# 230    many_cuts_one_quant_2
# 238    many_cuts_one_quant_2
# 239    many_cuts_one_quant_2
# 240    many_cuts_one_quant_2
# 242    many_cuts_one_quant_2
# 243    many_cuts_one_quant_2
# 244    many_cuts_one_quant_2
# 252    many_cuts_one_quant_2
# 255    many_cuts_one_quant_2
# 256    many_cuts_one_quant_2
# 259    many_cuts_one_quant_2
# 265    many_cuts_one_quant_2
# 450        one_cut_one_quant
# 605        one_cut_one_quant
# 608        one_cut_one_quant
# 986        one_cut_one_quant
# 1046       one_cut_one_quant
# 1092       one_cut_one_quant
# 1307       one_cut_one_quant
# 1647       one_cut_one_quant
# 1757       one_cut_one_quant
# 2059       one_cut_one_quant
# 2235       one_cut_one_quant
# 2294       one_cut_one_quant
# 2365       one_cut_one_quant
# 2458       one_cut_one_quant
# 2894       one_cut_one_quant
# 3038       one_cut_one_quant
# 3359      one_cut_many_quant
# 3955      one_cut_many_quant
# 5144      one_cut_many_quant
# 5203      one_cut_many_quant
# 5367      one_cut_many_quant
# 5947      one_cut_many_quant
# 6084   many_cuts_one_quant_1
# 6086   many_cuts_one_quant_1
# 6088   many_cuts_one_quant_1
# 6090   many_cuts_one_quant_1
# 6093   many_cuts_one_quant_1
# 6094   many_cuts_one_quant_1
# 6095   many_cuts_one_quant_1
# 6097   many_cuts_one_quant_1
# 6098   many_cuts_one_quant_1
# 6099   many_cuts_one_quant_1
# 6100   many_cuts_one_quant_1
# 6101   many_cuts_one_quant_1
# 6105   many_cuts_one_quant_1
# 6107   many_cuts_one_quant_1
# 6109   many_cuts_one_quant_1
# 6114   many_cuts_one_quant_1
# 6116   many_cuts_one_quant_1
# 6117   many_cuts_one_quant_1
# 6118   many_cuts_one_quant_1
# 6119   many_cuts_one_quant_1
# 6122   many_cuts_one_quant_1
# 6123   many_cuts_one_quant_1
# 6126   many_cuts_one_quant_1
# 6127   many_cuts_one_quant_1
# 6128   many_cuts_one_quant_1
# 6129   many_cuts_one_quant_1
# 6130   many_cuts_one_quant_1
# 6131   many_cuts_one_quant_1
# 6132   many_cuts_one_quant_1
# 6133   many_cuts_one_quant_1
# 6134   many_cuts_one_quant_1
# 6135   many_cuts_one_quant_1
# 6136   many_cuts_one_quant_1
# 6142   many_cuts_one_quant_1
# 6144   many_cuts_one_quant_1
# 6145   many_cuts_one_quant_1
# 6146   many_cuts_one_quant_1
# 6148   many_cuts_one_quant_1
# 6150   many_cuts_one_quant_1
# 6151   many_cuts_one_quant_1
# 6152   many_cuts_one_quant_1
# 6153   many_cuts_one_quant_1
# 6155   many_cuts_one_quant_1
# 6159   many_cuts_one_quant_1
# 6160   many_cuts_one_quant_1
# 6161   many_cuts_one_quant_1
# 6162   many_cuts_one_quant_1
# 6163   many_cuts_one_quant_1
# 6164   many_cuts_one_quant_1
# 6165   many_cuts_one_quant_1
# 6166   many_cuts_one_quant_1
# 6168   many_cuts_one_quant_1
# 6169   many_cuts_one_quant_1
# 6170   many_cuts_one_quant_1
# 6171   many_cuts_one_quant_1
# 6173   many_cuts_one_quant_1
# 6174   many_cuts_one_quant_1
# 6177   many_cuts_one_quant_1
# 6178   many_cuts_one_quant_1
# 6179   many_cuts_one_quant_1
# 6183   many_cuts_one_quant_1
# 6184   many_cuts_one_quant_1
# 6185   many_cuts_one_quant_1
# 6186   many_cuts_one_quant_1
# 6188   many_cuts_one_quant_1
# 6189   many_cuts_one_quant_1
# 6190   many_cuts_one_quant_1
# 6191   many_cuts_one_quant_1
# 6196   many_cuts_one_quant_1
# 6198   many_cuts_one_quant_1
# 6199   many_cuts_one_quant_1
# 6200   many_cuts_one_quant_1
# 6202   many_cuts_one_quant_1
# 6203   many_cuts_one_quant_1
# 6205   many_cuts_one_quant_1
# 6209   many_cuts_one_quant_1
# 6213   many_cuts_one_quant_1
# 6214   many_cuts_one_quant_1
# 6215   many_cuts_one_quant_1
# 6218   many_cuts_one_quant_1
# 6219   many_cuts_one_quant_1
# 6220   many_cuts_one_quant_1
# 6221   many_cuts_one_quant_1
# 6222   many_cuts_one_quant_1
# 6224   many_cuts_one_quant_1
# 6225   many_cuts_one_quant_1
# 6226   many_cuts_one_quant_1
# 6227   many_cuts_one_quant_1
# 6228   many_cuts_one_quant_1
# 6230   many_cuts_one_quant_1
# 6231   many_cuts_one_quant_1
# 6233   many_cuts_one_quant_1
# 6234   many_cuts_one_quant_1
# 6237   many_cuts_one_quant_1
# 6238   many_cuts_one_quant_1
# 6241   many_cuts_one_quant_1
# 6243   many_cuts_one_quant_1
# 6244   many_cuts_one_quant_1
# 6245   many_cuts_one_quant_1
# 6247   many_cuts_one_quant_1
# 6249   many_cuts_one_quant_1
# 6251   many_cuts_one_quant_1
# 6253   many_cuts_one_quant_1
# 6255   many_cuts_one_quant_1
# 6257   many_cuts_one_quant_1
# 6258   many_cuts_one_quant_1
# 6261   many_cuts_one_quant_1
# 6265   many_cuts_one_quant_1
# 6266   many_cuts_one_quant_1
# 6267   many_cuts_one_quant_1
# 6270   many_cuts_one_quant_1
# 6274   many_cuts_one_quant_1
# 6275   many_cuts_one_quant_1
# 6276   many_cuts_one_quant_1
# 6277   many_cuts_one_quant_1
# 6279   many_cuts_one_quant_1
# 6282   many_cuts_one_quant_1
# 6283   many_cuts_one_quant_1
# 6285   many_cuts_one_quant_1
# 6288   many_cuts_one_quant_1
# 6289   many_cuts_one_quant_1
# 6292   many_cuts_one_quant_1
# 6296   many_cuts_one_quant_1
# 6297   many_cuts_one_quant_1
# 6298   many_cuts_one_quant_1
# 6301   many_cuts_one_quant_1
# 6302   many_cuts_one_quant_1
# 6303   many_cuts_one_quant_1
# 6304   many_cuts_one_quant_1
# 6309   many_cuts_one_quant_1
# 6311   many_cuts_one_quant_1
# 6316   many_cuts_one_quant_1
# 6318   many_cuts_one_quant_1
# 6319   many_cuts_one_quant_1
# 6321   many_cuts_one_quant_1
# 6322   many_cuts_one_quant_1
# 6325   many_cuts_one_quant_1
# 6327   many_cuts_one_quant_1
# 6328   many_cuts_one_quant_1
# 6329   many_cuts_one_quant_1
# 6330   many_cuts_one_quant_1
# 6331   many_cuts_one_quant_1
# 6332   many_cuts_one_quant_1
# 6334   many_cuts_one_quant_1
# 6337   many_cuts_one_quant_1
# 6339   many_cuts_one_quant_1
# 6340   many_cuts_one_quant_1
# 6341   many_cuts_one_quant_1
# 6342   many_cuts_one_quant_1
# 6343   many_cuts_one_quant_1
# 6344   many_cuts_one_quant_1
# 6345   many_cuts_one_quant_1
# 6346   many_cuts_one_quant_1
# 6350   many_cuts_one_quant_1
# 6351   many_cuts_one_quant_1
# 6352   many_cuts_one_quant_1
# 6353   many_cuts_one_quant_1
# 6354   many_cuts_one_quant_1
# 6355   many_cuts_one_quant_1
# 6357   many_cuts_one_quant_1
# 6358   many_cuts_one_quant_1
# 6360   many_cuts_one_quant_1
# 6361   many_cuts_one_quant_1
# 6362   many_cuts_one_quant_1
# 6366   many_cuts_one_quant_1
# 6367   many_cuts_one_quant_1
# 6371   many_cuts_one_quant_1
# 6372   many_cuts_one_quant_1
# 6373   many_cuts_one_quant_1
# 6375   many_cuts_one_quant_1
# 6376   many_cuts_one_quant_1
# 6378   many_cuts_one_quant_1
# 6381   many_cuts_one_quant_1
# 6383   many_cuts_one_quant_1
# 6384   many_cuts_one_quant_1
# 6385   many_cuts_one_quant_1
# 6387   many_cuts_one_quant_1
# 6390   many_cuts_one_quant_1
# 6392   many_cuts_one_quant_1
# 6393   many_cuts_one_quant_1
# 6395   many_cuts_one_quant_1
# 6396   many_cuts_one_quant_1
# 6398   many_cuts_one_quant_1
# 6399   many_cuts_one_quant_1
# 6400   many_cuts_one_quant_1
# 6402   many_cuts_one_quant_1
# 6403   many_cuts_one_quant_1
# 6405   many_cuts_one_quant_1
# 6406   many_cuts_one_quant_1
# 6407   many_cuts_one_quant_1
# 6408   many_cuts_one_quant_1
# 6409   many_cuts_one_quant_1
# 6411   many_cuts_one_quant_1
# 6412   many_cuts_one_quant_1
# 6415   many_cuts_one_quant_1
# 6416   many_cuts_one_quant_1
# 6417   many_cuts_one_quant_1
# 6419   many_cuts_one_quant_1
# 6421   many_cuts_one_quant_1
# 6424   many_cuts_one_quant_1
# 6425   many_cuts_one_quant_1
# 6428   many_cuts_one_quant_1
# 6429   many_cuts_one_quant_1
# 6430   many_cuts_one_quant_1
# 6431   many_cuts_one_quant_1
# 6433   many_cuts_one_quant_1
# 6434   many_cuts_one_quant_1
# 6436   many_cuts_one_quant_1
# 6438   many_cuts_one_quant_1
# 6440   many_cuts_one_quant_1
# 6442   many_cuts_one_quant_1
# 6444   many_cuts_one_quant_1
# 6445   many_cuts_one_quant_1
# 6446   many_cuts_one_quant_1
# 6447   many_cuts_one_quant_1
# 6450   many_cuts_one_quant_1
# 6451   many_cuts_one_quant_1
# 6452   many_cuts_one_quant_1
# 6453   many_cuts_one_quant_1
# 6455   many_cuts_one_quant_1
# 6456   many_cuts_one_quant_1
# 6457   many_cuts_one_quant_1
# 6458   many_cuts_one_quant_1
# 6459   many_cuts_one_quant_1
# 6460   many_cuts_one_quant_1
# 6461   many_cuts_one_quant_1
# 6463   many_cuts_one_quant_1
# 6464   many_cuts_one_quant_1
# 6465   many_cuts_one_quant_1
# 6469   many_cuts_one_quant_1
# 6471   many_cuts_one_quant_1
# 6472   many_cuts_one_quant_1
# 6479   many_cuts_one_quant_1
# 6480   many_cuts_one_quant_1
# 6482   many_cuts_one_quant_1
# 6483   many_cuts_one_quant_1
# 6484   many_cuts_one_quant_1
# 6485   many_cuts_one_quant_1
# 6486   many_cuts_one_quant_1
# 6488   many_cuts_one_quant_1
# 6489   many_cuts_one_quant_1
# 6491   many_cuts_one_quant_1
# 6492   many_cuts_one_quant_1
# 6493   many_cuts_one_quant_1
# 6494   many_cuts_one_quant_1
# 6495   many_cuts_one_quant_1
# 6497   many_cuts_one_quant_1
# 6501   many_cuts_one_quant_1
# 6503   many_cuts_one_quant_1
# 6504   many_cuts_one_quant_1
# 6506   many_cuts_one_quant_1
# 6508   many_cuts_one_quant_1
# 6511   many_cuts_one_quant_1
# 6512   many_cuts_one_quant_1
# 6514   many_cuts_one_quant_1
# 6518   many_cuts_one_quant_1
# 6519   many_cuts_one_quant_1
# 6520   many_cuts_one_quant_1
# 6521   many_cuts_one_quant_1
# 6522   many_cuts_one_quant_1
# 6523   many_cuts_one_quant_1
# 6524   many_cuts_one_quant_1
# 6525   many_cuts_one_quant_1
# 6527   many_cuts_one_quant_1
# 6529   many_cuts_one_quant_1
# 6531   many_cuts_one_quant_1
# 6532   many_cuts_one_quant_1
# 6533   many_cuts_one_quant_1
# 6535   many_cuts_one_quant_1
# 6538   many_cuts_one_quant_1
# 6540   many_cuts_one_quant_1
# 6543   many_cuts_one_quant_1
# 6544   many_cuts_one_quant_1
# 6545   many_cuts_one_quant_1
# 6546   many_cuts_one_quant_1
# 6547   many_cuts_one_quant_1
# 6549   many_cuts_one_quant_1
# 6550   many_cuts_one_quant_1
# 6552   many_cuts_one_quant_1
# 6555   many_cuts_one_quant_1
# 6556   many_cuts_one_quant_1
# 6557   many_cuts_one_quant_1
# 6558   many_cuts_one_quant_1
# 6559   many_cuts_one_quant_1
# 6560   many_cuts_one_quant_1
# 6561   many_cuts_one_quant_1
# 6562   many_cuts_one_quant_1
# 6563   many_cuts_one_quant_1
# 6565   many_cuts_one_quant_1
# 6566   many_cuts_one_quant_1
# 6567   many_cuts_one_quant_1
# 6568   many_cuts_one_quant_1
# 6569   many_cuts_one_quant_1
# 6571   many_cuts_one_quant_1
# 6576   many_cuts_one_quant_1
# 6577   many_cuts_one_quant_1
# 6578   many_cuts_one_quant_1
# 6580   many_cuts_one_quant_1
# 6581   many_cuts_one_quant_1
# 6582   many_cuts_one_quant_1
# 6583   many_cuts_one_quant_1
# 6584   many_cuts_one_quant_1
# 6585   many_cuts_one_quant_1
# 6586   many_cuts_one_quant_1
# 6587   many_cuts_one_quant_1
# 6588   many_cuts_one_quant_1
# 6591   many_cuts_one_quant_1
# 6592   many_cuts_one_quant_1
# 6594   many_cuts_one_quant_1
# 6596   many_cuts_one_quant_1
# 6597   many_cuts_one_quant_1
# 6599   many_cuts_one_quant_1
# 6602   many_cuts_one_quant_1
# 6603   many_cuts_one_quant_1
# 6604   many_cuts_one_quant_1
# 6605   many_cuts_one_quant_1
# 6606   many_cuts_one_quant_1
# 6607   many_cuts_one_quant_1
# 6608   many_cuts_one_quant_1
# 6609   many_cuts_one_quant_1
# 6610   many_cuts_one_quant_1
# 6611   many_cuts_one_quant_1
# 6612   many_cuts_one_quant_1
# 6613   many_cuts_one_quant_1
# 6614   many_cuts_one_quant_1
# 6615   many_cuts_one_quant_1
# 6617   many_cuts_one_quant_1
# 6621   many_cuts_one_quant_1
# 6622   many_cuts_one_quant_1
# 6623   many_cuts_one_quant_1
# 6626   many_cuts_one_quant_1
# 6628   many_cuts_one_quant_1
# 6629   many_cuts_one_quant_1
# 6630   many_cuts_one_quant_1
# 6631   many_cuts_one_quant_1
# 6632   many_cuts_one_quant_1
# 6633   many_cuts_one_quant_1
# 6635   many_cuts_one_quant_1
# 6637   many_cuts_one_quant_1
# 6638   many_cuts_one_quant_1
# 6639   many_cuts_one_quant_1
# 6640   many_cuts_one_quant_1
# 6641   many_cuts_one_quant_1
# 6642   many_cuts_one_quant_1
# 6643   many_cuts_one_quant_1
# 6644   many_cuts_one_quant_1
# 6646   many_cuts_one_quant_1
# 6647   many_cuts_one_quant_1
# 6648   many_cuts_one_quant_1
# 6649   many_cuts_one_quant_1
# 6650   many_cuts_one_quant_1
# 6651   many_cuts_one_quant_1
# 6652   many_cuts_one_quant_1
# 6656   many_cuts_one_quant_1
# 6658   many_cuts_one_quant_1
# 6659   many_cuts_one_quant_1
# 6660   many_cuts_one_quant_1
# 6661   many_cuts_one_quant_1
# 6662   many_cuts_one_quant_1
# 6665   many_cuts_one_quant_1
# 6666   many_cuts_one_quant_1
# 6668   many_cuts_one_quant_1
# 6669   many_cuts_one_quant_1
# 6670   many_cuts_one_quant_1
# 6673   many_cuts_one_quant_1
# 6675   many_cuts_one_quant_1
# 6676   many_cuts_one_quant_1
# 6681   many_cuts_one_quant_1
# 6683   many_cuts_one_quant_1
# 6684   many_cuts_one_quant_1
# 6685   many_cuts_one_quant_1
# 6687   many_cuts_one_quant_1
# 6688   many_cuts_one_quant_1
# 6689   many_cuts_one_quant_1
# 6690   many_cuts_one_quant_1
# 6691   many_cuts_one_quant_1
# 6692   many_cuts_one_quant_1
# 6695   many_cuts_one_quant_1
# 6696   many_cuts_one_quant_1
# 6698   many_cuts_one_quant_1
# 6699   many_cuts_one_quant_1
# 6700   many_cuts_one_quant_1
# 6701   many_cuts_one_quant_1
# 6702   many_cuts_one_quant_1
# 6703   many_cuts_one_quant_1
# 6704   many_cuts_one_quant_1
# 6705   many_cuts_one_quant_1
# 6706   many_cuts_one_quant_1
# 6709   many_cuts_one_quant_1
# 6710   many_cuts_one_quant_1
# 6712   many_cuts_one_quant_1
# 6714   many_cuts_one_quant_1
# 6715   many_cuts_one_quant_1
# 6716   many_cuts_one_quant_1
# 6718   many_cuts_one_quant_1
# 6720   many_cuts_one_quant_1
# 6723   many_cuts_one_quant_1
# 6724   many_cuts_one_quant_1
# 6725   many_cuts_one_quant_1
# 6726   many_cuts_one_quant_1
# 6730   many_cuts_one_quant_1
# 6731   many_cuts_one_quant_1
# 6734   many_cuts_one_quant_1
# 6735   many_cuts_one_quant_1
# 6736   many_cuts_one_quant_1
# 6740   many_cuts_one_quant_1
# 6742   many_cuts_one_quant_1
# 6743   many_cuts_one_quant_1
# 6744   many_cuts_one_quant_1
# 6745   many_cuts_one_quant_1
# 6746   many_cuts_one_quant_1
# 6750   many_cuts_one_quant_1
# 6751   many_cuts_one_quant_1
# 6753   many_cuts_one_quant_1
# 6756   many_cuts_one_quant_1
# 6759   many_cuts_one_quant_1
# 6762   many_cuts_one_quant_1
# 6765   many_cuts_one_quant_1
# 6766   many_cuts_one_quant_1
# 6770   many_cuts_one_quant_1
# 6777   many_cuts_one_quant_1
# 6778   many_cuts_one_quant_1
# 6783   many_cuts_one_quant_1
# 6788   many_cuts_one_quant_1
# 6789   many_cuts_one_quant_1
# 6790   many_cuts_one_quant_1
# 6795   many_cuts_one_quant_1
# 6797   many_cuts_one_quant_1
# 6798   many_cuts_one_quant_1
# 6799   many_cuts_one_quant_1
# 6800   many_cuts_one_quant_1
# 6801   many_cuts_one_quant_1
# 6802   many_cuts_one_quant_1
# 6806   many_cuts_one_quant_1
# 6807   many_cuts_one_quant_1
# 6810   many_cuts_one_quant_1
# 6811   many_cuts_one_quant_1
# 6813   many_cuts_one_quant_1
# ...                      ...
# 11033  many_cuts_one_quant_2
# 11034  many_cuts_one_quant_2
# 11037  many_cuts_one_quant_2
# 11038  many_cuts_one_quant_2
# 11040  many_cuts_one_quant_2
# 11042  many_cuts_one_quant_2
# 11043  many_cuts_one_quant_2
# 11044  many_cuts_one_quant_2
# 11050  many_cuts_one_quant_2
# 11051  many_cuts_one_quant_2
# 11052  many_cuts_one_quant_2
# 11053  many_cuts_one_quant_2
# 11054  many_cuts_one_quant_2
# 11055  many_cuts_one_quant_2
# 11056  many_cuts_one_quant_2
# 11057  many_cuts_one_quant_2
# 11058  many_cuts_one_quant_2
# 11062  many_cuts_one_quant_2
# 11063  many_cuts_one_quant_2
# 11064  many_cuts_one_quant_2
# 11065  many_cuts_one_quant_2
# 11067  many_cuts_one_quant_2
# 11070  many_cuts_one_quant_2
# 11072  many_cuts_one_quant_2
# 11073  many_cuts_one_quant_2
# 11077  many_cuts_one_quant_2
# 11079  many_cuts_one_quant_2
# 11083  many_cuts_one_quant_2
# 11084  many_cuts_one_quant_2
# 11085  many_cuts_one_quant_2
# 11086  many_cuts_one_quant_2
# 11088  many_cuts_one_quant_2
# 11089  many_cuts_one_quant_2
# 11090  many_cuts_one_quant_2
# 11091  many_cuts_one_quant_2
# 11095  many_cuts_one_quant_2
# 11097  many_cuts_one_quant_2
# 11099  many_cuts_one_quant_2
# 11100  many_cuts_one_quant_2
# 11102  many_cuts_one_quant_2
# 11103  many_cuts_one_quant_2
# 11105  many_cuts_one_quant_2
# 11106  many_cuts_one_quant_2
# 11108  many_cuts_one_quant_2
# 11109  many_cuts_one_quant_2
# 11111  many_cuts_one_quant_2
# 11112  many_cuts_one_quant_2
# 11115  many_cuts_one_quant_2
# 11118  many_cuts_one_quant_2
# 11120  many_cuts_one_quant_2
# 11121  many_cuts_one_quant_2
# 11122  many_cuts_one_quant_2
# 11124  many_cuts_one_quant_2
# 11125  many_cuts_one_quant_2
# 11128  many_cuts_one_quant_2
# 11129  many_cuts_one_quant_2
# 11132  many_cuts_one_quant_2
# 11133  many_cuts_one_quant_2
# 11134  many_cuts_one_quant_2
# 11135  many_cuts_one_quant_2
# 11136  many_cuts_one_quant_2
# 11137  many_cuts_one_quant_2
# 11138  many_cuts_one_quant_2
# 11140  many_cuts_one_quant_2
# 11144  many_cuts_one_quant_2
# 11146  many_cuts_one_quant_2
# 11148  many_cuts_one_quant_2
# 11151  many_cuts_one_quant_2
# 11152  many_cuts_one_quant_2
# 11153  many_cuts_one_quant_2
# 11156  many_cuts_one_quant_2
# 11158  many_cuts_one_quant_2
# 11159  many_cuts_one_quant_2
# 11160  many_cuts_one_quant_2
# 11162  many_cuts_one_quant_2
# 11163  many_cuts_one_quant_2
# 11165  many_cuts_one_quant_2
# 11170  many_cuts_one_quant_2
# 11171  many_cuts_one_quant_2
# 11173  many_cuts_one_quant_2
# 11174  many_cuts_one_quant_2
# 11175  many_cuts_one_quant_2
# 11177  many_cuts_one_quant_2
# 11178  many_cuts_one_quant_2
# 11179  many_cuts_one_quant_2
# 11180  many_cuts_one_quant_2
# 11181  many_cuts_one_quant_2
# 11183  many_cuts_one_quant_2
# 11185  many_cuts_one_quant_2
# 11187  many_cuts_one_quant_2
# 11188  many_cuts_one_quant_2
# 11189  many_cuts_one_quant_2
# 11190  many_cuts_one_quant_2
# 11192  many_cuts_one_quant_2
# 11193  many_cuts_one_quant_2
# 11196  many_cuts_one_quant_2
# 11197  many_cuts_one_quant_2
# 11199  many_cuts_one_quant_2
# 11202  many_cuts_one_quant_2
# 11207  many_cuts_one_quant_2
# 11208  many_cuts_one_quant_2
# 11210  many_cuts_one_quant_2
# 11211  many_cuts_one_quant_2
# 11212  many_cuts_one_quant_2
# 11213  many_cuts_one_quant_2
# 11216  many_cuts_one_quant_2
# 11217  many_cuts_one_quant_2
# 11221  many_cuts_one_quant_2
# 11222  many_cuts_one_quant_2
# 11223  many_cuts_one_quant_2
# 11226  many_cuts_one_quant_2
# 11227  many_cuts_one_quant_2
# 11228  many_cuts_one_quant_2
# 11229  many_cuts_one_quant_2
# 11232  many_cuts_one_quant_2
# 11234  many_cuts_one_quant_2
# 11235  many_cuts_one_quant_2
# 11236  many_cuts_one_quant_2
# 11237  many_cuts_one_quant_2
# 11238  many_cuts_one_quant_2
# 11242  many_cuts_one_quant_2
# 11243  many_cuts_one_quant_2
# 11246  many_cuts_one_quant_2
# 11247  many_cuts_one_quant_2
# 11250  many_cuts_one_quant_2
# 11251  many_cuts_one_quant_2
# 11252  many_cuts_one_quant_2
# 11253  many_cuts_one_quant_2
# 11254  many_cuts_one_quant_2
# 11255  many_cuts_one_quant_2
# 11258  many_cuts_one_quant_2
# 11259  many_cuts_one_quant_2
# 11261  many_cuts_one_quant_2
# 11263  many_cuts_one_quant_2
# 11268  many_cuts_one_quant_2
# 11269  many_cuts_one_quant_2
# 11270  many_cuts_one_quant_2
# 11274  many_cuts_one_quant_2
# 11277  many_cuts_one_quant_2
# 11278  many_cuts_one_quant_2
# 11279  many_cuts_one_quant_2
# 11288  many_cuts_one_quant_2
# 11289  many_cuts_one_quant_2
# 11290  many_cuts_one_quant_2
# 11293  many_cuts_one_quant_2
# 11294  many_cuts_one_quant_2
# 11295  many_cuts_one_quant_2
# 11296  many_cuts_one_quant_2
# 11303  many_cuts_one_quant_2
# 11305  many_cuts_one_quant_2
# 11306  many_cuts_one_quant_2
# 11307  many_cuts_one_quant_2
# 11308  many_cuts_one_quant_2
# 11309  many_cuts_one_quant_2
# 11311  many_cuts_one_quant_2
# 11312  many_cuts_one_quant_2
# 11313  many_cuts_one_quant_2
# 11314  many_cuts_one_quant_2
# 11315  many_cuts_one_quant_2
# 11316  many_cuts_one_quant_2
# 11317  many_cuts_one_quant_2
# 11318  many_cuts_one_quant_2
# 11319  many_cuts_one_quant_2
# 11322  many_cuts_one_quant_2
# 11323  many_cuts_one_quant_2
# 11325  many_cuts_one_quant_2
# 11328  many_cuts_one_quant_2
# 11331  many_cuts_one_quant_2
# 11333  many_cuts_one_quant_2
# 11336  many_cuts_one_quant_2
# 11339  many_cuts_one_quant_2
# 11343  many_cuts_one_quant_2
# 11345  many_cuts_one_quant_2
# 11349  many_cuts_one_quant_2
# 11350  many_cuts_one_quant_2
# 11351  many_cuts_one_quant_2
# 11353  many_cuts_one_quant_2
# 11356  many_cuts_one_quant_2
# 11358  many_cuts_one_quant_2
# 11363  many_cuts_one_quant_2
# 11364  many_cuts_one_quant_2
# 11365  many_cuts_one_quant_2
# 11366  many_cuts_one_quant_2
# 11368  many_cuts_one_quant_2
# 11369  many_cuts_one_quant_2
# 11371  many_cuts_one_quant_2
# 11375  many_cuts_one_quant_2
# 11376  many_cuts_one_quant_2
# 11377  many_cuts_one_quant_2
# 11379  many_cuts_one_quant_2
# 11380  many_cuts_one_quant_2
# 11381  many_cuts_one_quant_2
# 11382  many_cuts_one_quant_2
# 11383  many_cuts_one_quant_2
# 11384  many_cuts_one_quant_2
# 11386  many_cuts_one_quant_2
# 11387  many_cuts_one_quant_2
# 11388  many_cuts_one_quant_2
# 11389  many_cuts_one_quant_2
# 11390  many_cuts_one_quant_2
# 11392  many_cuts_one_quant_2
# 11394  many_cuts_one_quant_2
# 11397  many_cuts_one_quant_2
# 11398  many_cuts_one_quant_2
# 11399  many_cuts_one_quant_2
# 11400  many_cuts_one_quant_2
# 11401  many_cuts_one_quant_2
# 11402  many_cuts_one_quant_2
# 11404  many_cuts_one_quant_2
# 11406  many_cuts_one_quant_2
# 11409  many_cuts_one_quant_2
# 11412  many_cuts_one_quant_2
# 11413  many_cuts_one_quant_2
# 11414  many_cuts_one_quant_2
# 11415  many_cuts_one_quant_2
# 11416  many_cuts_one_quant_2
# 11417  many_cuts_one_quant_2
# 11418  many_cuts_one_quant_2
# 11419  many_cuts_one_quant_2
# 11421  many_cuts_one_quant_2
# 11422  many_cuts_one_quant_2
# 11423  many_cuts_one_quant_2
# 11425  many_cuts_one_quant_2
# 11429  many_cuts_one_quant_2
# 11431  many_cuts_one_quant_2
# 11432  many_cuts_one_quant_2
# 11433  many_cuts_one_quant_2
# 11434  many_cuts_one_quant_2
# 11435  many_cuts_one_quant_2
# 11436  many_cuts_one_quant_2
# 11439  many_cuts_one_quant_2
# 11443  many_cuts_one_quant_2
# 11445  many_cuts_one_quant_2
# 11446  many_cuts_one_quant_2
# 11447  many_cuts_one_quant_2
# 11448  many_cuts_one_quant_2
# 11449  many_cuts_one_quant_2
# 11450  many_cuts_one_quant_2
# 11451  many_cuts_one_quant_2
# 11452  many_cuts_one_quant_2
# 11456  many_cuts_one_quant_2
# 11461  many_cuts_one_quant_2
# 11463  many_cuts_one_quant_2
# 11465  many_cuts_one_quant_2
# 11467  many_cuts_one_quant_2
# 11468  many_cuts_one_quant_2
# 11469  many_cuts_one_quant_2
# 11470  many_cuts_one_quant_2
# 11471  many_cuts_one_quant_2
# 11472  many_cuts_one_quant_2
# 11473  many_cuts_one_quant_2
# 11475  many_cuts_one_quant_2
# 11479  many_cuts_one_quant_2
# 11481  many_cuts_one_quant_2
# 11482  many_cuts_one_quant_2
# 11484  many_cuts_one_quant_2
# 11487  many_cuts_one_quant_2
# 11488  many_cuts_one_quant_2
# 11489  many_cuts_one_quant_2
# 11490  many_cuts_one_quant_2
# 11491  many_cuts_one_quant_2
# 11493  many_cuts_one_quant_2
# 11494  many_cuts_one_quant_2
# 11495  many_cuts_one_quant_2
# 11496  many_cuts_one_quant_2
# 11498  many_cuts_one_quant_2
# 11499  many_cuts_one_quant_2
# 11501  many_cuts_one_quant_2
# 11502  many_cuts_one_quant_2
# 11504  many_cuts_one_quant_2
# 11505  many_cuts_one_quant_2
# 11507  many_cuts_one_quant_2
# 11508  many_cuts_one_quant_2
# 11509  many_cuts_one_quant_2
# 11510  many_cuts_one_quant_2
# 11512  many_cuts_one_quant_2
# 11513  many_cuts_one_quant_2
# 11514  many_cuts_one_quant_2
# 11516  many_cuts_one_quant_2
# 11518  many_cuts_one_quant_2
# 11519  many_cuts_one_quant_2
# 11520  many_cuts_one_quant_2
# 11521  many_cuts_one_quant_2
# 11522  many_cuts_one_quant_2
# 11523  many_cuts_one_quant_2
# 11524  many_cuts_one_quant_2
# 11526  many_cuts_one_quant_2
# 11527  many_cuts_one_quant_2
# 11529  many_cuts_one_quant_2
# 11532  many_cuts_one_quant_2
# 11533  many_cuts_one_quant_2
# 11536  many_cuts_one_quant_2
# 11537  many_cuts_one_quant_2
# 11539  many_cuts_one_quant_2
# 11542  many_cuts_one_quant_2
# 11544  many_cuts_one_quant_2
# 11545  many_cuts_one_quant_2
# 11546  many_cuts_one_quant_2
# 11548  many_cuts_one_quant_2
# 11550  many_cuts_one_quant_2
# 11551  many_cuts_one_quant_2
# 11552  many_cuts_one_quant_2
# 11557  many_cuts_one_quant_2
# 11559  many_cuts_one_quant_2
# 11560  many_cuts_one_quant_2
# 11562  many_cuts_one_quant_2
# 11565  many_cuts_one_quant_2
# 11567  many_cuts_one_quant_2
# 11568  many_cuts_one_quant_2
# 11569  many_cuts_one_quant_2
# 11570  many_cuts_one_quant_2
# 11571  many_cuts_one_quant_2
# 11576  many_cuts_one_quant_2
# 11581  many_cuts_one_quant_2
# 11582  many_cuts_one_quant_2
# 11588  many_cuts_one_quant_2
# 11589  many_cuts_one_quant_2
# 11590  many_cuts_one_quant_2
# 11591  many_cuts_one_quant_2
# 11593  many_cuts_one_quant_2
# 11595  many_cuts_one_quant_2
# 11598  many_cuts_one_quant_2
# 11600  many_cuts_one_quant_2
# 11601  many_cuts_one_quant_2
# 11603  many_cuts_one_quant_2
# 11605  many_cuts_one_quant_2
# 11606  many_cuts_one_quant_2
# 11607  many_cuts_one_quant_2
# 11611  many_cuts_one_quant_2
# 11614  many_cuts_one_quant_2
# 11617  many_cuts_one_quant_2
# 11622  many_cuts_one_quant_2
# 11623  many_cuts_one_quant_2
# 11624  many_cuts_one_quant_2
# 11625  many_cuts_one_quant_2
# 11627  many_cuts_one_quant_2
# 11628  many_cuts_one_quant_2
# 11629  many_cuts_one_quant_2
# 11630  many_cuts_one_quant_2
# 11631  many_cuts_one_quant_2
# 11632  many_cuts_one_quant_2
# 11633  many_cuts_one_quant_2
# 11634  many_cuts_one_quant_2
# 11637  many_cuts_one_quant_2
# 11639  many_cuts_one_quant_2
# 11640  many_cuts_one_quant_2
# 11641  many_cuts_one_quant_2
# 11647  many_cuts_one_quant_2
# 11648  many_cuts_one_quant_2
# 11649  many_cuts_one_quant_2
# 11650  many_cuts_one_quant_2
# 11651  many_cuts_one_quant_2
# 11652  many_cuts_one_quant_2
# 11656  many_cuts_one_quant_2
# 11657  many_cuts_one_quant_2
# 11658  many_cuts_one_quant_2
# 11661  many_cuts_one_quant_2
# 11664  many_cuts_one_quant_2
# 11666  many_cuts_one_quant_2
# 11667  many_cuts_one_quant_2
# 11668  many_cuts_one_quant_2
# 11671  many_cuts_one_quant_2
# 11672  many_cuts_one_quant_2
# 11674  many_cuts_one_quant_2
# 11675  many_cuts_one_quant_2
# 11680  many_cuts_one_quant_2
# 11681  many_cuts_one_quant_2
# 11684  many_cuts_one_quant_2
# 11685  many_cuts_one_quant_2
# 11688  many_cuts_one_quant_2
# 11689  many_cuts_one_quant_2
# 11694  many_cuts_one_quant_2
# 11695  many_cuts_one_quant_2
# 11698  many_cuts_one_quant_2
# 11699  many_cuts_one_quant_2
# 11700  many_cuts_one_quant_2
# 11702  many_cuts_one_quant_2
# 11703  many_cuts_one_quant_2
# 11704  many_cuts_one_quant_2
# 11705  many_cuts_one_quant_2
# 11706  many_cuts_one_quant_2
# 11711  many_cuts_one_quant_2
# 11712  many_cuts_one_quant_2
# 11713  many_cuts_one_quant_2
# 11714  many_cuts_one_quant_2
# 11716  many_cuts_one_quant_2
# 11717  many_cuts_one_quant_2
# 11718  many_cuts_one_quant_2
# 11719  many_cuts_one_quant_2
# 11720  many_cuts_one_quant_2
# 11722  many_cuts_one_quant_2
# 11723  many_cuts_one_quant_2
# 11724  many_cuts_one_quant_2
# 11725  many_cuts_one_quant_2
# 11726  many_cuts_one_quant_2
# 11727  many_cuts_one_quant_2
# 11728  many_cuts_one_quant_2
# 11729  many_cuts_one_quant_2
# 11730  many_cuts_one_quant_2
# 11731  many_cuts_one_quant_2
# 11732  many_cuts_one_quant_2
# 11733  many_cuts_one_quant_2
# 11738  many_cuts_one_quant_2
# 11739  many_cuts_one_quant_2
# 11741  many_cuts_one_quant_2
# 11743  many_cuts_one_quant_2
# 11745  many_cuts_one_quant_2
# 11746  many_cuts_one_quant_2
# 11750  many_cuts_one_quant_2
# 11751  many_cuts_one_quant_2
# 11753  many_cuts_one_quant_2
# 11754  many_cuts_one_quant_2
# 11756  many_cuts_one_quant_2
# 11757  many_cuts_one_quant_2
# 11758  many_cuts_one_quant_2
# 11760  many_cuts_one_quant_2
# 11761  many_cuts_one_quant_2
# 11767  many_cuts_one_quant_2
# 11772  many_cuts_one_quant_2
# 11773  many_cuts_one_quant_2
# 11778  many_cuts_one_quant_2
# 11779  many_cuts_one_quant_2
# 11781  many_cuts_one_quant_2
# 11783  many_cuts_one_quant_2
# 11784  many_cuts_one_quant_2
# 11787  many_cuts_one_quant_2
# 11788  many_cuts_one_quant_2
# 11790  many_cuts_one_quant_2
# 11791  many_cuts_one_quant_2
# 11798  many_cuts_one_quant_2
# 11800  many_cuts_one_quant_2
# 11802  many_cuts_one_quant_2
# 11803  many_cuts_one_quant_2
# 11804  many_cuts_one_quant_2
# 11805  many_cuts_one_quant_2
# 11808  many_cuts_one_quant_2
# 11809  many_cuts_one_quant_2
# 11811  many_cuts_one_quant_2
# 11813  many_cuts_one_quant_2
# 11818  many_cuts_one_quant_2
# 11820  many_cuts_one_quant_2
# 11821  many_cuts_one_quant_2
# 11822  many_cuts_one_quant_2
# 11823  many_cuts_one_quant_2
# 11824  many_cuts_one_quant_2
# 11826  many_cuts_one_quant_2
# 11829  many_cuts_one_quant_2
# 11830  many_cuts_one_quant_2
# 11831  many_cuts_one_quant_2
# 11832  many_cuts_one_quant_2
# 11833  many_cuts_one_quant_2
# 11837  many_cuts_one_quant_2
# 11840  many_cuts_one_quant_2
# 11841  many_cuts_one_quant_2
# 11842  many_cuts_one_quant_2
# 11845  many_cuts_one_quant_2
# 11847  many_cuts_one_quant_2
# 11848  many_cuts_one_quant_2
# 11849  many_cuts_one_quant_2
# 11850  many_cuts_one_quant_2
# 11851  many_cuts_one_quant_2
# 11852  many_cuts_one_quant_2
# 11854  many_cuts_one_quant_2
# 11855  many_cuts_one_quant_2
# 11856  many_cuts_one_quant_2
# 11858  many_cuts_one_quant_2
# 11860  many_cuts_one_quant_2
# 11861  many_cuts_one_quant_2
# 11863  many_cuts_one_quant_2
# 11864  many_cuts_one_quant_2
# 11866  many_cuts_one_quant_2
# 11867  many_cuts_one_quant_2
# 11868  many_cuts_one_quant_2
# 11869  many_cuts_one_quant_2
# 11871  many_cuts_one_quant_2
# 11873  many_cuts_one_quant_2
# 11874  many_cuts_one_quant_2
# 11875  many_cuts_one_quant_2
# 11877  many_cuts_one_quant_2
# 11882  many_cuts_one_quant_2
# 11883  many_cuts_one_quant_2
# 11886  many_cuts_one_quant_2
# 11887  many_cuts_one_quant_2
# 11888  many_cuts_one_quant_2
# 11889  many_cuts_one_quant_2
# 11891  many_cuts_one_quant_2
# 11893  many_cuts_one_quant_2
# 11894  many_cuts_one_quant_2
# 11896  many_cuts_one_quant_2
# 11897  many_cuts_one_quant_2
# 11903      one_cut_one_quant
# 12045     one_cut_many_quant
# 12186  many_cuts_one_quant_1
# 12187  many_cuts_one_quant_1
# 12188  many_cuts_one_quant_1
# 12190  many_cuts_one_quant_1
# 12202  many_cuts_one_quant_1
# 12328  many_cuts_one_quant_2
# 12329  many_cuts_one_quant_2
# 12332  many_cuts_one_quant_2
#
#                                                     file  \
# 69                  UniformAssociativity3ExampleProof(1)
# 139                 UniformAssociativity3ExampleProof(1)
# 140                                LinearExampleProof(1)
# 141                                LinearExampleProof(2)
# 142                                LinearExampleProof(3)
# 155                               LinearExampleProof(16)
# 156                        SquareDiagonalExampleProof(1)
# 157                        SquareDiagonalExampleProof(2)
# 165                       SquareDiagonalExampleProof(10)
# 166                           SquareEdgesExampleProof(1)
# 174                           SquareEdgesExampleProof(9)
# 175                       SquareEdges2DimExampleProof(1)
# 176                       SquareEdges2DimExampleProof(2)
# 177                       SquareEdges2DimExampleProof(3)
# 180                       SquareEdges2DimExampleProof(6)
# 181                              LinearEqExampleProof(1)
# 194                           SumOfOnesF2ExampleProof(1)
# 197                           SumOfOnesF2ExampleProof(4)
# 198                            SumOfOnesFExampleProof(1)
# 201                            SumOfOnesFExampleProof(4)
# 203                             SumOfOnesExampleProof(2)
# 205                             SumOfOnesExampleProof(4)
# 206                 UniformAssociativity3ExampleProof(1)
# 207                 UniformAssociativity3ExampleProof(2)
# 208                                LinearExampleProof(1)
# 209                                LinearExampleProof(2)
# 210                                LinearExampleProof(3)
# 221                        SquareDiagonalExampleProof(1)
# 230                           SquareEdgesExampleProof(1)
# 238                       SquareEdges2DimExampleProof(1)
# 239                       SquareEdges2DimExampleProof(2)
# 240                       SquareEdges2DimExampleProof(3)
# 242                       SquareEdges2DimExampleProof(5)
# 243                              LinearEqExampleProof(1)
# 244                              LinearEqExampleProof(2)
# 252                           SumOfOnesF2ExampleProof(1)
# 255                           SumOfOnesF2ExampleProof(4)
# 256                            SumOfOnesFExampleProof(1)
# 259                            SumOfOnesFExampleProof(4)
# 265                 UniformAssociativity3ExampleProof(1)
# 450    testing/TSTP/prover9/SYN/SYN052-1/Prover9---11...
# 605    testing/TSTP/prover9/SWV/SWV757-1/Prover9---11...
# 608    testing/TSTP/prover9/SEU/SEU369+1/Prover9---11...
# 986    testing/TSTP/prover9/KLE/KLE021+4/Prover9---11...
# 1046   testing/TSTP/prover9/GRP/GRP135-2.002/Prover9-...
# 1092   testing/TSTP/prover9/KLE/KLE021+3/Prover9---11...
# 1307   testing/TSTP/prover9/SWV/SWV743-1/Prover9---11...
# 1647   testing/TSTP/prover9/KLE/KLE025+2/Prover9---11...
# 1757   testing/TSTP/prover9/SWV/SWV308-2/Prover9---11...
# 2059   testing/TSTP/prover9/SWV/SWV742-1/Prover9---11...
# 2235   testing/TSTP/prover9/LAT/LAT327+1/Prover9---11...
# 2294   testing/TSTP/prover9/SYN/SYN156-1/Prover9---11...
# 2365   testing/TSTP/prover9/KLE/KLE022+4/Prover9---11...
# 2458   testing/TSTP/prover9/PLA/PLA002-2/Prover9---11...
# 2894   testing/TSTP/prover9/LCL/LCL224-1/Prover9---11...
# 3038   testing/TSTP/prover9/GRP/GRP135-1.002/Prover9-...
# 3359   testing/TSTP/prover9/SYN/SYN052-1/Prover9---11...
# 3955   testing/TSTP/prover9/GRP/GRP135-2.002/Prover9-...
# 5144   testing/TSTP/prover9/LAT/LAT327+1/Prover9---11...
# 5203   testing/TSTP/prover9/SYN/SYN156-1/Prover9---11...
# 5367   testing/TSTP/prover9/PLA/PLA002-2/Prover9---11...
# 5947   testing/TSTP/prover9/GRP/GRP135-1.002/Prover9-...
# 6084   testing/TSTP/prover9/COL/COL091-1/Prover9---11...
# 6086   testing/TSTP/prover9/FLD/FLD065-1/Prover9---11...
# 6088   testing/TSTP/prover9/GEO/GEO170+2/Prover9---11...
# 6090   testing/TSTP/prover9/SWV/SWV480+1/Prover9---11...
# 6093   testing/TSTP/prover9/NUM/NUM566+1/Prover9---11...
# 6094   testing/TSTP/prover9/KRS/KRS163+1/Prover9---11...
# 6095   testing/TSTP/prover9/NUM/NUM317+1/Prover9---11...
# 6097   testing/TSTP/prover9/SYN/SYN940+1/Prover9---11...
# 6098   testing/TSTP/prover9/SYN/SYN668-1/Prover9---11...
# 6099   testing/TSTP/prover9/NUM/NUM926+1/Prover9---11...
# 6100   testing/TSTP/prover9/GRP/GRP181-3/Prover9---11...
# 6101   testing/TSTP/prover9/SWV/SWV230+1/Prover9---11...
# 6402   testing/TSTP/prover9/NUM/NUM496+3/Prover9---11...
# 6403   testing/TSTP/prover9/LCL/LCL237-1/Prover9---11...
# 6405   testing/TSTP/prover9/SWV/SWV841-1/Prover9---11...
# 6406   testing/TSTP/prover9/SYN/SYN171-1/Prover9---11...
# 6407   testing/TSTP/prover9/SET/SET918+1/Prover9---11...
# 6408   testing/TSTP/prover9/GEO/GEO213+2/Prover9---11...
# 6409   testing/TSTP/prover9/COM/COM003+2/Prover9---11...
# 6411   testing/TSTP/prover9/SWB/SWB004+2/Prover9---11...
# 6412   testing/TSTP/prover9/MGT/MGT022-2/Prover9---11...
# 6415   testing/TSTP/prover9/GEO/GEO209+2/Prover9---11...
# 6416   testing/TSTP/prover9/GRP/GRP128-1.003/Prover9-...
# 6417   testing/TSTP/prover9/ROB/ROB010-1/Prover9---11...
# 6419   testing/TSTP/prover9/COL/COL027-1/Prover9---11...
# 6421   testing/TSTP/prover9/SET/SET027-6/Prover9---11...
# 6424   testing/TSTP/prover9/LCL/LCL430-2/Prover9---11...
# 6425   testing/TSTP/prover9/SWV/SWV056+1/Prover9---11...
# 6428   testing/TSTP/prover9/PUZ/PUZ035-3/Prover9---11...
# ...
# 11294     cutintro_uncompressible       ok
# 11295     cutintro_uncompressible       ok
# 11296     cutintro_uncompressible       ok
# 11303     cutintro_uncompressible       ok
# 11305     cutintro_uncompressible       ok
# 11306     cutintro_uncompressible       ok
# 11307     cutintro_uncompressible       ok
# 11308     cutintro_uncompressible       ok
# 11309     cutintro_uncompressible       ok
# 11311     cutintro_uncompressible       ok
# 11312     cutintro_uncompressible       ok
# 11313     cutintro_uncompressible       ok
# 11314     cutintro_uncompressible       ok
# 11315     cutintro_uncompressible       ok
# 11316     cutintro_uncompressible       ok
# 11317     cutintro_uncompressible       ok
# 11318     cutintro_uncompressible       ok
# 11319     cutintro_uncompressible       ok
# 11322     cutintro_uncompressible       ok
# 11323     cutintro_uncompressible       ok
# 11325     cutintro_uncompressible       ok
# 11328     cutintro_uncompressible       ok
# 11331     cutintro_uncompressible       ok
# 11333     cutintro_uncompressible       ok
# 11336     cutintro_uncompressible       ok
# 11339     cutintro_uncompressible       ok
# 11343     cutintro_uncompressible       ok
# 11345              prcons_timeout       ok
# 11349     cutintro_uncompressible       ok
# 11350     cutintro_uncompressible       ok
# 11351     cutintro_uncompressible       ok
# 11353     cutintro_uncompressible       ok
# 11356     cutintro_uncompressible       ok
# 11358     cutintro_uncompressible       ok
# 11363     cutintro_uncompressible       ok
# 11364     cutintro_uncompressible       ok
# 11365     cutintro_uncompressible       ok
# 11366     cutintro_uncompressible       ok
# 11368     cutintro_uncompressible       ok
# 11369     cutintro_uncompressible       ok
# 11371     cutintro_uncompressible       ok
# 11375     cutintro_uncompressible       ok
# 11376     cutintro_uncompressible       ok
# 11377     cutintro_uncompressible       ok
# 11379     cutintro_uncompressible       ok
# 11380     cutintro_uncompressible       ok
# 11381     cutintro_uncompressible       ok
# 11382     cutintro_uncompressible       ok
# 11383     cutintro_uncompressible       ok
# 11384     cutintro_uncompressible       ok
# 11386     cutintro_uncompressible       ok
# 11387     cutintro_uncompressible       ok
# 11388     cutintro_uncompressible       ok
# 11389     cutintro_uncompressible       ok
# 11390     cutintro_uncompressible       ok
# 11392     cutintro_uncompressible       ok
# 11394     cutintro_uncompressible       ok
# 11397     cutintro_uncompressible       ok
# 11398     cutintro_uncompressible       ok
# 11399     cutintro_uncompressible       ok
# 11400     cutintro_uncompressible       ok
# 11401     cutintro_uncompressible       ok
# 11402     cutintro_uncompressible       ok
# 11404     cutintro_uncompressible       ok
# 11406     cutintro_uncompressible       ok
# 11409              prcons_timeout       ok
# 11412     cutintro_uncompressible       ok
# 11413     cutintro_uncompressible       ok
# 11414     cutintro_uncompressible       ok
# 11415     cutintro_uncompressible       ok
# 11416     cutintro_uncompressible       ok
# 11417     cutintro_uncompressible       ok
# 11418     cutintro_uncompressible       ok
# 11419     cutintro_uncompressible       ok
# 11421     cutintro_uncompressible       ok
# 11422     cutintro_uncompressible       ok
# 11423     cutintro_uncompressible       ok
# 11425     cutintro_uncompressible       ok
# 11429     cutintro_uncompressible       ok
# 11431     cutintro_uncompressible       ok
# 11432              prcons_timeout       ok
# 11433     cutintro_uncompressible       ok
# 11434     cutintro_uncompressible       ok
# 11435     cutintro_uncompressible       ok
# 11436     cutintro_uncompressible       ok
# 11439     cutintro_uncompressible       ok
# 11443     cutintro_uncompressible       ok
# 11445              prcons_timeout       ok
# 11446     cutintro_uncompressible       ok
# 11447     cutintro_uncompressible       ok
# 11448     cutintro_uncompressible       ok
# 11449     cutintro_uncompressible       ok
# 11450     cutintro_uncompressible       ok
# 11451     cutintro_uncompressible       ok
# 11452     cutintro_uncompressible       ok
# 11456     cutintro_uncompressible       ok
# 11461     cutintro_uncompressible       ok
# 11463     cutintro_uncompressible       ok
# 11465     cutintro_uncompressible       ok
# 11467     cutintro_uncompressible       ok
# 11468     cutintro_uncompressible       ok
# 11469     cutintro_uncompressible       ok
# 11470     cutintro_uncompressible       ok
# 11471              prcons_timeout       ok
# 11472     cutintro_uncompressible       ok
# 11473     cutintro_uncompressible       ok
# 11475     cutintro_uncompressible       ok
# 11479     cutintro_uncompressible       ok
# 11481     cutintro_uncompressible       ok
# 11482     cutintro_uncompressible       ok
# 11484     cutintro_uncompressible       ok
# 11487     cutintro_uncompressible       ok
# 11488     cutintro_uncompressible       ok
# 11489     cutintro_uncompressible       ok
# 11490              prcons_timeout       ok
# 11491     cutintro_uncompressible       ok
# 11493     cutintro_uncompressible       ok
# 11494     cutintro_uncompressible       ok
# 11495     cutintro_uncompressible       ok
# 11496     cutintro_uncompressible       ok
# 11498     cutintro_uncompressible       ok
# 11499              prcons_timeout       ok
# 11501     cutintro_uncompressible       ok
# 11502     cutintro_uncompressible       ok
# 11504     cutintro_uncompressible       ok
# 11505     cutintro_uncompressible       ok
# 11507     cutintro_uncompressible       ok
# 11508     cutintro_uncompressible       ok
# 11509     cutintro_uncompressible       ok
# 11510     cutintro_uncompressible       ok
# 11512     cutintro_uncompressible       ok
# 11513     cutintro_uncompressible       ok
# 11514              prcons_timeout       ok
# 11516     cutintro_uncompressible       ok
# 11518     cutintro_uncompressible       ok
# 11519     cutintro_uncompressible       ok
# 11520     cutintro_uncompressible       ok
# 11521     cutintro_uncompressible       ok
# 11522     cutintro_uncompressible       ok
# 11523     cutintro_uncompressible       ok
# 11524     cutintro_uncompressible       ok
# 11526     cutintro_uncompressible       ok
# 11527     cutintro_uncompressible       ok
# 11529     cutintro_uncompressible       ok
# 11532     cutintro_uncompressible       ok
# 11533     cutintro_uncompressible       ok
# 11536     cutintro_uncompressible       ok
# 11537     cutintro_uncompressible       ok
# 11539     cutintro_uncompressible       ok
# 11542     cutintro_uncompressible       ok
# 11544     cutintro_uncompressible       ok
# 11545     cutintro_uncompressible       ok
# 11546     cutintro_uncompressible       ok
# 11548     cutintro_uncompressible       ok
# 11550     cutintro_uncompressible       ok
# 11551     cutintro_uncompressible       ok
# 11552              prcons_timeout       ok
# 11557     cutintro_uncompressible       ok
# 11559     cutintro_uncompressible       ok
# 11560     cutintro_uncompressible       ok
# 11562     cutintro_uncompressible       ok
# 11565     cutintro_uncompressible       ok
# 11567     cutintro_uncompressible       ok
# 11568     cutintro_uncompressible       ok
# 11569     cutintro_uncompressible       ok
# 11570     cutintro_uncompressible       ok
# 11571     cutintro_uncompressible       ok
# 11576     cutintro_uncompressible       ok
# 11581     cutintro_uncompressible       ok
# 11582              prcons_timeout       ok
# 11588     cutintro_uncompressible       ok
# 11589     cutintro_uncompressible       ok
# 11590     cutintro_uncompressible       ok
# 11591     cutintro_uncompressible       ok
# 11593     cutintro_uncompressible       ok
# 11595     cutintro_uncompressible       ok
# 11598     cutintro_uncompressible       ok
# 11600     cutintro_uncompressible       ok
# 11601     cutintro_uncompressible       ok
# 11603     cutintro_uncompressible       ok
# 11605     cutintro_uncompressible       ok
# 11606     cutintro_uncompressible       ok
# 11607     cutintro_uncompressible       ok
# 11611     cutintro_uncompressible       ok
# 11614     cutintro_uncompressible       ok
# 11617     cutintro_uncompressible       ok
# 11622     cutintro_uncompressible       ok
# 11623     cutintro_uncompressible       ok
# 11624     cutintro_uncompressible       ok
# 11625     cutintro_uncompressible       ok
# 11627     cutintro_uncompressible       ok
# 11628     cutintro_uncompressible       ok
# 11629     cutintro_uncompressible       ok
# 11630     cutintro_uncompressible       ok
# 11631     cutintro_uncompressible       ok
# 11632     cutintro_uncompressible       ok
# 11633     cutintro_uncompressible       ok
# 11634     cutintro_uncompressible       ok
# 11637     cutintro_uncompressible       ok
# 11639     cutintro_uncompressible       ok
# 11640     cutintro_uncompressible       ok
# 11641     cutintro_uncompressible       ok
# 11647     cutintro_uncompressible       ok
# 11648     cutintro_uncompressible       ok
# 11649     cutintro_uncompressible       ok
# 11650              prcons_timeout       ok
# 11651     cutintro_uncompressible       ok
# 11652     cutintro_uncompressible       ok
# 11656     cutintro_uncompressible       ok
# 11657     cutintro_uncompressible       ok
# 11658     cutintro_uncompressible       ok
# 11661     cutintro_uncompressible       ok
# 11664     cutintro_uncompressible       ok
# 11666     cutintro_uncompressible       ok
# 11667     cutintro_uncompressible       ok
# 11668     cutintro_uncompressible       ok
# 11671     cutintro_uncompressible       ok
# 11672     cutintro_uncompressible       ok
# 11674     cutintro_uncompressible       ok
# 11675     cutintro_uncompressible       ok
# 11680     cutintro_uncompressible       ok
# 11681     cutintro_uncompressible       ok
# 11684     cutintro_uncompressible       ok
# 11685     cutintro_uncompressible       ok
# 11688     cutintro_uncompressible       ok
# 11689     cutintro_uncompressible       ok
# 11694              prcons_timeout       ok
# 11695     cutintro_uncompressible       ok
# 11698     cutintro_uncompressible       ok
# 11699     cutintro_uncompressible       ok
# 11700     cutintro_uncompressible       ok
# 11702     cutintro_uncompressible       ok
# 11703     cutintro_uncompressible       ok
# 11704     cutintro_uncompressible       ok
# 11705     cutintro_uncompressible       ok
# 11706     cutintro_uncompressible       ok
# 11711     cutintro_uncompressible       ok
# 11712     cutintro_uncompressible       ok
# 11713     cutintro_uncompressible       ok
# 11714              prcons_timeout       ok
# 11716     cutintro_uncompressible       ok
# 11717     cutintro_uncompressible       ok
# 11718     cutintro_uncompressible       ok
# 11719     cutintro_uncompressible       ok
# 11720     cutintro_uncompressible       ok
# 11722     cutintro_uncompressible       ok
# 11723     cutintro_uncompressible       ok
# 11724     cutintro_uncompressible       ok
# 11725     cutintro_uncompressible       ok
# 11726              prcons_timeout       ok
# 11727     cutintro_uncompressible       ok
# 11728     cutintro_uncompressible       ok
# 11729     cutintro_uncompressible       ok
# 11730     cutintro_uncompressible       ok
# 11731     cutintro_uncompressible       ok
# 11732     cutintro_uncompressible       ok
# 11733     cutintro_uncompressible       ok
# 11738     cutintro_uncompressible       ok
# 11739     cutintro_uncompressible       ok
# 11741     cutintro_uncompressible       ok
# 11743     cutintro_uncompressible       ok
# 11745              prcons_timeout       ok
# 11746     cutintro_uncompressible       ok
# 11750     cutintro_uncompressible       ok
# 11751              prcons_timeout       ok
# 11753     cutintro_uncompressible       ok
# 11754     cutintro_uncompressible       ok
# 11756     cutintro_uncompressible       ok
# 11757     cutintro_uncompressible       ok
# 11758     cutintro_uncompressible       ok
# 11760     cutintro_uncompressible       ok
# 11761     cutintro_uncompressible       ok
# 11767     cutintro_uncompressible       ok
# 11772     cutintro_uncompressible       ok
# 11773     cutintro_uncompressible       ok
# 11778     cutintro_uncompressible       ok
# 11779     cutintro_uncompressible       ok
# 11781     cutintro_uncompressible       ok
# 11783     cutintro_uncompressible       ok
# 11784     cutintro_uncompressible       ok
# 11787     cutintro_uncompressible       ok
# 11788     cutintro_uncompressible       ok
# 11790     cutintro_uncompressible       ok
# 11791     cutintro_uncompressible       ok
# 11798     cutintro_uncompressible       ok
# 11800     cutintro_uncompressible       ok
# 11802     cutintro_uncompressible       ok
# 11803     cutintro_uncompressible       ok
# 11804     cutintro_uncompressible       ok
# 11805     cutintro_uncompressible       ok
# 11808     cutintro_uncompressible       ok
# 11809     cutintro_uncompressible       ok
# 11811     cutintro_uncompressible       ok
# 11813     cutintro_uncompressible       ok
# 11818     cutintro_uncompressible       ok
# 11820     cutintro_uncompressible       ok
# 11821     cutintro_uncompressible       ok
# 11822     cutintro_uncompressible       ok
# 11823     cutintro_uncompressible       ok
# 11824     cutintro_uncompressible       ok
# 11826     cutintro_uncompressible       ok
# 11829     cutintro_uncompressible       ok
# 11830     cutintro_uncompressible       ok
# 11831     cutintro_uncompressible       ok
# 11832     cutintro_uncompressible       ok
# 11833     cutintro_uncompressible       ok
# 11837     cutintro_uncompressible       ok
# 11840     cutintro_uncompressible       ok
# 11841     cutintro_uncompressible       ok
# 11842     cutintro_uncompressible       ok
# 11845     cutintro_uncompressible       ok
# 11847     cutintro_uncompressible       ok
# 11848     cutintro_uncompressible       ok
# 11849     cutintro_uncompressible       ok
# 11850     cutintro_uncompressible       ok
# 11851     cutintro_uncompressible       ok
# 11852     cutintro_uncompressible       ok
# 11854     cutintro_uncompressible       ok
# 11855     cutintro_uncompressible       ok
# 11856     cutintro_uncompressible       ok
# 11858     cutintro_uncompressible       ok
# 11860     cutintro_uncompressible       ok
# 11861     cutintro_uncompressible       ok
# 11863     cutintro_uncompressible       ok
# 11864     cutintro_uncompressible       ok
# 11866     cutintro_uncompressible       ok
# 11867     cutintro_uncompressible       ok
# 11868     cutintro_uncompressible       ok
# 11869     cutintro_uncompressible       ok
# 11871     cutintro_uncompressible       ok
# 11873     cutintro_uncompressible       ok
# 11874     cutintro_uncompressible       ok
# 11875     cutintro_uncompressible       ok
# 11877     cutintro_uncompressible       ok
# 11882     cutintro_uncompressible       ok
# 11883     cutintro_uncompressible       ok
# 11886     cutintro_uncompressible       ok
# 11887     cutintro_uncompressible       ok
# 11888     cutintro_uncompressible       ok
# 11889     cutintro_uncompressible       ok
# 11891     cutintro_uncompressible       ok
# 11893     cutintro_uncompressible       ok
# 11894     cutintro_uncompressible       ok
# 11896     cutintro_uncompressible       ok
# 11897     cutintro_uncompressible       ok
# 11903              prcons_timeout       ok
# 12045                 sol_timeout       ok
# 12186     cutintro_uncompressible       ok
# 12187              prcons_timeout       ok
# 12188     grammar_finding_timeout       ok
# 12190              prcons_timeout       ok
# 12202     grammar_finding_timeout       ok
# 12328     cutintro_uncompressible       ok
# 12329              prcons_timeout       ok
# 12332     grammar_finding_timeout       ok
#
# [3463 rows x 4 columns]

# %%
# Separating data by method and database
data_ocoq_examples = data[(data.method == 'one_cut_one_quant') & (data.db == 0)]
data_ocoq_prover9 = data[(data.method == 'one_cut_one_quant') & (data.db == 1)]
data_ocoq_verit = data[(data.method == 'one_cut_one_quant') & (data.db == 2)]
data_ocmq_examples = data[(data.method == 'one_cut_many_quant') & (data.db == 0)]
data_ocmq_prover9 = data[(data.method == 'one_cut_many_quant') & (data.db == 1)]
data_ocmq_verit = data[(data.method == 'one_cut_many_quant') & (data.db == 2)]
data_mcoq1_examples = data[(data.method == 'many_cuts_one_quant_1') & (data.db == 0)]
data_mcoq1_prover9 = data[(data.method == 'many_cuts_one_quant_1') & (data.db == 1)]
data_mcoq1_verit = data[(data.method == 'many_cuts_one_quant_1') & (data.db == 2)]
data_mcoq2_examples = data[(data.method == 'many_cuts_one_quant_2') & (data.db == 0)]
data_mcoq2_prover9 = data[(data.method == 'many_cuts_one_quant_2') & (data.db == 1)]
data_mcoq2_verit = data[(data.method == 'many_cuts_one_quant_2') & (data.db == 2)]

print("=== Number of tests per database and method:\n")

print("Proof examples - one cut one quantifier:", data_ocoq_examples.shape[0])
print("Proof examples - one cut many quantifiers:", data_ocmq_examples.shape[0])
print("Proof examples - many (1) cuts one quantifier:", data_mcoq1_examples.shape[0])
print("Proof examples - many (2) cuts one quantifier:", data_mcoq1_examples.shape[0])
print()

print("Prover9 - one cut one quantifier:", data_ocoq_prover9.shape[0])
print("Prover9 - one cut many quantifiers:", data_ocmq_prover9.shape[0])
print("Prover9 - many (1) cuts one quantifier:", data_mcoq1_prover9.shape[0])
print("Prover9 - many (2) cuts one quantifier:", data_mcoq1_prover9.shape[0])
print()

print("VeriT - one cut one quantifier:", data_ocoq_verit.shape[0])
print("VeriT - one cut many quantifiers:", data_ocmq_verit.shape[0])
print("VeriT - many (1) cuts one quantifier:", data_mcoq1_verit.shape[0])
print("VeriT - many (2) cuts one quantifier:", data_mcoq1_verit.shape[0])
print()
# Out:
# === Number of tests per database and method:
#
# Proof examples - one cut one quantifier: 70
# Proof examples - one cut many quantifiers: 70
# Proof examples - many (1) cuts one quantifier: 68
# Proof examples - many (2) cuts one quantifier: 68
#
# Prover9 - one cut one quantifier: 2909
# Prover9 - one cut many quantifiers: 2909
# Prover9 - many (1) cuts one quantifier: 2909
# Prover9 - many (2) cuts one quantifier: 2909
#
# VeriT - one cut one quantifier: 142
# VeriT - one cut many quantifiers: 142
# VeriT - many (1) cuts one quantifier: 142
# VeriT - many (2) cuts one quantifier: 142

# %%
status = data.groupby(['status']).size()

labellst = ['ok', 
            'parsing_timeout', 
            'delta_table_computation_timeout',
            'grammar_finding_timeout',
            'cutintro_uncompressible',
            'prcons_timeout',
            'sol_timeout',
            'lk_rule_creation_exception',
            'cutintro_ehs_unprovable',
            'cutintro_other_exception'
            ]

colorlst = ['lime',
            'red',
            'skyblue',
            'royalblue',
            'gold',
            'darkred',
            'darkorange',
            'yellow',
            'gray',
            'fuchsia'
            ]

values = [status[l] if l in status else 0 for l in labellst]

handles = [mpatches.Patch(color=c, label=l) for c, l in zip(colorlst, labellst)]

plt.figure(figsize=(15,8))
plt.axis('equal')
plt.pie(values, autopct='%1.1f%%', shadow=True, colors=colorlst, radius=1.0, pctdistance=0.8)
plt.title("Return status: full set", size=25, y=1.1)
plt.legend(handles, labellst, loc = 'lower right')

# %%
status_ocoq_examples = data_ocoq_examples.groupby(['status']).size()
status_ocmq_examples = data_ocmq_examples.groupby(['status']).size()
status_mcoq1_examples = data_mcoq1_examples.groupby(['status']).size()
status_mcoq2_examples = data_mcoq2_examples.groupby(['status']).size()

status_ocoq_prover9 = data_ocoq_prover9.groupby(['status']).size()
status_ocmq_prover9 = data_ocmq_prover9.groupby(['status']).size()
status_mcoq1_prover9 = data_mcoq1_prover9.groupby(['status']).size()
status_mcoq2_prover9 = data_mcoq2_prover9.groupby(['status']).size()

status_ocoq_verit = data_ocoq_verit.groupby(['status']).size()
status_ocmq_verit = data_ocmq_verit.groupby(['status']).size()
status_mcoq1_verit = data_mcoq1_verit.groupby(['status']).size()
status_mcoq2_verit = data_mcoq2_verit.groupby(['status']).size()

def getValues (status):
    return [status[l] if l in status else 0 for l in labellst]

plt.figure(1, figsize=(17,17))
plt.subplots_adjust(wspace=0.25, hspace=0.20, top=0.85, bottom=0.05)
plt.figlegend(handles, labellst, loc='lower left')
plt.suptitle("Return Status", fontsize=24, fontweight='bold')

# LINE 1: one cut one quantifier
plt.subplot(4, 3, 1)
plt.axis('equal')
plt.pie(getValues(status_ocoq_examples), autopct='%1.1f%%', 
        shadow=True, colors=colorlst, radius=1.2, pctdistance=0.8)
plt.title("Proof examples: one cut one quantifier", size=15, y=1.1)

plt.subplot(4, 3, 2)
plt.axis('equal')
plt.pie(getValues(status_ocoq_prover9), autopct='%1.1f%%', 
        shadow=True, colors=colorlst, radius=1.2, pctdistance=0.8)
plt.title("Prover9: one cut one quantifier", size=15, y=1.1)

plt.subplot(4, 3, 3)
plt.axis('equal')
plt.pie(getValues(status_ocoq_verit), autopct='%1.1f%%', 
        shadow=True, colors=colorlst, radius=1.2, pctdistance=0.8)
plt.title("VeriT: one cut one quantifier", size=15, y=1.1)

# LINE 2: one cut many quantifiers
plt.subplot(4, 3, 4)
plt.axis('equal')
plt.pie(getValues(status_ocmq_examples), autopct='%1.1f%%', 
        shadow=True, colors=colorlst, radius=1.2, pctdistance=0.8)
plt.title("Proof examples: one cut many quantifiers", size=15, y=1.1)

plt.subplot(4, 3, 5)
plt.axis('equal')
plt.pie(getValues(status_ocmq_prover9), autopct='%1.1f%%', 
        shadow=True, colors=colorlst, radius=1.2, pctdistance=0.8)
plt.title("Prover9: one cut many quantifiers", size=15, y=1.1)

plt.subplot(4, 3, 6)
plt.axis('equal')
plt.pie(getValues(status_ocoq_verit), autopct='%1.1f%%', 
        shadow=True, colors=colorlst, radius=1.2, pctdistance=0.8)
plt.title("VeriT: one cut many quantifiers", size=15, y=1.1)

# LINE 3: many (1) cuts one quantifier
plt.subplot(4, 3, 7)
plt.axis('equal')
plt.pie(getValues(status_mcoq1_examples), autopct='%1.1f%%', 
        shadow=True, colors=colorlst, radius=1.2, pctdistance=0.8)
plt.title("Proof examples: many (1) cuts one quantifier", size=15, y=1.1)

plt.subplot(4, 3, 8)
plt.axis('equal')
plt.pie(getValues(status_mcoq1_prover9), autopct='%1.1f%%', 
        shadow=True, colors=colorlst, radius=1.2, pctdistance=0.8)
plt.title("Prover9: many (1) cuts one quantifier", size=15, y=1.1)

plt.subplot(4, 3, 9)
plt.axis('equal')
plt.pie(getValues(status_mcoq1_verit), autopct='%1.1f%%', 
        shadow=True, colors=colorlst, radius=1.2, pctdistance=0.8)
plt.title("VeriT: many (1) cuts one quantifier", size=15, y=1.1)

# LINE 4: many (2) cuts one quantifier
plt.subplot(4, 3, 10)
plt.axis('equal')
plt.pie(getValues(status_mcoq2_examples), autopct='%1.1f%%', 
        shadow=True, colors=colorlst, radius=1.2, pctdistance=0.8)
plt.title("Proof examples: many (2) cuts one quantifier", size=15, y=1.1)

plt.subplot(4, 3, 11)
plt.axis('equal')
plt.pie(getValues(status_mcoq2_prover9), autopct='%1.1f%%', 
        shadow=True, colors=colorlst, radius=1.2, pctdistance=0.8)
plt.title("Prover9: many (2) cuts one quantifier", size=15, y=1.1)

plt.subplot(4, 3, 12)
plt.axis('equal')
plt.pie(getValues(status_mcoq2_verit), autopct='%1.1f%%', 
        shadow=True, colors=colorlst, radius=1.2, pctdistance=0.8)
plt.title("VeriT: many (2) cuts one quantifier", size=15, y=1.1)

# %%
timecols = ['time_termset', 'time_grammar', 'time_minsol', 'time_proof', 'time_cleanproof']
times = []
def getTimes (data):
    times = []
    for c in timecols:
        times.append(data[c].mean())
    return times

times = pd.Series(getTimes(data), index=timecols)

colorlst = ['lime',
            'royalblue',
            'darkred',
            'yellow',
            'fuchsia'
            ]

values = [times[t] for t in timecols]

handles = [mpatches.Patch(color=c, label=t) for c, t in zip(colorlst, timecols)]

plt.figure(figsize=(15,7))
plt.axis('equal')
plt.pie(values, autopct='%1.1f%%', shadow=True, colors=colorlst, radius=1.2, pctdistance=0.8)
plt.title("Time consumption: full set", size=25, y=1.1)
plt.legend(handles, timecols, loc = 'lower right')

# %%
def getTimeValues (data):
    times = pd.Series(getTimes(data), index=timecols).replace(np.nan, 0)
    return [times[t] if t in times else 0 for t in timecols]

plt.figure(1, figsize=(17,17))
plt.subplots_adjust(wspace=0.25, hspace=0.20, top=0.85, bottom=0.05)
plt.figlegend(handles, timecols, loc='lower left')
plt.suptitle("Time Consumption", fontsize=24, fontweight='bold')

# LINE 1: one cut one quantifier
plt.subplot(4, 3, 1)
plt.axis('equal')
plt.pie(getTimeValues(data_ocoq_examples), autopct='%1.1f%%', 
        shadow=True, colors=colorlst, radius=1.2, pctdistance=0.8)
plt.title("Proof examples: one cut one quantifier", size=15, y=1.1)

plt.subplot(4, 3, 2)
plt.axis('equal')
plt.pie(getTimeValues(data_ocoq_prover9), autopct='%1.1f%%', 
        shadow=True, colors=colorlst, radius=1.2, pctdistance=0.8)
plt.title("Prover9: one cut one quantifier", size=15, y=1.1)

plt.subplot(4, 3, 3)
plt.axis('equal')
plt.pie(getTimeValues(data_ocoq_verit), autopct='%1.1f%%', 
        shadow=True, colors=colorlst, radius=1.2, pctdistance=0.8)
plt.title("VeriT: one cut one quantifier", size=15, y=1.1)

# LINE 2: one cut many quantifiers
plt.subplot(4, 3, 4)
plt.axis('equal')
plt.pie(getTimeValues(data_ocmq_examples), autopct='%1.1f%%', 
        shadow=True, colors=colorlst, radius=1.2, pctdistance=0.8)
plt.title("Proof examples: one cut many quantifiers", size=15, y=1.1)

plt.subplot(4, 3, 5)
plt.axis('equal')
plt.pie(getTimeValues(data_ocmq_prover9), autopct='%1.1f%%', 
        shadow=True, colors=colorlst, radius=1.2, pctdistance=0.8)
plt.title("Prover9: one cut many quantifiers", size=15, y=1.1)

plt.subplot(4, 3, 6)
plt.axis('equal')
plt.pie(getTimeValues(data_ocoq_verit), autopct='%1.1f%%', 
        shadow=True, colors=colorlst, radius=1.2, pctdistance=0.8)
plt.title("VeriT: one cut many quantifiers", size=15, y=1.1)

# LINE 3: many (1) cuts one quantifier
plt.subplot(4, 3, 7)
plt.axis('equal')
plt.pie(getTimeValues(data_mcoq1_examples), autopct='%1.1f%%', 
        shadow=True, colors=colorlst, radius=1.2, pctdistance=0.8)
plt.title("Proof examples: many (1) cuts one quantifier", size=15, y=1.1)

plt.subplot(4, 3, 8)
plt.axis('equal')
plt.pie(getTimeValues(data_mcoq1_prover9), autopct='%1.1f%%', 
        shadow=True, colors=colorlst, radius=1.2, pctdistance=0.8)
plt.title("Prover9: many (1) cuts one quantifier", size=15, y=1.1)

plt.subplot(4, 3, 9)
plt.axis('equal')
plt.pie(getTimeValues(data_mcoq1_verit), autopct='%1.1f%%', 
        shadow=True, colors=colorlst, radius=1.2, pctdistance=0.8)
plt.title("VeriT: many (1) cuts one quantifier", size=15, y=1.1)

# LINE 4: many (2) cuts one quantifier
plt.subplot(4, 3, 10)
plt.axis('equal')
plt.pie(getTimeValues(data_mcoq2_examples), autopct='%1.1f%%', 
        shadow=True, colors=colorlst, radius=1.2, pctdistance=0.8)
plt.title("Proof examples: many (2) cuts one quantifier", size=15, y=1.1)

plt.subplot(4, 3, 11)
plt.axis('equal')
plt.pie(getTimeValues(data_mcoq2_prover9), autopct='%1.1f%%', 
        shadow=True, colors=colorlst, radius=1.2, pctdistance=0.8)
plt.title("Prover9: many (2) cuts one quantifier", size=15, y=1.1)

plt.subplot(4, 3, 12)
plt.axis('equal')
plt.pie(getTimeValues(data_mcoq2_verit), autopct='%1.1f%%', 
        shadow=True, colors=colorlst, radius=1.2, pctdistance=0.8)
plt.title("VeriT: many (2) cuts one quantifier", size=15, y=1.1)

# %%
# Separating data by method and database (ok examples)
data_ocoq_examples_ok = data[(data.method == 'one_cut_one_quant') & (data.db == 0) & (data.status == 'ok')]
data_ocoq_prover9_ok = data[(data.method == 'one_cut_one_quant') & (data.db == 1) & (data.status == 'ok')]
data_ocoq_verit_ok = data[(data.method == 'one_cut_one_quant') & (data.db == 2) & (data.status == 'ok')]
data_ocmq_examples_ok = data[(data.method == 'one_cut_many_quant') & (data.db == 0) & (data.status == 'ok')]
data_ocmq_prover9_ok = data[(data.method == 'one_cut_many_quant') & (data.db == 1) & (data.status == 'ok')]
data_ocmq_verit_ok = data[(data.method == 'one_cut_many_quant') & (data.db == 2) & (data.status == 'ok')]
data_mcoq1_examples_ok = data[(data.method == 'many_cuts_one_quant_1') & (data.db == 0) & (data.status == 'ok')]
data_mcoq1_prover9_ok = data[(data.method == 'many_cuts_one_quant_1') & (data.db == 1) & (data.status == 'ok')]
data_mcoq1_verit_ok = data[(data.method == 'many_cuts_one_quant_1') & (data.db == 2) & (data.status == 'ok')]
data_mcoq2_examples_ok = data[(data.method == 'many_cuts_one_quant_2') & (data.db == 0) & (data.status == 'ok')]
data_mcoq2_prover9_ok = data[(data.method == 'many_cuts_one_quant_2') & (data.db == 1) & (data.status == 'ok')]
data_mcoq2_verit_ok = data[(data.method == 'many_cuts_one_quant_2') & (data.db == 2) & (data.status == 'ok')]

plt.figure(1, figsize=(17,17))
plt.subplots_adjust(wspace=0.25, hspace=0.20, top=0.85, bottom=0.05)
plt.figlegend(handles, timecols, loc='lower left')
plt.suptitle("Time Consumption for finished cases", fontsize=24, fontweight='bold')

# LINE 1: one cut one quantifier
plt.subplot(4, 3, 1)
plt.axis('equal')
plt.pie(getTimeValues(data_ocoq_examples_ok), autopct='%1.1f%%', 
        shadow=True, colors=colorlst, radius=1.2, pctdistance=0.8)
plt.title("Proof examples: one cut one quantifier", size=15, y=1.1)

plt.subplot(4, 3, 2)
plt.axis('equal')
plt.pie(getTimeValues(data_ocoq_prover9_ok), autopct='%1.1f%%', 
        shadow=True, colors=colorlst, radius=1.2, pctdistance=0.8)
plt.title("Prover9: one cut one quantifier", size=15, y=1.1)

plt.subplot(4, 3, 3)
plt.axis('equal')
plt.pie(getTimeValues(data_ocoq_verit_ok), autopct='%1.1f%%', 
        shadow=True, colors=colorlst, radius=1.2, pctdistance=0.8)
plt.title("VeriT: one cut one quantifier", size=15, y=1.1)

# LINE 2: one cut many quantifiers
plt.subplot(4, 3, 4)
plt.axis('equal')
plt.pie(getTimeValues(data_ocmq_examples_ok), autopct='%1.1f%%', 
        shadow=True, colors=colorlst, radius=1.2, pctdistance=0.8)
plt.title("Proof examples: one cut many quantifiers", size=15, y=1.1)

plt.subplot(4, 3, 5)
plt.axis('equal')
plt.pie(getTimeValues(data_ocmq_prover9_ok), autopct='%1.1f%%', 
        shadow=True, colors=colorlst, radius=1.2, pctdistance=0.8)
plt.title("Prover9: one cut many quantifiers", size=15, y=1.1)

plt.subplot(4, 3, 6)
plt.axis('equal')
plt.pie(getTimeValues(data_ocoq_verit_ok), autopct='%1.1f%%', 
        shadow=True, colors=colorlst, radius=1.2, pctdistance=0.8)
plt.title("VeriT: one cut many quantifiers", size=15, y=1.1)

# LINE 3: many (1) cuts one quantifier
plt.subplot(4, 3, 7)
plt.axis('equal')
plt.pie(getTimeValues(data_mcoq1_examples_ok), autopct='%1.1f%%', 
        shadow=True, colors=colorlst, radius=1.2, pctdistance=0.8)
plt.title("Proof examples: many (1) cuts one quantifier", size=15, y=1.1)

plt.subplot(4, 3, 8)
plt.axis('equal')
plt.pie(getTimeValues(data_mcoq1_prover9_ok), autopct='%1.1f%%', 
        shadow=True, colors=colorlst, radius=1.2, pctdistance=0.8)
plt.title("Prover9: many (1) cuts one quantifier", size=15, y=1.1)

plt.subplot(4, 3, 9)
plt.axis('equal')
plt.pie(getTimeValues(data_mcoq1_verit_ok), autopct='%1.1f%%', 
        shadow=True, colors=colorlst, radius=1.2, pctdistance=0.8)
plt.title("VeriT: many (1) cuts one quantifier", size=15, y=1.1)

# LINE 4: many (2) cuts one quantifier
plt.subplot(4, 3, 10)
plt.axis('equal')
plt.pie(getTimeValues(data_mcoq2_examples_ok), autopct='%1.1f%%', 
        shadow=True, colors=colorlst, radius=1.2, pctdistance=0.8)
plt.title("Proof examples: many (2) cuts one quantifier", size=15, y=1.1)

plt.subplot(4, 3, 11)
plt.axis('equal')
plt.pie(getTimeValues(data_mcoq2_prover9_ok), autopct='%1.1f%%', 
        shadow=True, colors=colorlst, radius=1.2, pctdistance=0.8)
plt.title("Prover9: many (2) cuts one quantifier", size=15, y=1.1)

plt.subplot(4, 3, 12)
plt.axis('equal')
plt.pie(getTimeValues(data_mcoq2_verit_ok), autopct='%1.1f%%', 
        shadow=True, colors=colorlst, radius=1.2, pctdistance=0.8)
plt.title("VeriT: many (2) cuts one quantifier", size=15, y=1.1)

# %%
# For Daniel
more_than_one_cut = data[(data.cuts_in > 1)]
print(more_than_one_cut.shape)
more_than_one_cut
# Out:
# (841, 20)
#                       method  \
# 220    many_cuts_one_quant_2
# 228    many_cuts_one_quant_2
# 230    many_cuts_one_quant_2
# 235    many_cuts_one_quant_2
# 239    many_cuts_one_quant_2
# 251    many_cuts_one_quant_2
# 253    many_cuts_one_quant_2
# 255    many_cuts_one_quant_2
# 276        one_cut_one_quant
# 289        one_cut_one_quant
# 290        one_cut_one_quant
# 297        one_cut_one_quant
# 306        one_cut_one_quant
# 307        one_cut_one_quant
# 310        one_cut_one_quant
# 311        one_cut_one_quant
# 312        one_cut_one_quant
# 325        one_cut_one_quant
# 326        one_cut_one_quant
# 332        one_cut_one_quant
# 337        one_cut_one_quant
# 340        one_cut_one_quant
# 353        one_cut_one_quant
# 355        one_cut_one_quant
# 362        one_cut_one_quant
# 367        one_cut_one_quant
# 373        one_cut_one_quant
# 377        one_cut_one_quant
# 378        one_cut_one_quant
# 379        one_cut_one_quant
# 387        one_cut_one_quant
# 390        one_cut_one_quant
# 393        one_cut_one_quant
# 397        one_cut_one_quant
# 398        one_cut_one_quant
# 402        one_cut_one_quant
# 409        one_cut_one_quant
# 418        one_cut_one_quant
# 426        one_cut_one_quant
# 427        one_cut_one_quant
# 438        one_cut_one_quant
# 440        one_cut_one_quant
# 455        one_cut_one_quant
# 458        one_cut_one_quant
# 459        one_cut_one_quant
# 480        one_cut_one_quant
# 494        one_cut_one_quant
# 498        one_cut_one_quant
# 501        one_cut_one_quant
# 503        one_cut_one_quant
# 505        one_cut_one_quant
# 530        one_cut_one_quant
# 533        one_cut_one_quant
# 534        one_cut_one_quant
# 542        one_cut_one_quant
# 560        one_cut_one_quant
# 562        one_cut_one_quant
# 563        one_cut_one_quant
# 575        one_cut_one_quant
# 576        one_cut_one_quant
# 591        one_cut_one_quant
# 596        one_cut_one_quant
# 599        one_cut_one_quant
# 606        one_cut_one_quant
# 608        one_cut_one_quant
# 613        one_cut_one_quant
# 618        one_cut_one_quant
# 624        one_cut_one_quant
# 625        one_cut_one_quant
# 635        one_cut_one_quant
# 636        one_cut_one_quant
# 652        one_cut_one_quant
# 653        one_cut_one_quant
# 660        one_cut_one_quant
# 667        one_cut_one_quant
# 676        one_cut_one_quant
# 685        one_cut_one_quant
# 686        one_cut_one_quant
# 691        one_cut_one_quant
# 712        one_cut_one_quant
# 718        one_cut_one_quant
# 723        one_cut_one_quant
# 725        one_cut_one_quant
# 734        one_cut_one_quant
# 739        one_cut_one_quant
# 742        one_cut_one_quant
# 743        one_cut_one_quant
# 759        one_cut_one_quant
# 761        one_cut_one_quant
# 765        one_cut_one_quant
# 766        one_cut_one_quant
# 770        one_cut_one_quant
# 776        one_cut_one_quant
# 788        one_cut_one_quant
# 794        one_cut_one_quant
# 804        one_cut_one_quant
# 805        one_cut_one_quant
# 808        one_cut_one_quant
# 811        one_cut_one_quant
# 815        one_cut_one_quant
# 816        one_cut_one_quant
# 822        one_cut_one_quant
# 828        one_cut_one_quant
# 830        one_cut_one_quant
# 834        one_cut_one_quant
# 839        one_cut_one_quant
# 846        one_cut_one_quant
# 858        one_cut_one_quant
# 864        one_cut_one_quant
# 868        one_cut_one_quant
# 876        one_cut_one_quant
# 894        one_cut_one_quant
# 898        one_cut_one_quant
# 899        one_cut_one_quant
# 913        one_cut_one_quant
# 914        one_cut_one_quant
# 920        one_cut_one_quant
# 922        one_cut_one_quant
# 923        one_cut_one_quant
# 925        one_cut_one_quant
# 927        one_cut_one_quant
# 941        one_cut_one_quant
# 943        one_cut_one_quant
# 944        one_cut_one_quant
# 946        one_cut_one_quant
# 951        one_cut_one_quant
# 953        one_cut_one_quant
# 957        one_cut_one_quant
# 960        one_cut_one_quant
# 962        one_cut_one_quant
# 965        one_cut_one_quant
# 966        one_cut_one_quant
# 968        one_cut_one_quant
# 978        one_cut_one_quant
# 984        one_cut_one_quant
# 989        one_cut_one_quant
# 991        one_cut_one_quant
# 994        one_cut_one_quant
# 998        one_cut_one_quant
# 1002       one_cut_one_quant
# 1003       one_cut_one_quant
# 1006       one_cut_one_quant
# 1010       one_cut_one_quant
# 1024       one_cut_one_quant
# 1025       one_cut_one_quant
# 1030       one_cut_one_quant
# 1033       one_cut_one_quant
# 1035       one_cut_one_quant
# 1041       one_cut_one_quant
# 1043       one_cut_one_quant
# 1044       one_cut_one_quant
# 1053       one_cut_one_quant
# 1065       one_cut_one_quant
# 1066       one_cut_one_quant
# 1071       one_cut_one_quant
# 1088       one_cut_one_quant
# 1101       one_cut_one_quant
# 1105       one_cut_one_quant
# 1109       one_cut_one_quant
# 1118       one_cut_one_quant
# 1120       one_cut_one_quant
# 1133       one_cut_one_quant
# 1134       one_cut_one_quant
# 1135       one_cut_one_quant
# 1140       one_cut_one_quant
# 1144       one_cut_one_quant
# 1146       one_cut_one_quant
# 1148       one_cut_one_quant
# 1153       one_cut_one_quant
# 1155       one_cut_one_quant
# 1157       one_cut_one_quant
# 1164       one_cut_one_quant
# 1169       one_cut_one_quant
# 1171       one_cut_one_quant
# 1174       one_cut_one_quant
# 2501       one_cut_one_quant
# 2502       one_cut_one_quant
# 2506       one_cut_one_quant
# 2510       one_cut_one_quant
# 2541       one_cut_one_quant
# 2542       one_cut_one_quant
# 2550       one_cut_one_quant
# 2553       one_cut_one_quant
# 2560       one_cut_one_quant
# 2561       one_cut_one_quant
# 2564       one_cut_one_quant
# 2567       one_cut_one_quant
# 2569       one_cut_one_quant
# 2579       one_cut_one_quant
# 2584       one_cut_one_quant
# 2590       one_cut_one_quant
# 2597       one_cut_one_quant
# 2604       one_cut_one_quant
# 2612       one_cut_one_quant
# 2618       one_cut_one_quant
# 2622       one_cut_one_quant
# 2623       one_cut_one_quant
# 2639       one_cut_one_quant
# 2644       one_cut_one_quant
# 2649       one_cut_one_quant
# 2650       one_cut_one_quant
# 2668       one_cut_one_quant
# 2669       one_cut_one_quant
# 2670       one_cut_one_quant
# 2675       one_cut_one_quant
# 2680       one_cut_one_quant
# 2682       one_cut_one_quant
# 2687       one_cut_one_quant
# 2688       one_cut_one_quant
# 2697       one_cut_one_quant
# 2703       one_cut_one_quant
# 2731       one_cut_one_quant
# 2751       one_cut_one_quant
# 2753       one_cut_one_quant
# 2763       one_cut_one_quant
# 2768       one_cut_one_quant
# 2769       one_cut_one_quant
# 2775       one_cut_one_quant
# 2783       one_cut_one_quant
# 2788       one_cut_one_quant
# 2802       one_cut_one_quant
# 2805       one_cut_one_quant
# 2826       one_cut_one_quant
# 2831       one_cut_one_quant
# 2838       one_cut_one_quant
# 2854       one_cut_one_quant
# 2859       one_cut_one_quant
# 2860       one_cut_one_quant
# 2862       one_cut_one_quant
# 2863       one_cut_one_quant
# 2873       one_cut_one_quant
# 2876       one_cut_one_quant
# 2887       one_cut_one_quant
# 2897       one_cut_one_quant
# 2913       one_cut_one_quant
# 2920       one_cut_one_quant
# 2939       one_cut_one_quant
# 2947       one_cut_one_quant
# 2953       one_cut_one_quant
# 2955       one_cut_one_quant
# 2956       one_cut_one_quant
# 2969       one_cut_one_quant
# 2977       one_cut_one_quant
# 2985       one_cut_one_quant
# 2986       one_cut_one_quant
# 3013       one_cut_one_quant
# 3021       one_cut_one_quant
# 3024       one_cut_one_quant
# 3031       one_cut_one_quant
# 3036       one_cut_one_quant
# 3045       one_cut_one_quant
# 3047       one_cut_one_quant
# 3048       one_cut_one_quant
# 3052       one_cut_one_quant
# 3053       one_cut_one_quant
# 3062       one_cut_one_quant
# 3063       one_cut_one_quant
# 3069       one_cut_one_quant
# 3071       one_cut_one_quant
# 3076       one_cut_one_quant
# 3078       one_cut_one_quant
# 3083       one_cut_one_quant
# 3087       one_cut_one_quant
# 3091       one_cut_one_quant
# 3092       one_cut_one_quant
# 3093       one_cut_one_quant
# 3111       one_cut_one_quant
# 3116       one_cut_one_quant
# 3120       one_cut_one_quant
# 3121       one_cut_one_quant
# 3123       one_cut_one_quant
# 3126       one_cut_one_quant
# 3136       one_cut_one_quant
# 3147       one_cut_one_quant
# 3149       one_cut_one_quant
# 3158       one_cut_one_quant
# 3161       one_cut_one_quant
# 3166       one_cut_one_quant
# 5930      one_cut_many_quant
# 5940      one_cut_many_quant
# 5945      one_cut_many_quant
# 5954      one_cut_many_quant
# 5956      one_cut_many_quant
# 5957      one_cut_many_quant
# 5961      one_cut_many_quant
# 5971      one_cut_many_quant
# 5972      one_cut_many_quant
# 5978      one_cut_many_quant
# 5980      one_cut_many_quant
# 5985      one_cut_many_quant
# 5987      one_cut_many_quant
# 5992      one_cut_many_quant
# 5996      one_cut_many_quant
# 6000      one_cut_many_quant
# 6002      one_cut_many_quant
# 6030      one_cut_many_quant
# 6056      one_cut_many_quant
# 6070      one_cut_many_quant
# 6075      one_cut_many_quant
# 9098   many_cuts_one_quant_2
# 9102   many_cuts_one_quant_2
# 9120   many_cuts_one_quant_2
# 9194   many_cuts_one_quant_2
# 9202   many_cuts_one_quant_2
# 9256   many_cuts_one_quant_2
# 9418   many_cuts_one_quant_2
# 9544   many_cuts_one_quant_2
# 9695   many_cuts_one_quant_2
# 9943   many_cuts_one_quant_2
# 10013  many_cuts_one_quant_2
# 10050  many_cuts_one_quant_2
# 10096  many_cuts_one_quant_2
# 10267  many_cuts_one_quant_2
# 10307  many_cuts_one_quant_2
# 10492  many_cuts_one_quant_2
# 10513  many_cuts_one_quant_2
# 10550  many_cuts_one_quant_2
# 10762  many_cuts_one_quant_2
# 10816  many_cuts_one_quant_2
# 11008  many_cuts_one_quant_2
# 11060  many_cuts_one_quant_2
# 11183  many_cuts_one_quant_2
# 11270  many_cuts_one_quant_2
# 11432  many_cuts_one_quant_2
# 11565  many_cuts_one_quant_2
# 11698  many_cuts_one_quant_2
# 12333  many_cuts_one_quant_2
# 12464  many_cuts_one_quant_2
#
#                                                     file  \
# 220                               LinearExampleProof(13)
# 228                        SquareDiagonalExampleProof(7)
# 230                        SquareDiagonalExampleProof(9)
# 235                           SquareEdgesExampleProof(5)
# 239                           SquareEdgesExampleProof(9)
# 251                              LinearEqExampleProof(7)
# 253                              LinearEqExampleProof(9)
# 255                             LinearEqExampleProof(11)
# 276    testing/TSTP/prover9/SWV/SWV480+1/Prover9---11...
# 289    testing/TSTP/prover9/SWV/SWV466+1/Prover9---11...
# 290    testing/TSTP/prover9/GEO/GEO070-3/Prover9---11...
# 297    testing/TSTP/prover9/GRP/GRP729-1/Prover9---11...
# 306    testing/TSTP/prover9/MGT/MGT054+1/Prover9---11...
# 307    testing/TSTP/prover9/MGT/MGT005-1/Prover9---11...
# 310    testing/TSTP/prover9/KLE/KLE150+2/Prover9---11...
# 311    testing/TSTP/prover9/NUM/NUM574+1/Prover9---11...
# 312    testing/TSTP/prover9/MGT/MGT055-1/Prover9---11...
# 325    testing/TSTP/prover9/KLE/KLE035+2/Prover9---11...
# 326    testing/TSTP/prover9/SEU/SEU340+1/Prover9---11...
# 332    testing/TSTP/prover9/SET/SET927+1/Prover9---11...
# 337    testing/TSTP/prover9/SET/SET017-7/Prover9---11...
# 340    testing/TSTP/prover9/BOO/BOO003-4/Prover9---11...
# 353    testing/TSTP/prover9/SWV/SWV745-1/Prover9---11...
# 355    testing/TSTP/prover9/SEU/SEU291+2/Prover9---11...
# 2221   testing/TSTP/prover9/GRP/GRP458-1/Prover9---11...
# 2235   testing/TSTP/prover9/GRP/GRP190-2/Prover9---11...
# 2248   testing/TSTP/prover9/PRO/PRO016+4/Prover9---11...
# 2257   testing/TSTP/prover9/NUM/NUM613+1/Prover9---11...
# 2258   testing/TSTP/prover9/MGT/MGT058+1/Prover9---11...
# 2261   testing/TSTP/prover9/GRP/GRP039-4/Prover9---11...
# 2284   testing/TSTP/prover9/SWV/SWV901-1/Prover9---11...
# 2285   testing/TSTP/prover9/HEN/HEN009-4/Prover9---11...
# 2286   testing/TSTP/prover9/GRP/GRP195-1/Prover9---11...
# 2291   testing/TSTP/prover9/GEO/GEO147-1/Prover9---11...
# 2297   testing/TSTP/prover9/CAT/CAT002-1/Prover9---11...
# 2300   testing/TSTP/prover9/SET/SET063-6/Prover9---11...
# 2301   testing/TSTP/prover9/GRP/GRP533-1/Prover9---11...
# 2302   testing/TSTP/prover9/REL/REL009-1/Prover9---11...
# 2307   testing/TSTP/prover9/KLE/KLE007+1/Prover9---11...
# 2312   testing/TSTP/prover9/LCL/LCL454+1/Prover9---11...
# 2313   testing/TSTP/prover9/BOO/BOO016-1/Prover9---11...
# 2322   testing/TSTP/prover9/GRP/GRP519-1/Prover9---11...
# 2325   testing/TSTP/prover9/KLE/KLE148+1/Prover9---11...
# 2338   testing/TSTP/prover9/SET/SET960+1/Prover9---11...
# ...
# 1951                28   1
# 1954                12   1
# 1975               151   1
# 1984                 6   1
# 1989                17   1
# 1997                 5   1
# 1998                14   1
# 2004                22   1
# 2021                10   1
# 2035                 5   1
# 2043                39   1
# 2047                15   1
# 2054                28   1
# 2062                43   1
# 2064                 4   1
# 2068                13   1
# 2074                 5   1
# 2075                32   1
# 2076                 1   1
# 2086               169   1
# 2103                 7   1
# 2107                13   1
# 2122                29   1
# 2123                 7   1
# 2132                 1   1
# 2134                27   1
# 2138                 4   1
# 2141                13   1
# 2144                 1   1
# 2145                 3   1
# 2160                 3   1
# 2162                44   1
# 2169                51   1
# 2170                33   1
# 2176                 6   1
# 2183                25   1
# 2206                11   1
# 2211                 3   1
# 2213                 5   1
# 2221                 6   1
# 2235               119   1
# 2248                28   1
# 2257                 8   1
# 2258                 2   1
# 2261                 5   1
# 2284                 9   1
# 2285                 1   1
# 2286                24   1
# 2291                 1   1
# 2297                 3   1
# 2300                 2   1
# 2301                 7   1
# 2302                 5   1
# 2307                 7   1
# 2312                 4   1
# 2313                 6   1
# 2322               170   1
# 2325                 2   1
# 2338                 7   1
# 2343                 9   1
# 2344                21   1
# 2348                21   1
# 2351                 5   1
# 2353                 8   1
# 2355                 6   1
# 2358                 6   1
# 2387                 1   1
# 2393                49   1
# 2399                 4   1
# 2404                10   1
# 2407                 4   1
# 2408                 6   1
# 2418                10   1
# 2420                 3   1
# 2422                63   1
# 2424                 4   1
# 2429                 2   1
# 2431                 1   1
# 2438                 6   1
# 2444                 1   1
# 2445               105   1
# 2446                58   1
# 2453                 1   1
# 2456                 7   1
# 2463                 4   1
# cutintro_other_exception             10
# lk_rule_creation_exception            2
# dtype: int64

# %% [markdown]
# Different grammar sizes between different methods:

# %%
data[data.mingrammar == data.mingrammar] \
    .groupby('file') \
    .filter(lambda x: len(set(x.mingrammar)) > 1) \
    .sort('file')[['file', 'method', 'mingrammar']]
# Out:
#                                                     file  \
# 37                        SquareEdges2DimExampleProof(6)
# 107                       SquareEdges2DimExampleProof(6)
# 180                       SquareEdges2DimExampleProof(6)
# 691    testing/TSTP/prover9/ALG/ALG029+1/Prover9---11...
# 3600   testing/TSTP/prover9/ALG/ALG029+1/Prover9---11...
# 6509   testing/TSTP/prover9/ALG/ALG029+1/Prover9---11...
# 9418   testing/TSTP/prover9/ALG/ALG029+1/Prover9---11...
# 968    testing/TSTP/prover9/ALG/ALG030+1/Prover9---11...
# 3877   testing/TSTP/prover9/ALG/ALG030+1/Prover9---11...
# 6786   testing/TSTP/prover9/ALG/ALG030+1/Prover9---11...
# 9695   testing/TSTP/prover9/ALG/ALG030+1/Prover9---11...
# 596    testing/TSTP/prover9/ALG/ALG074+1/Prover9---11...
# 3505   testing/TSTP/prover9/ALG/ALG074+1/Prover9---11...
# 6414   testing/TSTP/prover9/ALG/ALG074+1/Prover9---11...
# 9323   testing/TSTP/prover9/ALG/ALG074+1/Prover9---11...
# 1552   testing/TSTP/prover9/ALG/ALG178+1/Prover9---11...
# 4461   testing/TSTP/prover9/ALG/ALG178+1/Prover9---11...
# 7370   testing/TSTP/prover9/ALG/ALG178+1/Prover9---11...
# 10279  testing/TSTP/prover9/ALG/ALG178+1/Prover9---11...
# 362    testing/TSTP/prover9/ALG/ALG179+1/Prover9---11...
# 3271   testing/TSTP/prover9/ALG/ALG179+1/Prover9---11...
# 6180   testing/TSTP/prover9/ALG/ALG179+1/Prover9---11...
# 9089   testing/TSTP/prover9/ALG/ALG179+1/Prover9---11...
# 1369   testing/TSTP/prover9/ALG/ALG222+1/Prover9---11...
# 4278   testing/TSTP/prover9/ALG/ALG222+1/Prover9---11...
# 10096  testing/TSTP/prover9/ALG/ALG222+1/Prover9---11...
# 1520   testing/TSTP/prover9/ALG/ALG245-1/Prover9---11...
# 4429   testing/TSTP/prover9/ALG/ALG245-1/Prover9---11...
# 7338   testing/TSTP/prover9/ALG/ALG245-1/Prover9---11...
# 3048   testing/TSTP/prover9/ALG/ALG437-1/Prover9---11...
# 5957   testing/TSTP/prover9/ALG/ALG437-1/Prover9---11...
# 8866   testing/TSTP/prover9/ALG/ALG437-1/Prover9---11...
# 11775  testing/TSTP/prover9/ALG/ALG437-1/Prover9---11...
# 3384   testing/TSTP/prover9/ALG/ALG441-1/Prover9---11...
# 9202   testing/TSTP/prover9/ALG/ALG441-1/Prover9---11...
# 1410   testing/TSTP/prover9/BOO/BOO001-1/Prover9---11...
# 4319   testing/TSTP/prover9/BOO/BOO001-1/Prover9---11...
# 7228   testing/TSTP/prover9/BOO/BOO001-1/Prover9---11...
# 920    testing/TSTP/prover9/BOO/BOO003-2/Prover9---11...
# 3829   testing/TSTP/prover9/BOO/BOO003-2/Prover9---11...
# 2059   testing/TSTP/prover9/GEO/GEO181+1/Prover9---11...
# 4968   testing/TSTP/prover9/GEO/GEO181+1/Prover9---11...
# 7877   testing/TSTP/prover9/GEO/GEO181+1/Prover9---11...
# 10786  testing/TSTP/prover9/GEO/GEO181+1/Prover9---11...
# 1985   testing/TSTP/prover9/GEO/GEO191+1/Prover9---11...
# 4894   testing/TSTP/prover9/GEO/GEO191+1/Prover9---11...
# 7803   testing/TSTP/prover9/GEO/GEO191+1/Prover9---11...
# 2915   testing/TSTP/prover9/GEO/GEO193+1/Prover9---11...
# 5824   testing/TSTP/prover9/GEO/GEO193+1/Prover9---11...
# 8733   testing/TSTP/prover9/GEO/GEO193+1/Prover9---11...
# 1256   testing/TSTP/prover9/GEO/GEO196+1/Prover9---11...
# 4165   testing/TSTP/prover9/GEO/GEO196+1/Prover9---11...
# 7074   testing/TSTP/prover9/GEO/GEO196+1/Prover9---11...
# 2791   testing/TSTP/prover9/GEO/GEO198+1/Prover9---11...
# 5700   testing/TSTP/prover9/GEO/GEO198+1/Prover9---11...
# 8609   testing/TSTP/prover9/GEO/GEO198+1/Prover9---11...
# 11518  testing/TSTP/prover9/GEO/GEO198+1/Prover9---11...
# 2070   testing/TSTP/prover9/GEO/GEO199+2/Prover9---11...
# 4979   testing/TSTP/prover9/GEO/GEO199+2/Prover9---11...
# 7888   testing/TSTP/prover9/GEO/GEO199+2/Prover9---11...
# 10797  testing/TSTP/prover9/GEO/GEO199+2/Prover9---11...
# 4998   testing/TSTP/prover9/GEO/GEO200+2/Prover9---11...
# 10816  testing/TSTP/prover9/GEO/GEO200+2/Prover9---11...
# 5242   testing/TSTP/prover9/GEO/GEO201+1/Prover9---11...
# 11060  testing/TSTP/prover9/GEO/GEO201+1/Prover9---11...
# 4732   testing/TSTP/prover9/GEO/GEO201+2/Prover9---11...
# 10550  testing/TSTP/prover9/GEO/GEO201+2/Prover9---11...
# 2316   testing/TSTP/prover9/GEO/GEO201+3/Prover9---11...
# 5225   testing/TSTP/prover9/GEO/GEO201+3/Prover9---11...
# 8134   testing/TSTP/prover9/GEO/GEO201+3/Prover9---11...
# 2829   testing/TSTP/prover9/GEO/GEO204+2/Prover9---11...
# 5738   testing/TSTP/prover9/GEO/GEO204+2/Prover9---11...
# 8647   testing/TSTP/prover9/GEO/GEO204+2/Prover9---11...
# 11556  testing/TSTP/prover9/GEO/GEO204+2/Prover9---11...
# 1466   testing/TSTP/prover9/GEO/GEO205+1/Prover9---11...
# 4375   testing/TSTP/prover9/GEO/GEO205+1/Prover9---11...
# 7284   testing/TSTP/prover9/GEO/GEO205+1/Prover9---11...
# 10193  testing/TSTP/prover9/GEO/GEO205+1/Prover9---11...
# 1013   testing/TSTP/prover9/GEO/GEO205+3/Prover9---11...
# 3922   testing/TSTP/prover9/GEO/GEO205+3/Prover9---11...
# 6831   testing/TSTP/prover9/GEO/GEO205+3/Prover9---11...
# 1882   testing/TSTP/prover9/GEO/GEO255+3/Prover9---11...
# 4791   testing/TSTP/prover9/GEO/GEO255+3/Prover9---11...
# 7700   testing/TSTP/prover9/GEO/GEO255+3/Prover9---11...
# 10609  testing/TSTP/prover9/GEO/GEO255+3/Prover9---11...
# 529    testing/TSTP/prover9/GEO/GEO266+3/Prover9---11...
# 3438   testing/TSTP/prover9/GEO/GEO266+3/Prover9---11...
# 9256   testing/TSTP/prover9/GEO/GEO266+3/Prover9---11...
# 978    testing/TSTP/prover9/GRA/GRA004+1/Prover9---11...
# 3887   testing/TSTP/prover9/GRA/GRA004+1/Prover9---11...
# 6796   testing/TSTP/prover9/GRA/GRA004+1/Prover9---11...
# 9705   testing/TSTP/prover9/GRA/GRA004+1/Prover9---11...
# 1787   testing/TSTP/prover9/GRP/GRP001-4/Prover9---11...
# 4696   testing/TSTP/prover9/GRP/GRP001-4/Prover9---11...
# 7605   testing/TSTP/prover9/GRP/GRP001-4/Prover9---11...
# 10514  testing/TSTP/prover9/GRP/GRP001-4/Prover9---11...
# 2422   testing/TSTP/prover9/GRP/GRP011-4/Prover9---11...
# 5331   testing/TSTP/prover9/GRP/GRP011-4/Prover9---11...
# 8240   testing/TSTP/prover9/GRP/GRP011-4/Prover9---11...
# 11149  testing/TSTP/prover9/GRP/GRP011-4/Prover9---11...
# 2862   testing/TSTP/prover9/GRP/GRP040-3/Prover9---11...
# 5771   testing/TSTP/prover9/GRP/GRP040-3/Prover9---11...
# 8680   testing/TSTP/prover9/GRP/GRP040-3/Prover9---11...
# 2629   testing/TSTP/prover9/GRP/GRP124-1.004/Prover9-...
# 5538   testing/TSTP/prover9/GRP/GRP124-1.004/Prover9-...
# 8447   testing/TSTP/prover9/GRP/GRP124-1.004/Prover9-...
# 488    testing/TSTP/prover9/GRP/GRP124-3.004/Prover9-...
# 3397   testing/TSTP/prover9/GRP/GRP124-3.004/Prover9-...
# 6306   testing/TSTP/prover9/GRP/GRP124-3.004/Prover9-...
# 754    testing/TSTP/prover9/GRP/GRP124-4.004/Prover9-...
# 3663   testing/TSTP/prover9/GRP/GRP124-4.004/Prover9-...
# 6572   testing/TSTP/prover9/GRP/GRP124-4.004/Prover9-...
# 665    testing/TSTP/prover9/GRP/GRP124-6.004/Prover9-...
# 3574   testing/TSTP/prover9/GRP/GRP124-6.004/Prover9-...
# 6483   testing/TSTP/prover9/GRP/GRP124-6.004/Prover9-...
# 1327   testing/TSTP/prover9/GRP/GRP124-7.004/Prover9-...
# 4236   testing/TSTP/prover9/GRP/GRP124-7.004/Prover9-...
# 7145   testing/TSTP/prover9/GRP/GRP124-7.004/Prover9-...
# 3066   testing/TSTP/prover9/GRP/GRP124-8.004/Prover9-...
# 5975   testing/TSTP/prover9/GRP/GRP124-8.004/Prover9-...
# 8884   testing/TSTP/prover9/GRP/GRP124-8.004/Prover9-...
# 2110   testing/TSTP/prover9/GRP/GRP124-9.004/Prover9-...
# 5019   testing/TSTP/prover9/GRP/GRP124-9.004/Prover9-...
# 7928   testing/TSTP/prover9/GRP/GRP124-9.004/Prover9-...
# 3003   testing/TSTP/prover9/GRP/GRP126-2.004/Prover9-...
# 7167   testing/TSTP/prover9/GRP/GRP172-1/Prover9---11...
# 1509   testing/TSTP/prover9/GRP/GRP172-2/Prover9---11...
# 4418   testing/TSTP/prover9/GRP/GRP172-2/Prover9---11...
# 7327   testing/TSTP/prover9/GRP/GRP172-2/Prover9---11...
# 635    testing/TSTP/prover9/GRP/GRP174-1/Prover9---11...
# 3544   testing/TSTP/prover9/GRP/GRP174-1/Prover9---11...
# 6453   testing/TSTP/prover9/GRP/GRP174-1/Prover9---11...
# 9362   testing/TSTP/prover9/GRP/GRP174-1/Prover9---11...
# 1364   testing/TSTP/prover9/GRP/GRP175-4/Prover9---11...
# 4273   testing/TSTP/prover9/GRP/GRP175-4/Prover9---11...
# 7182   testing/TSTP/prover9/GRP/GRP175-4/Prover9---11...
# 3121   testing/TSTP/prover9/GRP/GRP190-1/Prover9---11...
# 6030   testing/TSTP/prover9/GRP/GRP190-1/Prover9---11...
# 8939   testing/TSTP/prover9/GRP/GRP190-1/Prover9---11...
# 11848  testing/TSTP/prover9/GRP/GRP190-1/Prover9---11...
# 2235   testing/TSTP/prover9/GRP/GRP190-2/Prover9---11...
# 5144   testing/TSTP/prover9/GRP/GRP190-2/Prover9---11...
# 8053   testing/TSTP/prover9/GRP/GRP190-2/Prover9---11...
# 2286   testing/TSTP/prover9/GRP/GRP195-1/Prover9---11...
# 5195   testing/TSTP/prover9/GRP/GRP195-1/Prover9---11...
# 8104   testing/TSTP/prover9/GRP/GRP195-1/Prover9---11...
# 1100   testing/TSTP/prover9/GRP/GRP292-1/Prover9---11...
# 6918   testing/TSTP/prover9/GRP/GRP292-1/Prover9---11...
# 1105   testing/TSTP/prover9/GRP/GRP355-1/Prover9---11...
# 4014   testing/TSTP/prover9/GRP/GRP355-1/Prover9---11...
# 6923   testing/TSTP/prover9/GRP/GRP355-1/Prover9---11...
# 1947   testing/TSTP/prover9/GRP/GRP455-1/Prover9---11...
# 4856   testing/TSTP/prover9/GRP/GRP455-1/Prover9---11...
# 7765   testing/TSTP/prover9/GRP/GRP455-1/Prover9---11...
# 10674  testing/TSTP/prover9/GRP/GRP455-1/Prover9---11...
# 2221   testing/TSTP/prover9/GRP/GRP458-1/Prover9---11...
# 5130   testing/TSTP/prover9/GRP/GRP458-1/Prover9---11...
# 8039   testing/TSTP/prover9/GRP/GRP458-1/Prover9---11...
# 10948  testing/TSTP/prover9/GRP/GRP458-1/Prover9---11...
# 2062   testing/TSTP/prover9/GRP/GRP487-1/Prover9---11...
# 4971   testing/TSTP/prover9/GRP/GRP487-1/Prover9---11...
# 7880   testing/TSTP/prover9/GRP/GRP487-1/Prover9---11...
# 10789  testing/TSTP/prover9/GRP/GRP487-1/Prover9---11...
# 2322   testing/TSTP/prover9/GRP/GRP519-1/Prover9---11...
# 8140   testing/TSTP/prover9/GRP/GRP519-1/Prover9---11...
# 2393   testing/TSTP/prover9/GRP/GRP520-1/Prover9---11...
# 5302   testing/TSTP/prover9/GRP/GRP520-1/Prover9---11...
# 8211   testing/TSTP/prover9/GRP/GRP520-1/Prover9---11...
# 11120  testing/TSTP/prover9/GRP/GRP520-1/Prover9---11...
# 898    testing/TSTP/prover9/GRP/GRP531-1/Prover9---11...
# 3807   testing/TSTP/prover9/GRP/GRP531-1/Prover9---11...
# 6716   testing/TSTP/prover9/GRP/GRP531-1/Prover9---11...
# 3136   testing/TSTP/prover9/GRP/GRP540-1/Prover9---11...
# 6045   testing/TSTP/prover9/GRP/GRP540-1/Prover9---11...
# 8954   testing/TSTP/prover9/GRP/GRP540-1/Prover9---11...
# 11863  testing/TSTP/prover9/GRP/GRP540-1/Prover9---11...
# 815    testing/TSTP/prover9/GRP/GRP544-1/Prover9---11...
# 3724   testing/TSTP/prover9/GRP/GRP544-1/Prover9---11...
# 2873   testing/TSTP/prover9/GRP/GRP552-1/Prover9---11...
# 8691   testing/TSTP/prover9/GRP/GRP552-1/Prover9---11...
# 1363   testing/TSTP/prover9/GRP/GRP565-1/Prover9---11...
# 4272   testing/TSTP/prover9/GRP/GRP565-1/Prover9---11...
# 7181   testing/TSTP/prover9/GRP/GRP565-1/Prover9---11...
# 10090  testing/TSTP/prover9/GRP/GRP565-1/Prover9---11...
# 1547   testing/TSTP/prover9/GRP/GRP573-1/Prover9---11...
# 4456   testing/TSTP/prover9/GRP/GRP573-1/Prover9---11...
# 7365   testing/TSTP/prover9/GRP/GRP573-1/Prover9---11...
# 10274  testing/TSTP/prover9/GRP/GRP573-1/Prover9---11...
# 3078   testing/TSTP/prover9/GRP/GRP574-1/Prover9---11...
# 5987   testing/TSTP/prover9/GRP/GRP574-1/Prover9---11...
# 8896   testing/TSTP/prover9/GRP/GRP574-1/Prover9---11...
# 11805  testing/TSTP/prover9/GRP/GRP574-1/Prover9---11...
# 1512   testing/TSTP/prover9/GRP/GRP577-1/Prover9---11...
# 4421   testing/TSTP/prover9/GRP/GRP577-1/Prover9---11...
# 7330   testing/TSTP/prover9/GRP/GRP577-1/Prover9---11...
# 10239  testing/TSTP/prover9/GRP/GRP577-1/Prover9---11...
# 1514   testing/TSTP/prover9/GRP/GRP578-1/Prover9---11...
# 4423   testing/TSTP/prover9/GRP/GRP578-1/Prover9---11...
# 7332   testing/TSTP/prover9/GRP/GRP578-1/Prover9---11...
# 10241  testing/TSTP/prover9/GRP/GRP578-1/Prover9---11...
# 2896   testing/TSTP/prover9/GRP/GRP589-1/Prover9---11...
# 5805   testing/TSTP/prover9/GRP/GRP589-1/Prover9---11...
# 8714   testing/TSTP/prover9/GRP/GRP589-1/Prover9---11...
# 11623  testing/TSTP/prover9/GRP/GRP589-1/Prover9---11...
# 2887   testing/TSTP/prover9/GRP/GRP640+1/Prover9---11...
# 5796   testing/TSTP/prover9/GRP/GRP640+1/Prover9---11...
# 8705   testing/TSTP/prover9/GRP/GRP640+1/Prover9---11...
# 1702   testing/TSTP/prover9/GRP/GRP656+1/Prover9---11...
# 4611   testing/TSTP/prover9/GRP/GRP656+1/Prover9---11...
# 7520   testing/TSTP/prover9/GRP/GRP656+1/Prover9---11...
# 10429  testing/TSTP/prover9/GRP/GRP656+1/Prover9---11...
# 7404   testing/TSTP/prover9/SET/SET505-6/Prover9---11...
# 333    testing/TSTP/prover9/SET/SET510-6/Prover9---11...
# 3242   testing/TSTP/prover9/SET/SET510-6/Prover9---11...
# 6151   testing/TSTP/prover9/SET/SET510-6/Prover9---11...
# 2165   testing/TSTP/prover9/SET/SET511-6/Prover9---11...
# 5074   testing/TSTP/prover9/SET/SET511-6/Prover9---11...
# 7983   testing/TSTP/prover9/SET/SET511-6/Prover9---11...
# 2557   testing/TSTP/prover9/SET/SET515-6/Prover9---11...
# 5466   testing/TSTP/prover9/SET/SET515-6/Prover9---11...
# 8375   testing/TSTP/prover9/SET/SET515-6/Prover9---11...
# 1276   testing/TSTP/prover9/SET/SET622+3/Prover9---11...
# 4185   testing/TSTP/prover9/SET/SET622+3/Prover9---11...
# 7094   testing/TSTP/prover9/SET/SET622+3/Prover9---11...
# 1630   testing/TSTP/prover9/SET/SET646+3/Prover9---11...
# 4539   testing/TSTP/prover9/SET/SET646+3/Prover9---11...
# 7448   testing/TSTP/prover9/SET/SET646+3/Prover9---11...
# 2817   testing/TSTP/prover9/SET/SET655+3/Prover9---11...
# 5726   testing/TSTP/prover9/SET/SET655+3/Prover9---11...
# 8635   testing/TSTP/prover9/SET/SET655+3/Prover9---11...
# 2802   testing/TSTP/prover9/SET/SET667+3/Prover9---11...
# 5711   testing/TSTP/prover9/SET/SET667+3/Prover9---11...
# 8620   testing/TSTP/prover9/SET/SET667+3/Prover9---11...
# 793    testing/TSTP/prover9/SET/SET788+1/Prover9---11...
# 3702   testing/TSTP/prover9/SET/SET788+1/Prover9---11...
# 9520   testing/TSTP/prover9/SET/SET788+1/Prover9---11...
# 2407   testing/TSTP/prover9/SET/SET821-2/Prover9---11...
# 5316   testing/TSTP/prover9/SET/SET821-2/Prover9---11...
# 8225   testing/TSTP/prover9/SET/SET821-2/Prover9---11...
# 11134  testing/TSTP/prover9/SET/SET821-2/Prover9---11...
# 2095   testing/TSTP/prover9/SET/SET930+1/Prover9---11...
# 5004   testing/TSTP/prover9/SET/SET930+1/Prover9---11...
# 7913   testing/TSTP/prover9/SET/SET930+1/Prover9---11...
# 533    testing/TSTP/prover9/SET/SET935+1/Prover9---11...
# 3442   testing/TSTP/prover9/SET/SET935+1/Prover9---11...
# 6351   testing/TSTP/prover9/SET/SET935+1/Prover9---11...
# 2680   testing/TSTP/prover9/SET/SET961+1/Prover9---11...
# 5589   testing/TSTP/prover9/SET/SET961+1/Prover9---11...
# 8498   testing/TSTP/prover9/SET/SET961+1/Prover9---11...
# 11407  testing/TSTP/prover9/SET/SET961+1/Prover9---11...
# 2206   testing/TSTP/prover9/SET/SET994+1/Prover9---11...
# 5115   testing/TSTP/prover9/SET/SET994+1/Prover9---11...
# 8024   testing/TSTP/prover9/SET/SET994+1/Prover9---11...
# 1730   testing/TSTP/prover9/SEU/SEU141+2/Prover9---11...
# 4639   testing/TSTP/prover9/SEU/SEU141+2/Prover9---11...
# 7548   testing/TSTP/prover9/SEU/SEU141+2/Prover9---11...
# 6258   testing/TSTP/prover9/SWB/SWB031+2/Prover9---11...
# 9167   testing/TSTP/prover9/SWB/SWB031+2/Prover9---11...
# 2141   testing/TSTP/prover9/SWV/SWV249-2/Prover9---11...
# 5050   testing/TSTP/prover9/SWV/SWV249-2/Prover9---11...
# 7959   testing/TSTP/prover9/SWV/SWV249-2/Prover9---11...
# 1997   testing/TSTP/prover9/SWV/SWV251-2/Prover9---11...
# 4906   testing/TSTP/prover9/SWV/SWV251-2/Prover9---11...
# 7815   testing/TSTP/prover9/SWV/SWV251-2/Prover9---11...
# 10724  testing/TSTP/prover9/SWV/SWV251-2/Prover9---11...
# 1140   testing/TSTP/prover9/SWV/SWV252-2/Prover9---11...
# 4049   testing/TSTP/prover9/SWV/SWV252-2/Prover9---11...
# 941    testing/TSTP/prover9/SWV/SWV275-2/Prover9---11...
# 3850   testing/TSTP/prover9/SWV/SWV275-2/Prover9---11...
# 6759   testing/TSTP/prover9/SWV/SWV275-2/Prover9---11...
# 1290   testing/TSTP/prover9/SWV/SWV281-2/Prover9---11...
# 4199   testing/TSTP/prover9/SWV/SWV281-2/Prover9---11...
# 7108   testing/TSTP/prover9/SWV/SWV281-2/Prover9---11...
# 2472   testing/TSTP/prover9/SWV/SWV298-2/Prover9---11...
# 5381   testing/TSTP/prover9/SWV/SWV298-2/Prover9---11...
# 8290   testing/TSTP/prover9/SWV/SWV298-2/Prover9---11...
# 11199  testing/TSTP/prover9/SWV/SWV298-2/Prover9---11...
# 3052   testing/TSTP/prover9/SWV/SWV465+1/Prover9---11...
# 5961   testing/TSTP/prover9/SWV/SWV465+1/Prover9---11...
# 8870   testing/TSTP/prover9/SWV/SWV465+1/Prover9---11...
# 1401   testing/TSTP/prover9/SWV/SWV476+1/Prover9---11...
# 4310   testing/TSTP/prover9/SWV/SWV476+1/Prover9---11...
# 7219   testing/TSTP/prover9/SWV/SWV476+1/Prover9---11...
# ...
# 4863      one_cut_many_quant          30
# 7772   many_cuts_one_quant_1          32
# 393        one_cut_one_quant          18
# 3302      one_cut_many_quant          15
# 6211   many_cuts_one_quant_1          18
# 9120   many_cuts_one_quant_2          17
# 3092       one_cut_one_quant          29
# 6001      one_cut_many_quant          27
# 8910   many_cuts_one_quant_1          29
# 2456       one_cut_one_quant          18
# 5365      one_cut_many_quant          15
# 8274   many_cuts_one_quant_1          18
# 11183  many_cuts_one_quant_2          17
# 1412       one_cut_one_quant          29
# 4321      one_cut_many_quant          27
# 7230   many_cuts_one_quant_1          29
# 980        one_cut_one_quant          15
# 3889      one_cut_many_quant          15
# 6798   many_cuts_one_quant_1          13
# 9707   many_cuts_one_quant_2          13
# 2776       one_cut_one_quant          15
# 5685      one_cut_many_quant          15
# 8594   many_cuts_one_quant_1          13
# 11503  many_cuts_one_quant_2          13
# 3280      one_cut_many_quant           7
# 9098   many_cuts_one_quant_2           9
# 5190      one_cut_many_quant           7
# 11008  many_cuts_one_quant_2           9
# 965        one_cut_one_quant          25
# 3874      one_cut_many_quant          25
# 6783   many_cuts_one_quant_1          24
# 9692   many_cuts_one_quant_2          24
# 2783       one_cut_one_quant          23
# 5692      one_cut_many_quant          23
# 8601   many_cuts_one_quant_1          22
# 11510  many_cuts_one_quant_2          22
# 811        one_cut_one_quant          20
# 3720      one_cut_many_quant          20
# 6629   many_cuts_one_quant_1          19
# 9538   many_cuts_one_quant_2          19
# 455        one_cut_one_quant          18
# 3364      one_cut_many_quant          18
# 6273   many_cuts_one_quant_1          17
# 9182   many_cuts_one_quant_2          17
# 1778       one_cut_one_quant          12
# 4687      one_cut_many_quant          12
# 7596   many_cuts_one_quant_1          11
# 10505  many_cuts_one_quant_2          11
# 2651       one_cut_one_quant          19
# 5560      one_cut_many_quant          19
# 8469   many_cuts_one_quant_1          16
# 2940       one_cut_one_quant          26
# 5849      one_cut_many_quant          26
# 8758   many_cuts_one_quant_1          23
# 2035       one_cut_one_quant          15
# 4944      one_cut_many_quant          15
# 7853   many_cuts_one_quant_1          15
# 10762  many_cuts_one_quant_2          14
# 2760       one_cut_one_quant          18
# 5669      one_cut_many_quant          18
# 8578   many_cuts_one_quant_1          17
# 11487  many_cuts_one_quant_2          17
# 2517       one_cut_one_quant          18
# 5426      one_cut_many_quant          18
# 8335   many_cuts_one_quant_1          17
# 11244  many_cuts_one_quant_2          17
# 636        one_cut_one_quant          34
# 3545      one_cut_many_quant          31
# 2953       one_cut_one_quant          41
# 5862      one_cut_many_quant          38
# 3024       one_cut_one_quant          23
# 5933      one_cut_many_quant          22
# 8842   many_cuts_one_quant_1          23
# 1270       one_cut_one_quant          31
# 4179      one_cut_many_quant          30
# 7088   many_cuts_one_quant_1          30
# 1497       one_cut_one_quant          24
# 4406      one_cut_many_quant          24
# 7315   many_cuts_one_quant_1          23
# 1535       one_cut_one_quant          18
# 4444      one_cut_many_quant          18
# 7353   many_cuts_one_quant_1          17
# 10262  many_cuts_one_quant_2          17
# 1457       one_cut_one_quant          30
# 4366      one_cut_many_quant          30
# 7275   many_cuts_one_quant_1          29
# 623        one_cut_one_quant          29
# 3532      one_cut_many_quant          29
# 6441   many_cuts_one_quant_1          28
# 987        one_cut_one_quant          18
# 3896      one_cut_many_quant          18
# 6805   many_cuts_one_quant_1          17
# 9714   many_cuts_one_quant_2          17
# 2639       one_cut_one_quant          19
# 5548      one_cut_many_quant          19
# 8457   many_cuts_one_quant_1          17
# 11366  many_cuts_one_quant_2          17
# 2162       one_cut_one_quant          74
# 5071      one_cut_many_quant          72
# 2947       one_cut_one_quant          31
# 5856      one_cut_many_quant          31
# 8765   many_cuts_one_quant_1          30
# 748        one_cut_one_quant          25
# 3657      one_cut_many_quant          25
# 6566   many_cuts_one_quant_1          24
# 9475   many_cuts_one_quant_2          24
# 804        one_cut_one_quant          29
# 3713      one_cut_many_quant          29
# 6622   many_cuts_one_quant_1          28
# 2170       one_cut_one_quant          43
# 5079      one_cut_many_quant          35
# 1703       one_cut_one_quant          27
# 4612      one_cut_many_quant          27
# 7521   many_cuts_one_quant_1          26
# 2510       one_cut_one_quant          13
# 5419      one_cut_many_quant          12
# 8328   many_cuts_one_quant_1          13
# 11237  many_cuts_one_quant_2          13
# 625        one_cut_one_quant          22
# 3534      one_cut_many_quant          20
# 6443   many_cuts_one_quant_1          22
# 2753       one_cut_one_quant          24
# 5662      one_cut_many_quant          23
# 8571   many_cuts_one_quant_1          22
# 1323       one_cut_one_quant          10
# 4232      one_cut_many_quant           8
# 10050  many_cuts_one_quant_2          10
# 1000       one_cut_one_quant          10
# 3909      one_cut_many_quant           8
# 6818   many_cuts_one_quant_1          10
# 9727   many_cuts_one_quant_2          10
# 709        one_cut_one_quant          19
# 3618      one_cut_many_quant          19
# 6527   many_cuts_one_quant_1          16
# 1269       one_cut_one_quant          24
# 4178      one_cut_many_quant          24
# 7087   many_cuts_one_quant_1          22
# 1656       one_cut_one_quant          25
# 4565      one_cut_many_quant          25
# 7474   many_cuts_one_quant_1          23
# 2419       one_cut_one_quant          23
# 5328      one_cut_many_quant          23
# 8237   many_cuts_one_quant_1          21
# 783        one_cut_one_quant          23
# 3692      one_cut_many_quant          23
# 6601   many_cuts_one_quant_1          21
# 3161       one_cut_one_quant          27
# 6070      one_cut_many_quant          27
# 8979   many_cuts_one_quant_1          24
# 3167       one_cut_one_quant          26
# 6076      one_cut_many_quant          26
# 8985   many_cuts_one_quant_1          23
# 1119       one_cut_one_quant          26
# 4028      one_cut_many_quant          26
# 6937   many_cuts_one_quant_1          24
# 1586       one_cut_one_quant          27
# 4495      one_cut_many_quant          27
# 7404   many_cuts_one_quant_1          25
# 333        one_cut_one_quant          27
# 3242      one_cut_many_quant          27
# 6151   many_cuts_one_quant_1          23
# 2165       one_cut_one_quant          26
# 5074      one_cut_many_quant          26
# 7983   many_cuts_one_quant_1          21
# 2557       one_cut_one_quant          26
# 5466      one_cut_many_quant          26
# 8375   many_cuts_one_quant_1          23
# 1276       one_cut_one_quant          13
# 4185      one_cut_many_quant          12
# 7094   many_cuts_one_quant_1          13
# 1630       one_cut_one_quant          27
# 4539      one_cut_many_quant          26
# 7448   many_cuts_one_quant_1          27
# 2817       one_cut_one_quant          34
# 5726      one_cut_many_quant          32
# 8635   many_cuts_one_quant_1          33
# 2802       one_cut_one_quant          27
# 5711      one_cut_many_quant          27
# 8620   many_cuts_one_quant_1          26
# 793        one_cut_one_quant          10
# 3702      one_cut_many_quant           8
# 9520   many_cuts_one_quant_2          10
# 2407       one_cut_one_quant          16
# 5316      one_cut_many_quant          15
# 8225   many_cuts_one_quant_1          16
# 11134  many_cuts_one_quant_2          16
# 2095       one_cut_one_quant          22
# 5004      one_cut_many_quant          22
# 7913   many_cuts_one_quant_1          20
# 533        one_cut_one_quant          26
# 3442      one_cut_many_quant          26
# 6351   many_cuts_one_quant_1          25
# 2680       one_cut_one_quant          19
# 5589      one_cut_many_quant          17
# 8498   many_cuts_one_quant_1          19
# 11407  many_cuts_one_quant_2          19
# 2206       one_cut_one_quant          29
# 5115      one_cut_many_quant          29
# 8024   many_cuts_one_quant_1          27
# 1730       one_cut_one_quant          23
# 4639      one_cut_many_quant          22
# 7548   many_cuts_one_quant_1          23
# 10457  many_cuts_one_quant_2          23
# 808        one_cut_one_quant          16
# 3717      one_cut_many_quant          16
# 6626   many_cuts_one_quant_1          15
# 9535   many_cuts_one_quant_2          15
# 1480       one_cut_one_quant          32
# 4389      one_cut_many_quant          31
# 7298   many_cuts_one_quant_1          32
# 2607       one_cut_one_quant          32
# 5516      one_cut_many_quant          32
# 8425   many_cuts_one_quant_1          27
# 1285       one_cut_one_quant          32
# 4194      one_cut_many_quant          32
# 7103   many_cuts_one_quant_1          27
# 2156       one_cut_one_quant          23
# 5065      one_cut_many_quant          22
# 7974   many_cuts_one_quant_1          23
# 10883  many_cuts_one_quant_2          23
# 1155       one_cut_one_quant          52
# 4064      one_cut_many_quant          51
# 837        one_cut_one_quant          29
# 3746      one_cut_many_quant          28
# 998        one_cut_one_quant          26
# 3907      one_cut_many_quant          25
# 6816   many_cuts_one_quant_1          25
# 1175       one_cut_one_quant          25
# 4084      one_cut_many_quant          24
# 1657       one_cut_one_quant          22
# 4566      one_cut_many_quant          18
# 7475   many_cuts_one_quant_1          22
# 3726      one_cut_many_quant          19
# 9544   many_cuts_one_quant_2          20
# 4195      one_cut_many_quant          19
# 10013  many_cuts_one_quant_2          21
# 326        one_cut_one_quant          21
# 3235      one_cut_many_quant          20
# 6144   many_cuts_one_quant_1          21
# 5614      one_cut_many_quant          13
# 11432  many_cuts_one_quant_2          15
# 5452      one_cut_many_quant           9
# 11270  many_cuts_one_quant_2          11
# 440        one_cut_one_quant           9
# 3349      one_cut_many_quant           9
# 6258   many_cuts_one_quant_1           8
# 9167   many_cuts_one_quant_2           8
# 2141       one_cut_one_quant          24
# 5050      one_cut_many_quant          22
# 7959   many_cuts_one_quant_1          24
# 1997       one_cut_one_quant          15
# 4906      one_cut_many_quant          14
# 7815   many_cuts_one_quant_1          15
# 10724  many_cuts_one_quant_2          15
# 1140       one_cut_one_quant          29
# 4049      one_cut_many_quant          27
# 941        one_cut_one_quant          13
# 3850      one_cut_many_quant          12
# 6759   many_cuts_one_quant_1          13
# 1290       one_cut_one_quant          17
# 4199      one_cut_many_quant          17
# 7108   many_cuts_one_quant_1          16
# 2472       one_cut_one_quant          13
# 5381      one_cut_many_quant          12
# 8290   many_cuts_one_quant_1          13
# 11199  many_cuts_one_quant_2          13
# 3052       one_cut_one_quant          24
# 5961      one_cut_many_quant          24
# 8870   many_cuts_one_quant_1          23
# 1401       one_cut_one_quant          25
# 4310      one_cut_many_quant          25
# 7219   many_cuts_one_quant_1          23
# 2183       one_cut_one_quant          25
# 5092      one_cut_many_quant          25
# 8001   many_cuts_one_quant_1          23
# 377        one_cut_one_quant          25
# 3286      one_cut_many_quant          25
# 6195   many_cuts_one_quant_1          23
# 1739       one_cut_one_quant          22
# 4648      one_cut_many_quant          22
# 7557   many_cuts_one_quant_1          21
# 10466  many_cuts_one_quant_2          21
# 276        one_cut_one_quant          22
# 3185      one_cut_many_quant          22
# 6094   many_cuts_one_quant_1          21
# 9003   many_cuts_one_quant_2          21
# 953        one_cut_one_quant          28
# 3862      one_cut_many_quant          28
# 6771   many_cuts_one_quant_1          26
# 2697       one_cut_one_quant          15
# 5606      one_cut_many_quant          13
# 8515   many_cuts_one_quant_1          15
# 11424  many_cuts_one_quant_2          15
# 1984       one_cut_one_quant          23
# 4893      one_cut_many_quant          21
# 7802   many_cuts_one_quant_1          21
# 2063       one_cut_one_quant          34
# 4972      one_cut_many_quant          31
# 1311       one_cut_one_quant          34
# 4220      one_cut_many_quant          31
# 3012       one_cut_one_quant          31
# 5921      one_cut_many_quant          31
# 8830   many_cuts_one_quant_1          27
# 805        one_cut_one_quant          28
# 3714      one_cut_many_quant          28
# 6623   many_cuts_one_quant_1          26
# 944        one_cut_one_quant          28
# 3853      one_cut_many_quant          28
# 6762   many_cuts_one_quant_1          26
# 609        one_cut_one_quant          33
# 3518      one_cut_many_quant          31
# 3093       one_cut_one_quant          29
# 6002      one_cut_many_quant          29
# 8911   many_cuts_one_quant_1          25
# 1850       one_cut_one_quant          22
# 4759      one_cut_many_quant          22
# 7668   many_cuts_one_quant_1          20
# 2956       one_cut_one_quant          17
# 5865      one_cut_many_quant          16
# 8774   many_cuts_one_quant_1          17
# 4167      one_cut_many_quant          22
# 7076   many_cuts_one_quant_1          23
# 3162       one_cut_one_quant          19
# 6071      one_cut_many_quant          16
# 8980   many_cuts_one_quant_1          19
# 3156       one_cut_one_quant          19
# 6065      one_cut_many_quant          16
# 8974   many_cuts_one_quant_1          19
# 2356       one_cut_one_quant           7
# 5265      one_cut_many_quant           7
# 8174   many_cuts_one_quant_1           6
# 11083  many_cuts_one_quant_2           6
# 1332       one_cut_one_quant          24
# 4241      one_cut_many_quant          24
# 7150   many_cuts_one_quant_1          23
# 10059  many_cuts_one_quant_2          23
# 1747       one_cut_one_quant          19
# 4656      one_cut_many_quant          16
# 7565   many_cuts_one_quant_1          19
# 1447       one_cut_one_quant          19
# 4356      one_cut_many_quant          16
# 7265   many_cuts_one_quant_1          19
# 3001       one_cut_one_quant          14
# 5910      one_cut_many_quant          13
# 1803       one_cut_one_quant          13
# 4712      one_cut_many_quant          13
# 7621   many_cuts_one_quant_1          12
# 10530  many_cuts_one_quant_2          12
# 2151       one_cut_one_quant          12
# 5060      one_cut_many_quant          12
# 7969   many_cuts_one_quant_1          11
# 10878  many_cuts_one_quant_2          11
# 1601       one_cut_one_quant          12
# 4510      one_cut_many_quant          12
# 7419   many_cuts_one_quant_1          11
# 10328  many_cuts_one_quant_2          11
# 2871       one_cut_one_quant          10
# 5780      one_cut_many_quant          10
# 8689   many_cuts_one_quant_1           9
# 11598  many_cuts_one_quant_2           9
# 12322  many_cuts_one_quant_1          15
# 12464  many_cuts_one_quant_2          12
# 11911      one_cut_one_quant           9
# 12053     one_cut_many_quant           9
# 12195  many_cuts_one_quant_1           8
# 12337  many_cuts_one_quant_2           8
# 11907      one_cut_one_quant          20
# 12049     one_cut_many_quant          20
# 12191  many_cuts_one_quant_1          14
# 12333  many_cuts_one_quant_2          13
# 11910      one_cut_one_quant          32
# 12194  many_cuts_one_quant_1          20
